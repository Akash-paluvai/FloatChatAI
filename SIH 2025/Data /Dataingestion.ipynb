# %%
import requests
from bs4 import BeautifulSoup
import xarray as xr
import fsspec
import pandas as pd
import numpy as np
import os

# -----------------------
# Config
# -----------------------
BASE_URL = "https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/"
YEARS = range(2022, 2026)
MONTHS = [f"{m:02d}" for m in range(1, 13)]
OUT_DIR = "argo_2022_2025_parquet"
os.makedirs(OUT_DIR, exist_ok=True)

# -----------------------
# Function: process 1 file
# -----------------------
def process_argo_file(file_url: str) -> pd.DataFrame:
    """Download, flatten, and clean one Argo .nc file into a DataFrame"""
    with fsspec.open(file_url) as f:
        ds = xr.open_dataset(f, engine="scipy")

    # Infer dims (N_PROF, N_LEVELS)
    prof_dim = next((d for d in ds.dims if "N_PROF" in d), None)
    level_dim = next((d for d in ds.dims if "N_LEVEL" in d or "N_LEVELS" in d), None)

    # Flatten into DataFrame
    if prof_dim and level_dim:
        df = ds.stack(obs=[prof_dim, level_dim]).to_dataframe().reset_index()
    elif prof_dim:
        df = ds.stack(obs=[prof_dim]).to_dataframe().reset_index()
    else:
        df = ds.to_dataframe().reset_index()

    # Basic cleaning
    df.dropna(axis=1, how="all", inplace=True)  # drop fully empty columns
    thresh = int(0.1 * len(df))                 # drop cols >90% NaN
    df.dropna(axis=1, thresh=thresh, inplace=True)

    # Fill numeric NaNs with mean
    for col in df.select_dtypes(include=[np.number]).columns:
        if df[col].isna().any():
            df[col].fillna(df[col].mean(), inplace=True)

    df["source_file"] = file_url
    return df

# -----------------------
# Main loop
# -----------------------
for year in YEARS:
    print(f"\n📂 Processing year: {year}")
    for month in MONTHS:
        dir_url = f"{BASE_URL}{year}/{month}/"

        # Fetch directory listing
        try:
            resp = requests.get(dir_url, timeout=10)
            if resp.status_code != 200:
                continue
        except:
            continue

        soup = BeautifulSoup(resp.text, "html.parser")
        files = [a['href'] for a in soup.find_all('a') if a['href'].endswith(".nc")]
        if not files:
            continue

        month_data = []
        for file in files:   # ✅ take all files, not just one
            file_url = dir_url + file
            print(f"  🔹 Reading: {file_url}")
            try:
                df = process_argo_file(file_url)
                month_data.append(df)
            except Exception as e:
                print(f"    ⚠ Skipped {file}: {e}")

        # Save monthly parquet
        if month_data:
            final_df = pd.concat(month_data, ignore_index=True)
            out_file = f"{OUT_DIR}/{year}_{month}_ALL_PARAMS.parquet"
            final_df.to_parquet(out_file, index=False)
            print(f"✅ Saved Parquet: {out_file} | Shape: {final_df.shape}")

print("\n🎉 Processing complete! One Parquet per month with all detected parameters.")
# Out:
# 📂 Processing year: 2022
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220101_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220101_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220102_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220102_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220103_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220103_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220104_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220104_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220105_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220105_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220106_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220106_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220107_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220107_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220108_prof.nc
#     ⚠ Skipped 20220108_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220109_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220109_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220110_prof.nc
#     ⚠ Skipped 20220110_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220111_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220111_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220112_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220112_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220113_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220113_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220114_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220114_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220115_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220115_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220116_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220116_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220117_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220117_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220118_prof.nc
#     ⚠ Skipped 20220118_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220119_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220119_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220120_prof.nc
#     ⚠ Skipped 20220120_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220121_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220121_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220122_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220122_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220123_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220123_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220124_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220124_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220125_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220125_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220126_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220126_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220127_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# ...
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220325_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220326_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220326_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220327_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220327_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220328_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220328_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220329_prof.nc
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-3758854293.py:24: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220329_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#   🔹 Reading: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220330_prof.nc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3758854293.py in <cell line: 0>()
#      75             print(f"  🔹 Reading: {file_url}")
#      76             try:
# ---> 77                 df = process_argo_file(file_url)
#      78                 month_data.append(df)
#      79             except Exception as e:
#
# /tmp/ipython-input-3758854293.py in process_argo_file(file_url)
#      22     """Download, flatten, and clean one Argo .nc file into a DataFrame"""
#      23     with fsspec.open(file_url) as f:
# ---> 24         ds = xr.open_dataset(f, engine="scipy")
#      25
#      26     # Infer dims (N_PROF, N_LEVELS)
#
# /usr/local/lib/python3.12/dist-packages/xarray/backends/api.py in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     758
#     759     overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 760     backend_ds = backend.open_dataset(
#     761         filename_or_obj,
#     762         drop_variables=drop_variables,
#
# /usr/local/lib/python3.12/dist-packages/xarray/backends/scipy_.py in open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, mode, format, group, mmap, lock)
#     361     ) -> Dataset:
#     362         filename_or_obj = _normalize_filename_or_obj(filename_or_obj)
# --> 363         store = ScipyDataStore(
#     364             filename_or_obj, mode=mode, format=format, group=group, mmap=mmap, lock=lock
#     365         )
#
# /usr/local/lib/python3.12/dist-packages/xarray/backends/scipy_.py in __init__(self, filename_or_obj, mode, format, group, mmap, lock)
#     184             # Note: checking for .seek matches the check for file objects
#     185             # in scipy.io.netcdf_file
# --> 186             scipy_dataset = _open_scipy_netcdf(
#     187                 filename_or_obj, mode=mode, mmap=mmap, version=version
#     188             )
#
# /usr/local/lib/python3.12/dist-packages/xarray/backends/scipy_.py in _open_scipy_netcdf(filename, mode, mmap, version)
#     125
#     126     try:
# --> 127         return scipy.io.netcdf_file(filename, mode=mode, mmap=mmap, version=version)
#     128     except TypeError as e:  # netcdf3 message is obscure in this case
#     129         errmsg = e.args[0]
#
# /usr/local/lib/python3.12/dist-packages/scipy/io/_netcdf.py in __init__(self, filename, mode, mmap, version, maskandscale)
#     281
#     282         if mode in 'ra':
# --> 283             self._read()
#     284
#     285     def __setattr__(self, attr, value):
#
# /usr/local/lib/python3.12/dist-packages/scipy/io/_netcdf.py in _read(self)
#     613         self._read_dim_array()
#     614         self._read_gatt_array()
# --> 615         self._read_var_array()
#     616
#     617     def _read_numrecs(self):
#
# /usr/local/lib/python3.12/dist-packages/scipy/io/_netcdf.py in _read_var_array(self)
#     701                     pos = self.fp.tell()
#     702                     self.fp.seek(begin_)
# --> 703                     data = frombuffer(self.fp.read(a_size), dtype=dtype_
#     704                                       ).copy()
#     705                     data.shape = shape
#
# /usr/local/lib/python3.12/dist-packages/fsspec/implementations/http.py in read(self, length)
#     625         else:
#     626             length = min(self.size - self.loc, length)
# --> 627         return super().read(length)
#     628
#     629     async def async_fetch_all(self):
#
# /usr/local/lib/python3.12/dist-packages/fsspec/spec.py in read(self, length)
#    2081             # don't even bother calling fetch
#    2082             return b""
# -> 2083         out = self.cache._fetch(self.loc, self.loc + length)
#    2084
#    2085         logger.debug(
#
# /usr/local/lib/python3.12/dist-packages/fsspec/caching.py in _fetch(self, start, end)
#     516                 elif end - self.end > self.blocksize:
#     517                     self.total_requested_bytes += bend - start
# --> 518                     self.cache = self.fetcher(start, bend)
#     519                     self.start = start
#     520                 else:
#
# /usr/local/lib/python3.12/dist-packages/fsspec/asyn.py in wrapper(*args, **kwargs)
#     116     def wrapper(*args, **kwargs):
#     117         self = obj or args[0]
# --> 118         return sync(self.loop, func, *args, **kwargs)
#     119
#     120     return wrapper
#
# /usr/local/lib/python3.12/dist-packages/fsspec/asyn.py in sync(loop, func, timeout, *args, **kwargs)
#      89     while True:
#      90         # this loops allows thread to get interrupted
# ---> 91         if event.wait(1):
#      92             break
#      93         if timeout is not None:
#
# /usr/lib/python3.12/threading.py in wait(self, timeout)
#     653             signaled = self._flag
#     654             if not signaled:
# --> 655                 signaled = self._cond.wait(timeout)
#     656             return signaled
#     657
#
# /usr/lib/python3.12/threading.py in wait(self, timeout)
#     357             else:
#     358                 if timeout > 0:
# --> 359                     gotit = waiter.acquire(True, timeout)
#     360                 else:
#     361                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
import requests
from bs4 import BeautifulSoup
import xarray as xr
import fsspec
import pandas as pd
import numpy as np
import os
from concurrent.futures import ThreadPoolExecutor, as_completed

# -----------------------
# Config
# -----------------------
BASE_URL = "https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/"
YEARS = range(2022, 2026)
MONTHS = [f"{m:02d}" for m in range(1, 13)]
OUT_DIR = "argo_2022_2025_parquet"
os.makedirs(OUT_DIR, exist_ok=True)

# -----------------------
# Function: process 1 file
# -----------------------
def process_argo_file(file_url: str) -> pd.DataFrame:
    """Download, flatten, and clean one Argo .nc file into a DataFrame"""
    with fsspec.open(file_url) as f:
        ds = xr.open_dataset(f, engine="scipy")

    # Infer dims (N_PROF, N_LEVELS)
    prof_dim = next((d for d in ds.dims if "N_PROF" in d), None)
    level_dim = next((d for d in ds.dims if "N_LEVEL" in d or "N_LEVELS" in d), None)

    # Flatten into DataFrame
    if prof_dim and level_dim:
        df = ds.stack(obs=[prof_dim, level_dim]).to_dataframe().reset_index()
    elif prof_dim:
        df = ds.stack(obs=[prof_dim]).to_dataframe().reset_index()
    else:
        df = ds.to_dataframe().reset_index()

    # Basic cleaning
    df.dropna(axis=1, how="all", inplace=True)  # drop fully empty columns
    thresh = int(0.1 * len(df))                 # drop cols >90% NaN
    df.dropna(axis=1, thresh=thresh, inplace=True)

    # Fill numeric NaNs with mean
    for col in df.select_dtypes(include=[np.number]).columns:
        if df[col].isna().any():
            df[col].fillna(df[col].mean(), inplace=True)

    df["source_file"] = file_url
    return df

# -----------------------
# Main loop (parallelized)
# -----------------------
for year in YEARS:
    print(f"\n📂 Processing year: {year}")
    for month in MONTHS:
        dir_url = f"{BASE_URL}{year}/{month}/"

        # Fetch directory listing
        try:
            resp = requests.get(dir_url, timeout=10)
            if resp.status_code != 200:
                continue
        except:
            continue

        soup = BeautifulSoup(resp.text, "html.parser")
        files = [a['href'] for a in soup.find_all('a') if a['href'].endswith(".nc")]
        if not files:
            continue

        month_data = []
        # 🔹 Process files in parallel
        with ThreadPoolExecutor(max_workers=8) as executor:  # adjust workers depending on Colab runtime
            future_to_file = {executor.submit(process_argo_file, dir_url + file): file for file in files}

            for future in as_completed(future_to_file):
                file = future_to_file[future]
                try:
                    df = future.result()
                    month_data.append(df)
                    print(f"  ✅ Done: {file}")
                except Exception as e:
                    print(f"    ⚠ Skipped {file}: {e}")

        # Save monthly parquet
        if month_data:
            final_df = pd.concat(month_data, ignore_index=True)
            out_file = f"{OUT_DIR}/{year}_{month}_ALL_PARAMS.parquet"
            final_df.to_parquet(out_file, index=False)
            print(f"✅ Saved Parquet: {out_file} | Shape: {final_df.shape}")

print("\n🎉 Processing complete! One Parquet per month with all detected parameters.")
# Out:
# 📂 Processing year: 2022
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220103_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220108_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220102_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220106_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220104_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220105_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220110_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220109_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
# /usr/local/lib/python3.12/dist-packages/xarray/coding/times.py:650: RuntimeWarning: invalid value encountered in cast
#   flat_num = flat_num.astype(np.int64)
#     ⚠ Skipped 20220112_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220113_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220114_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220115_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220116_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220118_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220120_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220119_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220122_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220123_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220124_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220126_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220125_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220128_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220129_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220130_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220111_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220101_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220107_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220121_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
#     ⚠ Skipped 20220117_prof.nc: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# ...
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# /tmp/ipython-input-504543416.py:25: FutureWarning: In a future version, xarray will not decode the variable 'MTIME_ADJUSTED_ERROR' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset(f, engine="scipy")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-504543416.py in <cell line: 0>()
#      76             future_to_file = {executor.submit(process_argo_file, dir_url + file): file for file in files}
#      77
# ---> 78             for future in as_completed(future_to_file):
#      79                 file = future_to_file[future]
#      80                 try:
#
# /usr/lib/python3.12/concurrent/futures/_base.py in as_completed(fs, timeout)
#     241                             len(pending), total_futures))
#     242
# --> 243             waiter.event.wait(wait_timeout)
#     244
#     245             with waiter.lock:
#
# /usr/lib/python3.12/threading.py in wait(self, timeout)
#     653             signaled = self._flag
#     654             if not signaled:
# --> 655                 signaled = self._cond.wait(timeout)
#     656             return signaled
#     657
#
# /usr/lib/python3.12/threading.py in wait(self, timeout)
#     353         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354             if timeout is None:
# --> 355                 waiter.acquire()
#     356                 gotit = True
#     357             else:
#
# KeyboardInterrupt:

# %%
import requests
from bs4 import BeautifulSoup
import xarray as xr
import fsspec
import pandas as pd
import numpy as np
import os
import traceback
from concurrent.futures import ThreadPoolExecutor, as_completed

# -----------------------
# Config
# -----------------------
BASE_URL = "https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/"
YEARS = range(2022, 2026)
MONTHS = [f"{m:02d}" for m in range(1, 13)]
OUT_DIR = "argo_2022_2025_parquet"
os.makedirs(OUT_DIR, exist_ok=True)

# Speed / concurrency
USE_PARALLEL = True        # set False to process sequentially (exact original behaviour)
MAX_WORKERS = 6            # threads for downloading/processing (adjust to suit environment)

# -----------------------
# Helper: process 1 file
# -----------------------
def process_argo_file(file_url: str) -> pd.DataFrame:
    """
    Download, flatten, and clean one Argo .nc file into a DataFrame.
    Preserves all variables found; adds 'source_file'.
    """
    with fsspec.open(file_url) as f:
        # Avoid MTIME timedelta decode warnings by setting decode_timedelta=False
        ds = xr.open_dataset(f, engine="scipy", decode_timedelta=False)

    # Infer dims: try to find N_PROF and N_LEVEL(S)
    prof_dim = next((d for d in ds.dims if "N_PROF" in d or d.upper().startswith("N_PROF")), None)
    level_dim = next((d for d in ds.dims if "N_LEVEL" in d or "N_LEVELS" in d or d.upper().startswith("N_LEVEL")), None)

    # Flatten into DataFrame safely
    if prof_dim and level_dim and (ds[prof_dim].size > 0 and ds.dims.get(level_dim, 0) > 0):
        stacked = ds.stack(obs=(prof_dim, level_dim))
        df = stacked.to_dataframe().reset_index()
    elif prof_dim:
        stacked = ds.stack(obs=(prof_dim,))
        df = stacked.to_dataframe().reset_index()
    else:
        df = ds.to_dataframe().reset_index()

    # Basic cleaning (preserve behavior)
    df.dropna(axis=1, how="all", inplace=True)  # drop fully empty columns
    thresh = int(0.1 * len(df))                 # drop cols with >90% NaN
    if thresh > 0:
        df.dropna(axis=1, thresh=thresh, inplace=True)

    # Fill numeric NaNs with mean (same behavior as before)
    for col in df.select_dtypes(include=[np.number]).columns:
        if df[col].isna().any():
            # if column all NaN, mean() gives nan -> leave as-is
            m = df[col].mean()
            if not np.isnan(m):
                df[col].fillna(m, inplace=True)

    df["source_file"] = os.path.basename(file_url)
    return df

# -----------------------
# Helper: summarization
# -----------------------
def summarize_month(df: pd.DataFrame) -> pd.DataFrame:
    """
    Create a compact summary DataFrame for the month:
    - overall mean TEMP/PSAL (if available)
    - stats by depth bins (surface 0-10m, mid 10-200m, deep >200m) using PRES or PRES_ADJUSTED
    - top source files by observation counts
    Returns a tidy DataFrame for saving; also printed diagnostics.
    """
    # copy to avoid modifying original
    s = df.copy()

    # derive DEPTH (use PRES_ADJUSTED then PRES)
    depth_col = None
    if "PRES_ADJUSTED" in s.columns:
        depth_col = "PRES_ADJUSTED"
    elif "PRES" in s.columns:
        depth_col = "PRES"

    # convert to numeric if possible
    if depth_col is not None:
        s[depth_col] = pd.to_numeric(s[depth_col], errors="coerce")

    # simple overall metrics
    metrics = []
    overall = {"metric": "overall", "n_obs": len(s)}
    if "TEMP" in s.columns:
        overall["temp_mean"] = float(s["TEMP"].mean()) if s["TEMP"].notna().any() else np.nan
        overall["temp_std"] = float(s["TEMP"].std()) if s["TEMP"].notna().any() else np.nan
    if "PSAL" in s.columns:
        overall["psal_mean"] = float(s["PSAL"].mean()) if s["PSAL"].notna().any() else np.nan
        overall["psal_std"] = float(s["PSAL"].std()) if s["PSAL"].notna().any() else np.nan
    metrics.append(overall)

    # depth bins
    if depth_col is not None:
        bins = [-1e9, 10, 200, 1e9]
        labels = ["surface_0_10m", "mid_10_200m", "deep_200m_plus"]
        s["depth_bin"] = pd.cut(s[depth_col], bins=bins, labels=labels)
        depth_stats = []
        for lbl in labels:
            sub = s[s["depth_bin"] == lbl]
            rec = {"metric": f"depth_bin::{lbl}", "n_obs": int(len(sub))}
            if "TEMP" in sub.columns and len(sub) > 0 and sub["TEMP"].notna().any():
                rec["temp_mean"] = float(sub["TEMP"].mean())
                rec["temp_std"] = float(sub["TEMP"].std())
            else:
                rec["temp_mean"], rec["temp_std"] = np.nan, np.nan
            if "PSAL" in sub.columns and len(sub) > 0 and sub["PSAL"].notna().any():
                rec["psal_mean"] = float(sub["PSAL"].mean())
                rec["psal_std"] = float(sub["PSAL"].std())
            else:
                rec["psal_mean"], rec["psal_std"] = np.nan, np.nan
            depth_stats.append(rec)
        metrics.extend(depth_stats)

    # top source files by count (helpful to see contributing floats)
    top_sources = (
        s["source_file"].value_counts().reset_index().rename(columns={"index": "source_file", "source_file": "n_obs"})
    )
    top10 = top_sources.head(10)
    # flatten top10 into metrics as separate rows
    for _, row in top10.iterrows():
        metrics.append({"metric": f"top_source::{row['source_file']}", "n_obs": int(row["n_obs"])})

    # turn into DataFrame
    summary_df = pd.DataFrame(metrics)
    # include some columns from the original if present (mean lat/lon for the month)
    if "LATITUDE" in s.columns:
        try:
            summary_df["lat_mean"] = float(s["LATITUDE"].mean())
        except Exception:
            summary_df["lat_mean"] = np.nan
    if "LONGITUDE" in s.columns:
        try:
            summary_df["lon_mean"] = float(s["LONGITUDE"].mean())
        except Exception:
            summary_df["lon_mean"] = np.nan

    return summary_df

# -----------------------
# Main loop (keeps all functionality)
# -----------------------
for year in YEARS:
    print(f"\n📂 Processing year: {year}")
    for month in MONTHS:
        dir_url = f"{BASE_URL}{year}/{month}/"

        # Fetch directory listing
        try:
            resp = requests.get(dir_url, timeout=10)
            if resp.status_code != 200:
                print(f"  (no listing or status {resp.status_code}): {dir_url}")
                continue
        except Exception as e:
            print(f"  (request error for {dir_url}): {e}")
            continue

        soup = BeautifulSoup(resp.text, "html.parser")
        files = [a['href'] for a in soup.find_all('a') if a.get('href', "").endswith(".nc")]
        if not files:
            # no .nc files for that month
            continue

        month_data = []

        # Option A: parallel
        if USE_PARALLEL:
            print(f"  ⚡ Processing {len(files)} files in parallel (max_workers={MAX_WORKERS})")
            with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
                future_to_file = {executor.submit(process_argo_file, dir_url + file): file for file in files}
                for future in as_completed(future_to_file):
                    file = future_to_file[future]
                    try:
                        df = future.result()
                        month_data.append(df)
                        print(f"    ✅ Done: {file} | rows: {len(df)}")
                    except Exception:
                        print(f"    ⚠ Skipped {file} due to error:")
                        traceback.print_exc()
        else:
            # Option B: sequential (original behavior)
            for file in files:
                file_url = dir_url + file
                print(f"  🔹 Reading: {file_url}")
                try:
                    df = process_argo_file(file_url)
                    month_data.append(df)
                    print(f"    ✅ Done: {file} | rows: {len(df)}")
                except Exception:
                    print(f"    ⚠ Skipped {file} due to error:")
                    traceback.print_exc()

        # Save monthly parquet (raw merged)
        if month_data:
            final_df = pd.concat(month_data, ignore_index=True)
            out_file = f"{OUT_DIR}/{year}_{month}_ALL_PARAMS.parquet"
            final_df.to_parquet(out_file, index=False)
            print(f"  ✅ Saved Parquet: {out_file} | Shape: {final_df.shape}")

            # --- Summarization step (lightweight) ---
            try:
                summary_df = summarize_month(final_df)
                out_summary = f"{OUT_DIR}/{year}_{month}_SUMMARY.parquet"
                summary_df.to_parquet(out_summary, index=False)
                print(f"  🔎 Saved SUMMARY: {out_summary} | rows: {len(summary_df)}")
            except Exception:
                print("  ⚠ Failed to create/save summary:")
                traceback.print_exc()

print("\n🎉 Processing complete! One Parquet (ALL_PARAMS) + one SUMMARY per month saved when data exists.")
# Out:
# 📂 Processing year: 2022
#   ⚡ Processing 31 files in parallel (max_workers=6)
# /tmp/ipython-input-2176132070.py:41: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   if prof_dim and level_dim and (ds[prof_dim].size > 0 and ds.dims.get(level_dim, 0) > 0):
# <frozen _collections_abc>:807: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
# /tmp/ipython-input-2176132070.py:41: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   if prof_dim and level_dim and (ds[prof_dim].size > 0 and ds.dims.get(level_dim, 0) > 0):
# <frozen _collections_abc>:807: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
# /tmp/ipython-input-2176132070.py:41: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   if prof_dim and level_dim and (ds[prof_dim].size > 0 and ds.dims.get(level_dim, 0) > 0):
# <frozen _collections_abc>:807: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
# /tmp/ipython-input-2176132070.py:41: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   if prof_dim and level_dim and (ds[prof_dim].size > 0 and ds.dims.get(level_dim, 0) > 0):
# <frozen _collections_abc>:807: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
# /tmp/ipython-input-2176132070.py:41: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   if prof_dim and level_dim and (ds[prof_dim].size > 0 and ds.dims.get(level_dim, 0) > 0):
# <frozen _collections_abc>:807: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#     ⚠ Skipped 20220103_prof.nc due to error:
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2176132070.py", line 184, in <cell line: 0>
#     df = future.result()
#          ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-2176132070.py", line 42, in process_argo_file
#     stacked = ds.stack(obs=(prof_dim, level_dim))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5275, in stack
#     result = result._stack_once(dims, new_dim, index_cls, create_index)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5190, in _stack_once
#     stacked_var = exp_var.stack(**{new_dim: dims})
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1547, in stack
#     result = result._stack_once(dims, new_dim)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1510, in _stack_once
#     new_data = duck_array_ops.reshape(reordered.data, new_shape)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/duck_array_ops.py", line 454, in reshape
#     return xp.reshape(array, shape)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 299, in reshape
#     return _wrapfunc(a, 'reshape', newshape, order=order)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2176132070.py", line 184, in <cell line: 0>
#     df = future.result()
#          ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-2176132070.py", line 42, in process_argo_file
#     stacked = ds.stack(obs=(prof_dim, level_dim))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5275, in stack
#     result = result._stack_once(dims, new_dim, index_cls, create_index)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5190, in _stack_once
#     stacked_var = exp_var.stack(**{new_dim: dims})
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1547, in stack
#     result = result._stack_once(dims, new_dim)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1510, in _stack_once
#     new_data = duck_array_ops.reshape(reordered.data, new_shape)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/duck_array_ops.py", line 454, in reshape
#     return xp.reshape(array, shape)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 299, in reshape
#     return _wrapfunc(a, 'reshape', newshape, order=order)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2176132070.py", line 184, in <cell line: 0>
#     df = future.result()
#          ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-2176132070.py", line 42, in process_argo_file
#     stacked = ds.stack(obs=(prof_dim, level_dim))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5275, in stack
#     result = result._stack_once(dims, new_dim, index_cls, create_index)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5190, in _stack_once
#     stacked_var = exp_var.stack(**{new_dim: dims})
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1547, in stack
#     result = result._stack_once(dims, new_dim)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1510, in _stack_once
#     new_data = duck_array_ops.reshape(reordered.data, new_shape)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/duck_array_ops.py", line 454, in reshape
#     return xp.reshape(array, shape)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 299, in reshape
#     return _wrapfunc(a, 'reshape', newshape, order=order)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2176132070.py", line 184, in <cell line: 0>
#     df = future.result()
#          ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-2176132070.py", line 42, in process_argo_file
#     stacked = ds.stack(obs=(prof_dim, level_dim))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5275, in stack
#     result = result._stack_once(dims, new_dim, index_cls, create_index)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5190, in _stack_once
#     stacked_var = exp_var.stack(**{new_dim: dims})
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1547, in stack
#     result = result._stack_once(dims, new_dim)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1510, in _stack_once
#     new_data = duck_array_ops.reshape(reordered.data, new_shape)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/duck_array_ops.py", line 454, in reshape
#     return xp.reshape(array, shape)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 299, in reshape
#     return _wrapfunc(a, 'reshape', newshape, order=order)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2176132070.py", line 184, in <cell line: 0>
#     df = future.result()
#          ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-2176132070.py", line 42, in process_argo_file
#     stacked = ds.stack(obs=(prof_dim, level_dim))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5275, in stack
#     result = result._stack_once(dims, new_dim, index_cls, create_index)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5190, in _stack_once
#     stacked_var = exp_var.stack(**{new_dim: dims})
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1547, in stack
#     result = result._stack_once(dims, new_dim)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1510, in _stack_once
#     new_data = duck_array_ops.reshape(reordered.data, new_shape)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/duck_array_ops.py", line 454, in reshape
#     return xp.reshape(array, shape)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 299, in reshape
#     return _wrapfunc(a, 'reshape', newshape, order=order)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220102_prof.nc due to error:
#     ⚠ Skipped 20220105_prof.nc due to error:
#     ⚠ Skipped 20220106_prof.nc due to error:
#     ⚠ Skipped 20220104_prof.nc due to error:
# /tmp/ipython-input-2176132070.py:41: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   if prof_dim and level_dim and (ds[prof_dim].size > 0 and ds.dims.get(level_dim, 0) > 0):
# <frozen _collections_abc>:807: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
# /tmp/ipython-input-2176132070.py:41: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   if prof_dim and level_dim and (ds[prof_dim].size > 0 and ds.dims.get(level_dim, 0) > 0):
# <frozen _collections_abc>:807: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#     ⚠ Skipped 20220110_prof.nc due to error:
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2176132070.py", line 184, in <cell line: 0>
#     df = future.result()
#          ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-2176132070.py", line 42, in process_argo_file
#     stacked = ds.stack(obs=(prof_dim, level_dim))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5275, in stack
#     result = result._stack_once(dims, new_dim, index_cls, create_index)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5190, in _stack_once
#     stacked_var = exp_var.stack(**{new_dim: dims})
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1547, in stack
#     result = result._stack_once(dims, new_dim)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1510, in _stack_once
#     new_data = duck_array_ops.reshape(reordered.data, new_shape)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/duck_array_ops.py", line 454, in reshape
#     return xp.reshape(array, shape)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 299, in reshape
#     return _wrapfunc(a, 'reshape', newshape, order=order)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220108_prof.nc due to error:
#     ⚠ Skipped 20220109_prof.nc due to error:
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2176132070.py", line 184, in <cell line: 0>
#     df = future.result()
#          ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-2176132070.py", line 42, in process_argo_file
#     stacked = ds.stack(obs=(prof_dim, level_dim))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5275, in stack
#     result = result._stack_once(dims, new_dim, index_cls, create_index)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5190, in _stack_once
#     stacked_var = exp_var.stack(**{new_dim: dims})
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1547, in stack
#     result = result._stack_once(dims, new_dim)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1510, in _stack_once
#     new_data = duck_array_ops.reshape(reordered.data, new_shape)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/duck_array_ops.py", line 454, in reshape
#     return xp.reshape(array, shape)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 299, in reshape
#     return _wrapfunc(a, 'reshape', newshape, order=order)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2176132070.py", line 184, in <cell line: 0>
#     df = future.result()
#          ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-2176132070.py", line 42, in process_argo_file
#     stacked = ds.stack(obs=(prof_dim, level_dim))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5275, in stack
#     result = result._stack_once(dims, new_dim, index_cls, create_index)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5190, in _stack_once
#     stacked_var = exp_var.stack(**{new_dim: dims})
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1547, in stack
#     result = result._stack_once(dims, new_dim)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1510, in _stack_once
#     new_data = duck_array_ops.reshape(reordered.data, new_shape)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/duck_array_ops.py", line 454, in reshape
#     return xp.reshape(array, shape)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 299, in reshape
#     return _wrapfunc(a, 'reshape', newshape, order=order)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-2176132070.py:41: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   if prof_dim and level_dim and (ds[prof_dim].size > 0 and ds.dims.get(level_dim, 0) > 0):
# <frozen _collections_abc>:807: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
# /tmp/ipython-input-2176132070.py:41: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   if prof_dim and level_dim and (ds[prof_dim].size > 0 and ds.dims.get(level_dim, 0) > 0):
# <frozen _collections_abc>:807: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2176132070.py", line 184, in <cell line: 0>
#     df = future.result()
#          ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-2176132070.py", line 42, in process_argo_file
#     stacked = ds.stack(obs=(prof_dim, level_dim))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5275, in stack
#     result = result._stack_once(dims, new_dim, index_cls, create_index)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5190, in _stack_once
#     stacked_var = exp_var.stack(**{new_dim: dims})
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1547, in stack
#     result = result._stack_once(dims, new_dim)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1510, in _stack_once
#     new_data = duck_array_ops.reshape(reordered.data, new_shape)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/duck_array_ops.py", line 454, in reshape
#     return xp.reshape(array, shape)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 299, in reshape
#     return _wrapfunc(a, 'reshape', newshape, order=order)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-2176132070.py:41: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   if prof_dim and level_dim and (ds[prof_dim].size > 0 and ds.dims.get(level_dim, 0) > 0):
# <frozen _collections_abc>:807: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#     ⚠ Skipped 20220112_prof.nc due to error:
#     ⚠ Skipped 20220113_prof.nc due to error:
#     ⚠ Skipped 20220114_prof.nc due to error:
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2176132070.py", line 184, in <cell line: 0>
#     df = future.result()
#          ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-2176132070.py", line 42, in process_argo_file
#     stacked = ds.stack(obs=(prof_dim, level_dim))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5275, in stack
#     result = result._stack_once(dims, new_dim, index_cls, create_index)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5190, in _stack_once
#     stacked_var = exp_var.stack(**{new_dim: dims})
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1547, in stack
#     result = result._stack_once(dims, new_dim)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1510, in _stack_once
#     new_data = duck_array_ops.reshape(reordered.data, new_shape)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/duck_array_ops.py", line 454, in reshape
#     return xp.reshape(array, shape)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 299, in reshape
#     return _wrapfunc(a, 'reshape', newshape, order=order)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2176132070.py", line 184, in <cell line: 0>
#     df = future.result()
#          ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-2176132070.py", line 42, in process_argo_file
#     stacked = ds.stack(obs=(prof_dim, level_dim))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5275, in stack
#     result = result._stack_once(dims, new_dim, index_cls, create_index)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5190, in _stack_once
#     stacked_var = exp_var.stack(**{new_dim: dims})
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1547, in stack
#     result = result._stack_once(dims, new_dim)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1510, in _stack_once
#     new_data = duck_array_ops.reshape(reordered.data, new_shape)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/duck_array_ops.py", line 454, in reshape
#     return xp.reshape(array, shape)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 299, in reshape
#     return _wrapfunc(a, 'reshape', newshape, order=order)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-2176132070.py:41: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   if prof_dim and level_dim and (ds[prof_dim].size > 0 and ds.dims.get(level_dim, 0) > 0):
# <frozen _collections_abc>:807: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#     ⚠ Skipped 20220115_prof.nc due to error:
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2176132070.py", line 184, in <cell line: 0>
#     df = future.result()
#          ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-2176132070.py", line 42, in process_argo_file
#     stacked = ds.stack(obs=(prof_dim, level_dim))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5275, in stack
#     result = result._stack_once(dims, new_dim, index_cls, create_index)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5190, in _stack_once
#     stacked_var = exp_var.stack(**{new_dim: dims})
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1547, in stack
#     result = result._stack_once(dims, new_dim)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1510, in _stack_once
#     new_data = duck_array_ops.reshape(reordered.data, new_shape)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/duck_array_ops.py", line 454, in reshape
#     return xp.reshape(array, shape)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 299, in reshape
#     return _wrapfunc(a, 'reshape', newshape, order=order)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-2176132070.py:41: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   if prof_dim and level_dim and (ds[prof_dim].size > 0 and ds.dims.get(level_dim, 0) > 0):
# <frozen _collections_abc>:807: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#     ⚠ Skipped 20220116_prof.nc due to error:
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2176132070.py", line 184, in <cell line: 0>
#     df = future.result()
#          ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-2176132070.py", line 42, in process_argo_file
#     stacked = ds.stack(obs=(prof_dim, level_dim))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5275, in stack
#     result = result._stack_once(dims, new_dim, index_cls, create_index)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5190, in _stack_once
#     stacked_var = exp_var.stack(**{new_dim: dims})
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1547, in stack
#     result = result._stack_once(dims, new_dim)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1510, in _stack_once
#     new_data = duck_array_ops.reshape(reordered.data, new_shape)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/duck_array_ops.py", line 454, in reshape
#     return xp.reshape(array, shape)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 299, in reshape
#     return _wrapfunc(a, 'reshape', newshape, order=order)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-2176132070.py:41: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   if prof_dim and level_dim and (ds[prof_dim].size > 0 and ds.dims.get(level_dim, 0) > 0):
# <frozen _collections_abc>:807: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#     ⚠ Skipped 20220118_prof.nc due to error:
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2176132070.py", line 184, in <cell line: 0>
#     df = future.result()
#          ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-2176132070.py", line 42, in process_argo_file
#     stacked = ds.stack(obs=(prof_dim, level_dim))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5275, in stack
#     result = result._stack_once(dims, new_dim, index_cls, create_index)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5190, in _stack_once
#     stacked_var = exp_var.stack(**{new_dim: dims})
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1547, in stack
#     result = result._stack_once(dims, new_dim)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1510, in _stack_once
#     new_data = duck_array_ops.reshape(reordered.data, new_shape)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/duck_array_ops.py", line 454, in reshape
#     return xp.reshape(array, shape)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 299, in reshape
#     return _wrapfunc(a, 'reshape', newshape, order=order)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-2176132070.py:41: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   if prof_dim and level_dim and (ds[prof_dim].size > 0 and ds.dims.get(level_dim, 0) > 0):
# <frozen _collections_abc>:807: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
# /tmp/ipython-input-2176132070.py:41: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   if prof_dim and level_dim and (ds[prof_dim].size > 0 and ds.dims.get(level_dim, 0) > 0):
# <frozen _collections_abc>:807: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#     ⚠ Skipped 20220120_prof.nc due to error:
#     ⚠ Skipped 20220119_prof.nc due to error:
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2176132070.py", line 184, in <cell line: 0>
#     df = future.result()
#          ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-2176132070.py", line 42, in process_argo_file
#     stacked = ds.stack(obs=(prof_dim, level_dim))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5275, in stack
#     result = result._stack_once(dims, new_dim, index_cls, create_index)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5190, in _stack_once
#     stacked_var = exp_var.stack(**{new_dim: dims})
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
# ...
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-2176132070.py", line 42, in process_argo_file
#     stacked = ds.stack(obs=(prof_dim, level_dim))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5275, in stack
#     result = result._stack_once(dims, new_dim, index_cls, create_index)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5190, in _stack_once
#     stacked_var = exp_var.stack(**{new_dim: dims})
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1547, in stack
#     result = result._stack_once(dims, new_dim)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1510, in _stack_once
#     new_data = duck_array_ops.reshape(reordered.data, new_shape)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/duck_array_ops.py", line 454, in reshape
#     return xp.reshape(array, shape)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 299, in reshape
#     return _wrapfunc(a, 'reshape', newshape, order=order)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-2176132070.py:41: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   if prof_dim and level_dim and (ds[prof_dim].size > 0 and ds.dims.get(level_dim, 0) > 0):
# <frozen _collections_abc>:807: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#     ⚠ Skipped 20221229_prof.nc due to error:
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2176132070.py", line 184, in <cell line: 0>
#     df = future.result()
#          ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-2176132070.py", line 42, in process_argo_file
#     stacked = ds.stack(obs=(prof_dim, level_dim))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5275, in stack
#     result = result._stack_once(dims, new_dim, index_cls, create_index)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5190, in _stack_once
#     stacked_var = exp_var.stack(**{new_dim: dims})
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1547, in stack
#     result = result._stack_once(dims, new_dim)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1510, in _stack_once
#     new_data = duck_array_ops.reshape(reordered.data, new_shape)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/duck_array_ops.py", line 454, in reshape
#     return xp.reshape(array, shape)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 299, in reshape
#     return _wrapfunc(a, 'reshape', newshape, order=order)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-2176132070.py:41: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   if prof_dim and level_dim and (ds[prof_dim].size > 0 and ds.dims.get(level_dim, 0) > 0):
# <frozen _collections_abc>:807: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2176132070.py", line 184, in <cell line: 0>
#     df = future.result()
#          ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-2176132070.py", line 42, in process_argo_file
#     stacked = ds.stack(obs=(prof_dim, level_dim))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5275, in stack
#     result = result._stack_once(dims, new_dim, index_cls, create_index)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5190, in _stack_once
#     stacked_var = exp_var.stack(**{new_dim: dims})
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1547, in stack
#     result = result._stack_once(dims, new_dim)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1510, in _stack_once
#     new_data = duck_array_ops.reshape(reordered.data, new_shape)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/duck_array_ops.py", line 454, in reshape
#     return xp.reshape(array, shape)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 299, in reshape
#     return _wrapfunc(a, 'reshape', newshape, order=order)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221230_prof.nc due to error:
# /tmp/ipython-input-2176132070.py:41: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   if prof_dim and level_dim and (ds[prof_dim].size > 0 and ds.dims.get(level_dim, 0) > 0):
# <frozen _collections_abc>:807: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#     ⚠ Skipped 20221223_prof.nc due to error:
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2176132070.py", line 184, in <cell line: 0>
#     df = future.result()
#          ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-2176132070.py", line 42, in process_argo_file
#     stacked = ds.stack(obs=(prof_dim, level_dim))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5275, in stack
#     result = result._stack_once(dims, new_dim, index_cls, create_index)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5190, in _stack_once
#     stacked_var = exp_var.stack(**{new_dim: dims})
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1547, in stack
#     result = result._stack_once(dims, new_dim)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1510, in _stack_once
#     new_data = duck_array_ops.reshape(reordered.data, new_shape)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/duck_array_ops.py", line 454, in reshape
#     return xp.reshape(array, shape)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 299, in reshape
#     return _wrapfunc(a, 'reshape', newshape, order=order)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-2176132070.py:41: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   if prof_dim and level_dim and (ds[prof_dim].size > 0 and ds.dims.get(level_dim, 0) > 0):
# <frozen _collections_abc>:807: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#     ⚠ Skipped 20221224_prof.nc due to error:
# Traceback (most recent call last):
#   File "/tmp/ipython-input-2176132070.py", line 184, in <cell line: 0>
#     df = future.result()
#          ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-2176132070.py", line 42, in process_argo_file
#     stacked = ds.stack(obs=(prof_dim, level_dim))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5275, in stack
#     result = result._stack_once(dims, new_dim, index_cls, create_index)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/dataset.py", line 5190, in _stack_once
#     stacked_var = exp_var.stack(**{new_dim: dims})
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/util/deprecation_helpers.py", line 144, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1547, in stack
#     result = result._stack_once(dims, new_dim)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/variable.py", line 1510, in _stack_once
#     new_data = duck_array_ops.reshape(reordered.data, new_shape)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/xarray/core/duck_array_ops.py", line 454, in reshape
#     return xp.reshape(array, shape)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 299, in reshape
#     return _wrapfunc(a, 'reshape', newshape, order=order)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)
# /tmp/ipython-input-2176132070.py:41: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   if prof_dim and level_dim and (ds[prof_dim].size > 0 and ds.dims.get(level_dim, 0) > 0):
# <frozen _collections_abc>:807: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.

# %%
import requests
from bs4 import BeautifulSoup
import xarray as xr
import fsspec
import pandas as pd
import numpy as np
import os
import traceback
from concurrent.futures import ThreadPoolExecutor, as_completed

# -----------------------
# Config
# -----------------------
BASE_URL = "https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/"
YEARS = range(2022, 2026)
MONTHS = [f"{m:02d}" for m in range(1, 13)]
OUT_DIR = "argo_2022_2025_parquet"
os.makedirs(OUT_DIR, exist_ok=True)

# Speed / concurrency
USE_PARALLEL = True        # set False to process sequentially
MAX_WORKERS = 6            # threads for downloading/processing

# -----------------------
# Helper: process 1 file
# -----------------------
def process_argo_file(file_url: str) -> pd.DataFrame:
    try:
        with fsspec.open(file_url) as f:
            ds = xr.open_dataset(f, engine="scipy", decode_timedelta=False)

        # Identify dimensions
        prof_dim = next((d for d in ds.dims if "N_PROF" in d or d.upper().startswith("N_PROF")), None)
        level_dim = next((d for d in ds.dims if "N_LEVEL" in d or "N_LEVELS" in d or d.upper().startswith("N_LEVEL")), None)

        # ✅ Guard: skip if any dimension is declared but has zero size
        if (prof_dim and ds.sizes.get(prof_dim, 0) == 0) or (level_dim and ds.sizes.get(level_dim, 0) == 0):
            print(f"⚠ Skipped {file_url}: declared but empty (N_PROF/N_LEVEL = 0)")
            return None

        # Stack safely
        if prof_dim and level_dim:
            stacked = ds.stack(obs=(prof_dim, level_dim))
        elif prof_dim:
            stacked = ds.stack(obs=(prof_dim,))
        else:
            stacked = ds

        df = stacked.to_dataframe().reset_index()

        # Basic cleaning
        df.dropna(axis=1, how="all", inplace=True)
        thresh = int(0.1 * len(df))
        if thresh > 0:
            df.dropna(axis=1, thresh=thresh, inplace=True)

        for col in df.select_dtypes(include=[np.number]).columns:
            if df[col].isna().any():
                m = df[col].mean()
                if not np.isnan(m):
                    df[col].fillna(m, inplace=True)

        df["source_file"] = os.path.basename(file_url)
        return df

    except Exception as e:
        print(f"⚠ Skipped {file_url} due to error: {e}")
        return None

# -----------------------
# Helper: summarization
# -----------------------
def summarize_month(df: pd.DataFrame) -> pd.DataFrame:
    s = df.copy()

    depth_col = None
    if "PRES_ADJUSTED" in s.columns:
        depth_col = "PRES_ADJUSTED"
    elif "PRES" in s.columns:
        depth_col = "PRES"

    if depth_col is not None:
        s[depth_col] = pd.to_numeric(s[depth_col], errors="coerce")

    metrics = []
    overall = {"metric": "overall", "n_obs": len(s)}
    if "TEMP" in s.columns:
        overall["temp_mean"] = float(s["TEMP"].mean()) if s["TEMP"].notna().any() else np.nan
        overall["temp_std"] = float(s["TEMP"].std()) if s["TEMP"].notna().any() else np.nan
    if "PSAL" in s.columns:
        overall["psal_mean"] = float(s["PSAL"].mean()) if s["PSAL"].notna().any() else np.nan
        overall["psal_std"] = float(s["PSAL"].std()) if s["PSAL"].notna().any() else np.nan
    metrics.append(overall)

    if depth_col is not None:
        bins = [-1e9, 10, 200, 1e9]
        labels = ["surface_0_10m", "mid_10_200m", "deep_200m_plus"]
        s["depth_bin"] = pd.cut(s[depth_col], bins=bins, labels=labels)
        for lbl in labels:
            sub = s[s["depth_bin"] == lbl]
            rec = {"metric": f"depth_bin::{lbl}", "n_obs": int(len(sub))}
            if "TEMP" in sub.columns and len(sub) > 0 and sub["TEMP"].notna().any():
                rec["temp_mean"] = float(sub["TEMP"].mean())
                rec["temp_std"] = float(sub["TEMP"].std())
            else:
                rec["temp_mean"], rec["temp_std"] = np.nan, np.nan
            if "PSAL" in sub.columns and len(sub) > 0 and sub["PSAL"].notna().any():
                rec["psal_mean"] = float(sub["PSAL"].mean())
                rec["psal_std"] = float(sub["PSAL"].std())
            else:
                rec["psal_mean"], rec["psal_std"] = np.nan, np.nan
            metrics.append(rec)

    top_sources = (
        s["source_file"].value_counts().reset_index().rename(columns={"index": "source_file", "source_file": "n_obs"})
    )
    for _, row in top_sources.head(10).iterrows():
        metrics.append({"metric": f"top_source::{row['source_file']}", "n_obs": int(row["n_obs"])})

    summary_df = pd.DataFrame(metrics)
    if "LATITUDE" in s.columns:
        summary_df["lat_mean"] = float(s["LATITUDE"].mean())
    if "LONGITUDE" in s.columns:
        summary_df["lon_mean"] = float(s["LONGITUDE"].mean())

    return summary_df

# -----------------------
# Main loop
# -----------------------
for year in YEARS:
    print(f"\n📂 Processing year: {year}")
    for month in MONTHS:
        dir_url = f"{BASE_URL}{year}/{month}/"
        try:
            resp = requests.get(dir_url, timeout=10)
            if resp.status_code != 200:
                print(f"  (no listing or status {resp.status_code}): {dir_url}")
                continue
        except Exception as e:
            print(f"  (request error for {dir_url}): {e}")
            continue

        soup = BeautifulSoup(resp.text, "html.parser")
        files = [a['href'] for a in soup.find_all('a') if a.get('href', "").endswith(".nc")]
        if not files:
            continue

        month_data = []

        if USE_PARALLEL:
            print(f"  ⚡ Processing {len(files)} files in parallel (max_workers={MAX_WORKERS})")
            with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
                future_to_file = {executor.submit(process_argo_file, dir_url + file): file for file in files}
                for future in as_completed(future_to_file):
                    file = future_to_file[future]
                    try:
                        df = future.result()
                        if df is not None and not df.empty:
                            month_data.append(df)
                            print(f"    ✅ Done: {file} | rows: {len(df)}")
                        else:
                            print(f"    ⚠ Skipped {file}: empty result")
                    except Exception:
                        print(f"    ⚠ Skipped {file} due to error:")
                        traceback.print_exc()
        else:
            for file in files:
                file_url = dir_url + file
                print(f"  🔹 Reading: {file_url}")
                try:
                    df = process_argo_file(file_url)
                    if df is not None and not df.empty:
                        month_data.append(df)
                        print(f"    ✅ Done: {file} | rows: {len(df)}")
                    else:
                        print(f"    ⚠ Skipped {file}: empty result")
                except Exception:
                    print(f"    ⚠ Skipped {file} due to error:")
                    traceback.print_exc()

        # ✅ Updated block with your logic
        if month_data:
            final_df = pd.concat([df for df in month_data if df is not None], ignore_index=True)
            if not final_df.empty:
                out_file = f"{OUT_DIR}/{year}_{month}_ALL_PARAMS.parquet"
                final_df.to_parquet(out_file, index=False)
                print(f"  ✅ Saved Parquet: {out_file} | Shape: {final_df.shape}")

                try:
                    summary_df = summarize_month(final_df)
                    out_summary = f"{OUT_DIR}/{year}_{month}_SUMMARY.parquet"
                    summary_df.to_parquet(out_summary, index=False)
                    print(f"  🔎 Saved SUMMARY: {out_summary} | rows: {len(summary_df)})")
                except Exception:
                    print("  ⚠ Failed to create/save summary:")
                    traceback.print_exc()
            else:
                print(f"  ⚠ No usable data for {year}-{month}")
        else:
            print(f"  ⚠ All files empty for {year}-{month}")

print("\n🎉 Processing complete! One Parquet (ALL_PARAMS) + one SUMMARY per month saved when data exists.")
# Out:
# 📂 Processing year: 2022
#   ⚡ Processing 31 files in parallel (max_workers=6)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220103_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220103_prof.nc
#     ⚠ Skipped 20220103_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220107_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220107_prof.nc
#     ⚠ Skipped 20220107_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220102_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220102_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220106_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220106_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220104_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220104_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220105_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220105_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220110_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220110_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220108_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220108_prof.nc
#     ⚠ Skipped 20220108_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220109_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220109_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220112_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220112_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220113_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220113_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220114_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220114_prof.nc
#     ⚠ Skipped 20220114_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220115_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220115_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220116_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220116_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220118_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220118_prof.nc
#     ⚠ Skipped 20220118_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220120_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220120_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220119_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220119_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220121_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220121_prof.nc
#     ⚠ Skipped 20220121_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220122_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220122_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220123_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220123_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220124_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220124_prof.nc
#     ⚠ Skipped 20220124_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220126_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220126_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220125_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220125_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220127_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220127_prof.nc
#     ⚠ Skipped 20220127_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220128_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220128_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220130_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220130_prof.nc
#     ⚠ Skipped 20220130_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220129_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220129_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220111_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220111_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220117_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220117_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220101_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220101_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220131_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220131_prof.nc: empty result
#   ⚠ All files empty for 2022-01
#   ⚡ Processing 28 files in parallel (max_workers=6)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220206_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220206_prof.nc
#     ⚠ Skipped 20220206_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220202_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220202_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220207_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220207_prof.nc
#     ⚠ Skipped 20220207_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220205_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220205_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220203_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220203_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220204_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220204_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220209_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220209_prof.nc
#     ⚠ Skipped 20220209_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220208_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220208_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220201_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220201_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220210_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220210_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220212_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220212_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220211_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220211_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220213_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220213_prof.nc
#     ⚠ Skipped 20220213_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220214_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220214_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220217_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220217_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220218_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220218_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220219_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220219_prof.nc
#     ⚠ Skipped 20220219_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220220_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220220_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220221_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220221_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220215_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220215_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220222_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220222_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220223_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220223_prof.nc
#     ⚠ Skipped 20220223_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220224_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220224_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220225_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220225_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220227_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220227_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220228_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220228_prof.nc
#     ⚠ Skipped 20220228_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220216_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220216_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220226_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220226_prof.nc: empty result
#   ⚠ All files empty for 2022-02
#   ⚡ Processing 31 files in parallel (max_workers=6)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220301_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220301_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220307_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220307_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220302_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220302_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220303_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220303_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220305_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220304_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220305_prof.nc: empty result
#     ⚠ Skipped 20220304_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220306_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220306_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220309_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220309_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220310_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220310_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220311_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220311_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220312_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220312_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220314_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220314_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220313_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220313_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220316_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220316_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220315_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220315_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220317_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220317_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220319_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220319_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220320_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220320_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220321_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220321_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220322_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220322_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220323_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220323_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220324_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220324_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220325_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220325_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220326_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220326_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220327_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220327_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220308_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220308_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220318_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220318_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220328_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220328_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220331_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220331_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220329_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220329_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220330_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220330_prof.nc: empty result
#   ⚠ All files empty for 2022-03
#   ⚡ Processing 30 files in parallel (max_workers=6)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220406_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220406_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220403_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220403_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220405_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220405_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220404_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220404_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220401_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220401_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220402_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220402_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220412_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220412_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220413_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220413_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220414_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220414_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220415_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220415_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220407_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220407_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220408_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220408_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220418_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220418_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220419_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220419_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220420_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220420_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220410_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220410_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220409_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220409_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220422_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220422_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220411_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220411_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220423_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220423_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220424_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220424_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220425_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220425_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220426_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220426_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220428_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220428_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220429_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220429_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220430_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220430_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220416_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220416_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220417_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220417_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220427_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220427_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220421_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220421_prof.nc: empty result
#   ⚠ All files empty for 2022-04
#   ⚡ Processing 31 files in parallel (max_workers=6)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220501_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220501_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220502_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220502_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220505_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220505_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220503_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220503_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220504_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220504_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220506_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220506_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220508_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220508_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220510_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220510_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220509_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220509_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220512_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220512_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220511_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220511_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220513_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220513_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220514_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220514_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220515_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220515_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220516_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220516_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220518_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220518_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220520_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220520_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220519_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220519_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220522_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220522_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220524_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220524_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220523_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220523_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220525_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220525_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220526_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220526_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220528_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220528_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220529_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220529_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220530_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220530_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220531_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220531_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220521_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220521_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220507_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220507_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220517_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220517_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220527_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220527_prof.nc: empty result
#   ⚠ All files empty for 2022-05
#   ⚡ Processing 30 files in parallel (max_workers=6)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220601_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220601_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220607_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220607_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220604_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220602_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#
#     ⚠ Skipped 20220602_prof.nc: empty result
#     ⚠ Skipped 20220604_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220605_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220605_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220603_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220603_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220608_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220608_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220611_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220611_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220612_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220609_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220612_prof.nc: empty result
#     ⚠ Skipped 20220609_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220610_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220610_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220613_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220613_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220614_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220614_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220615_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220615_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220618_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220618_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220619_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220619_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220620_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220620_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220621_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220621_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220622_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220622_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220623_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220623_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220624_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220624_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220625_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220625_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220628_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220628_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220627_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220627_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220629_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220629_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220630_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220630_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220617_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220617_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220606_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220606_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220616_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220616_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220626_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220626_prof.nc: empty result
#   ⚠ All files empty for 2022-06
#   ⚡ Processing 31 files in parallel (max_workers=6)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220701_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220701_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220703_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220703_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220705_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220704_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220704_prof.nc: empty result
#     ⚠ Skipped 20220705_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220702_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220702_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220707_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220707_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220708_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220708_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220710_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220710_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220709_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220709_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220711_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220711_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220713_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220713_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220712_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220712_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220714_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220714_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220715_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220715_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220718_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220718_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220719_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220719_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220717_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220717_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220722_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220722_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220721_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220721_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220723_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220723_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220724_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220724_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220725_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220725_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220727_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220727_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220728_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220728_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220729_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220729_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220731_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220731_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220720_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220720_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220706_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220706_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220716_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220716_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220730_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220730_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220726_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220726_prof.nc: empty result
#   ⚠ All files empty for 2022-07
#   ⚡ Processing 31 files in parallel (max_workers=6)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220801_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220801_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220802_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220802_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220803_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220803_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220804_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220804_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220806_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220806_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220808_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220808_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220807_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220807_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220809_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220809_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220810_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220810_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220811_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220811_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220812_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220812_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220814_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220814_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220813_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220813_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220817_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220817_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220818_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220818_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220820_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220820_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220821_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220821_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220822_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220822_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220823_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220823_prof.nc: empty result
# ...
#     ⚠ Skipped 20250705_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250706_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250706_prof.nc
#     ⚠ Skipped 20250706_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250708_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250708_prof.nc
#     ⚠ Skipped 20250708_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250707_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250707_prof.nc
#     ⚠ Skipped 20250707_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250709_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250709_prof.nc
#     ⚠ Skipped 20250709_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250711_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250711_prof.nc
#     ⚠ Skipped 20250711_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250710_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250710_prof.nc
#     ⚠ Skipped 20250710_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250712_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250712_prof.nc
#     ⚠ Skipped 20250712_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250713_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250713_prof.nc
#     ⚠ Skipped 20250713_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250714_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250714_prof.nc
#     ⚠ Skipped 20250714_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250715_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250715_prof.nc
#     ⚠ Skipped 20250715_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250716_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250716_prof.nc
#     ⚠ Skipped 20250716_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250717_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250717_prof.nc
#     ⚠ Skipped 20250717_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250718_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250718_prof.nc
#     ⚠ Skipped 20250718_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250719_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250719_prof.nc
#     ⚠ Skipped 20250719_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250720_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250720_prof.nc
#     ⚠ Skipped 20250720_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250721_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250721_prof.nc
#     ⚠ Skipped 20250721_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250722_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250722_prof.nc
#     ⚠ Skipped 20250722_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250723_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250723_prof.nc
#     ⚠ Skipped 20250723_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250724_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250724_prof.nc
#     ⚠ Skipped 20250724_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250725_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250725_prof.nc
#     ⚠ Skipped 20250725_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250726_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250726_prof.nc
#     ⚠ Skipped 20250726_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250727_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250727_prof.nc
#     ⚠ Skipped 20250727_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250728_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250728_prof.nc
#     ⚠ Skipped 20250728_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250729_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250729_prof.nc
#     ⚠ Skipped 20250729_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250730_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250730_prof.nc
#     ⚠ Skipped 20250730_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250731_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/07/20250731_prof.nc
#     ⚠ Skipped 20250731_prof.nc: empty result
#   ⚠ All files empty for 2025-07
#   ⚡ Processing 31 files in parallel (max_workers=6)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250801_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250801_prof.nc
#     ⚠ Skipped 20250801_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250804_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250804_prof.nc
#     ⚠ Skipped 20250804_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250802_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250802_prof.nc
#     ⚠ Skipped 20250802_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250805_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250805_prof.nc
#     ⚠ Skipped 20250805_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250806_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250806_prof.nc
#     ⚠ Skipped 20250806_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250803_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250803_prof.nc
#     ⚠ Skipped 20250803_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250807_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250807_prof.nc
#     ⚠ Skipped 20250807_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250808_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250808_prof.nc
#     ⚠ Skipped 20250808_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250809_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250809_prof.nc
#     ⚠ Skipped 20250809_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250810_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250810_prof.nc
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250811_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250811_prof.nc
#     ⚠ Skipped 20250810_prof.nc: empty result
#     ⚠ Skipped 20250811_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250812_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250812_prof.nc
#     ⚠ Skipped 20250812_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250813_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250813_prof.nc
#     ⚠ Skipped 20250813_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250814_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250814_prof.nc
#     ⚠ Skipped 20250814_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250815_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250815_prof.nc
#     ⚠ Skipped 20250815_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250816_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250816_prof.nc
#     ⚠ Skipped 20250816_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250818_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250818_prof.nc
#     ⚠ Skipped 20250818_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250817_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250817_prof.nc
#     ⚠ Skipped 20250817_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250819_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250819_prof.nc
#     ⚠ Skipped 20250819_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250820_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250820_prof.nc
#     ⚠ Skipped 20250820_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250821_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250821_prof.nc
#     ⚠ Skipped 20250821_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250822_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250822_prof.nc
#     ⚠ Skipped 20250822_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250823_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250823_prof.nc
#     ⚠ Skipped 20250823_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250824_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250824_prof.nc
#     ⚠ Skipped 20250824_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250825_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250825_prof.nc
#     ⚠ Skipped 20250825_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250826_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250826_prof.nc
#     ⚠ Skipped 20250826_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250827_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250827_prof.nc
#     ⚠ Skipped 20250827_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250828_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250828_prof.nc
#     ⚠ Skipped 20250828_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250829_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250829_prof.nc
#     ⚠ Skipped 20250829_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250830_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250830_prof.nc
#     ⚠ Skipped 20250830_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250831_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/08/20250831_prof.nc
#     ⚠ Skipped 20250831_prof.nc: empty result
#   ⚠ All files empty for 2025-08
#   ⚡ Processing 10 files in parallel (max_workers=6)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/09/20250901_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/09/20250901_prof.nc
#     ⚠ Skipped 20250901_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/09/20250902_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/09/20250902_prof.nc
#     ⚠ Skipped 20250902_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/09/20250904_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/09/20250904_prof.nc
#     ⚠ Skipped 20250904_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/09/20250903_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/09/20250903_prof.nc
#     ⚠ Skipped 20250903_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/09/20250905_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/09/20250905_prof.nc
#     ⚠ Skipped 20250905_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/09/20250906_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/09/20250906_prof.nc
#     ⚠ Skipped 20250906_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/09/20250907_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/09/20250907_prof.nc
#     ⚠ Skipped 20250907_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/09/20250909_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/09/20250909_prof.nc
#     ⚠ Skipped 20250909_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/09/20250908_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/09/20250908_prof.nc
#     ⚠ Skipped 20250908_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/09/20250910_prof.nc due to error: https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/09/20250910_prof.nc
#     ⚠ Skipped 20250910_prof.nc: empty result
#   ⚠ All files empty for 2025-09
#   (no listing or status 404): https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/10/
#   (no listing or status 404): https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/11/
#   (no listing or status 404): https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2025/12/
#
# 🎉 Processing complete! One Parquet (ALL_PARAMS) + one SUMMARY per month saved when data exists.

# %%
import requests
from bs4 import BeautifulSoup
import xarray as xr
import fsspec
import pandas as pd
import numpy as np
import os
import traceback
from concurrent.futures import ThreadPoolExecutor, as_completed
import tempfile

# -----------------------
# Config
# -----------------------
BASE_URL = "https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/"
YEARS = range(2022, 2026)
MONTHS = [f"{m:02d}" for m in range(1, 13)]
OUT_DIR = "argo_2022_2025_parquet"
os.makedirs(OUT_DIR, exist_ok=True)

# Speed / concurrency
USE_PARALLEL = True        # set False to process sequentially
MAX_WORKERS = 6            # threads for downloading/processing

# -----------------------
# Helper: process 1 file
# -----------------------
def process_argo_file(file_url: str) -> pd.DataFrame:
    try:
        # --- download to temp file ---
        with tempfile.NamedTemporaryFile(suffix=".nc") as tmp:
            with requests.get(file_url, stream=True, timeout=60) as r:
                r.raise_for_status()
                for chunk in r.iter_content(chunk_size=1024*1024):
                    tmp.write(chunk)
            tmp.flush()

            # --- try opening dataset ---
            try:
                ds = xr.open_dataset(tmp.name, engine="netcdf4", decode_cf=False)
            except Exception:
                ds = xr.open_dataset(tmp.name, engine="scipy", decode_timedelta=False)

        # --- identify dimensions ---
        prof_dim = next((d for d in ds.dims if "N_PROF" in d or d.upper().startswith("N_PROF")), None)
        level_dim = next((d for d in ds.dims if "N_LEVEL" in d or "N_LEVELS" in d or d.upper().startswith("N_LEVEL")), None)

        if (prof_dim and ds.sizes.get(prof_dim, 0) == 0) or (level_dim and ds.sizes.get(level_dim, 0) == 0):
            print(f"⚠ Skipped {file_url}: declared but empty (N_PROF/N_LEVEL = 0)")
            return None

        # --- stack safely ---
        if prof_dim and level_dim:
            stacked = ds.stack(obs=(prof_dim, level_dim))
        elif prof_dim:
            stacked = ds.stack(obs=(prof_dim,))
        else:
            stacked = ds

        df = stacked.to_dataframe().reset_index()

        # --- cleaning ---
        df.dropna(axis=1, how="all", inplace=True)
        thresh = int(0.1 * len(df))
        if thresh > 0:
            df.dropna(axis=1, thresh=thresh, inplace=True)

        for col in df.select_dtypes(include=[np.number]).columns:
            if df[col].isna().any():
                m = df[col].mean()
                if not np.isnan(m):
                    df[col].fillna(m, inplace=True)

        df["source_file"] = os.path.basename(file_url)
        return df

    except Exception as e:
        print(f"⚠ Skipped {file_url} due to error: {e}")
        return None

# -----------------------
# Helper: summarization
# -----------------------
def summarize_month(df: pd.DataFrame) -> pd.DataFrame:
    s = df.copy()

    depth_col = None
    if "PRES_ADJUSTED" in s.columns:
        depth_col = "PRES_ADJUSTED"
    elif "PRES" in s.columns:
        depth_col = "PRES"

    if depth_col is not None:
        s[depth_col] = pd.to_numeric(s[depth_col], errors="coerce")

    metrics = []
    overall = {"metric": "overall", "n_obs": len(s)}
    if "TEMP" in s.columns:
        overall["temp_mean"] = float(s["TEMP"].mean()) if s["TEMP"].notna().any() else np.nan
        overall["temp_std"] = float(s["TEMP"].std()) if s["TEMP"].notna().any() else np.nan
    if "PSAL" in s.columns:
        overall["psal_mean"] = float(s["PSAL"].mean()) if s["PSAL"].notna().any() else np.nan
        overall["psal_std"] = float(s["PSAL"].std()) if s["PSAL"].notna().any() else np.nan
    metrics.append(overall)

    if depth_col is not None:
        bins = [-1e9, 10, 200, 1e9]
        labels = ["surface_0_10m", "mid_10_200m", "deep_200m_plus"]
        s["depth_bin"] = pd.cut(s[depth_col], bins=bins, labels=labels)
        for lbl in labels:
            sub = s[s["depth_bin"] == lbl]
            rec = {"metric": f"depth_bin::{lbl}", "n_obs": int(len(sub))}
            if "TEMP" in sub.columns and len(sub) > 0 and sub["TEMP"].notna().any():
                rec["temp_mean"] = float(sub["TEMP"].mean())
                rec["temp_std"] = float(sub["TEMP"].std())
            else:
                rec["temp_mean"], rec["temp_std"] = np.nan, np.nan
            if "PSAL" in sub.columns and len(sub) > 0 and sub["PSAL"].notna().any():
                rec["psal_mean"] = float(sub["PSAL"].mean())
                rec["psal_std"] = float(sub["PSAL"].std())
            else:
                rec["psal_mean"], rec["psal_std"] = np.nan, np.nan
            metrics.append(rec)

    top_sources = (
        s["source_file"].value_counts().reset_index().rename(columns={"index": "source_file", "source_file": "n_obs"})
    )
    for _, row in top_sources.head(10).iterrows():
        metrics.append({"metric": f"top_source::{row['source_file']}", "n_obs": int(row["n_obs"])})

    summary_df = pd.DataFrame(metrics)
    if "LATITUDE" in s.columns:
        summary_df["lat_mean"] = float(s["LATITUDE"].mean())
    if "LONGITUDE" in s.columns:
        summary_df["lon_mean"] = float(s["LONGITUDE"].mean())

    return summary_df

# -----------------------
# Main loop
# -----------------------
for year in YEARS:
    print(f"\n📂 Processing year: {year}")
    for month in MONTHS:
        dir_url = f"{BASE_URL}{year}/{month}/"
        try:
            resp = requests.get(dir_url, timeout=10)
            if resp.status_code != 200:
                print(f"  (no listing or status {resp.status_code}): {dir_url}")
                continue
        except Exception as e:
            print(f"  (request error for {dir_url}): {e}")
            continue

        soup = BeautifulSoup(resp.text, "html.parser")
        files = [a['href'] for a in soup.find_all('a') if a.get('href', "").endswith(".nc")]
        if not files:
            continue

        month_data = []

        if USE_PARALLEL:
            print(f"  ⚡ Processing {len(files)} files in parallel (max_workers={MAX_WORKERS})")
            with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
                future_to_file = {executor.submit(process_argo_file, dir_url + file): file for file in files}
                for future in as_completed(future_to_file):
                    file = future_to_file[future]
                    try:
                        df = future.result()
                        if df is not None and not df.empty:
                            month_data.append(df)
                            print(f"    ✅ Done: {file} | rows: {len(df)}")
                        else:
                            print(f"    ⚠ Skipped {file}: empty result")
                    except Exception:
                        print(f"    ⚠ Skipped {file} due to error:")
                        traceback.print_exc()
        else:
            for file in files:
                file_url = dir_url + file
                print(f"  🔹 Reading: {file_url}")
                try:
                    df = process_argo_file(file_url)
                    if df is not None and not df.empty:
                        month_data.append(df)
                        print(f"    ✅ Done: {file} | rows: {len(df)}")
                    else:
                        print(f"    ⚠ Skipped {file}: empty result")
                except Exception:
                    print(f"    ⚠ Skipped {file} due to error:")
                    traceback.print_exc()

        # --- monthly parquet saving ---
        if month_data:
            final_df = pd.concat([df for df in month_data if df is not None], ignore_index=True)
            if not final_df.empty:
                out_file = f"{OUT_DIR}/{year}_{month}_ALL_PARAMS.parquet"
                final_df.to_parquet(out_file, index=False)
                print(f"  ✅ Saved Parquet: {out_file} | Shape: {final_df.shape}")

                try:
                    summary_df = summarize_month(final_df)
                    out_summary = f"{OUT_DIR}/{year}_{month}_SUMMARY.parquet"
                    summary_df.to_parquet(out_summary, index=False)
                    print(f"  🔎 Saved SUMMARY: {out_summary} | rows: {len(summary_df)})")
                except Exception:
                    print("  ⚠ Failed to create/save summary:")
                    traceback.print_exc()
            else:
                print(f"  ⚠ No usable data for {year}-{month}")
        else:
            print(f"  ⚠ All files empty for {year}-{month}")

print("\n🎉 Processing complete! One Parquet (ALL_PARAMS) + one SUMMARY per month saved when data exists.")
# Out:
# 📂 Processing year: 2022
#   ⚡ Processing 31 files in parallel (max_workers=6)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220105_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220105_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220106_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220102_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220102_prof.nc: empty result
#     ⚠ Skipped 20220106_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220101_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220101_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220107_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220107_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220108_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220108_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220109_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220109_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220110_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220110_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220111_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220111_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220113_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220113_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220114_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220114_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220112_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220112_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220115_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220115_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220116_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220116_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220117_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220117_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220118_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220118_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220103_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220103_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220120_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220120_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220122_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220122_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220104_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220104_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220123_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220123_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220124_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220124_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220125_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220125_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220126_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220126_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220128_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220128_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220129_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220129_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220130_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220130_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220131_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220131_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220119_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220119_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220121_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220121_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/01/20220127_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220127_prof.nc: empty result
#   ⚠ All files empty for 2022-01
#   ⚡ Processing 28 files in parallel (max_workers=6)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220202_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220202_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220205_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220205_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220201_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220201_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220204_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220204_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220203_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220203_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220206_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220206_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220207_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220207_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220209_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220209_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220208_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220208_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220211_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220211_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220212_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220212_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220213_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220213_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220215_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220215_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220217_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220217_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220216_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220216_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220219_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220219_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220218_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220218_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220220_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220220_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220222_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220222_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220223_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220223_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220224_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220224_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220227_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220227_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220226_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220226_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220228_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220228_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220210_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220210_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220214_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220214_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220221_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220221_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/02/20220225_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220225_prof.nc: empty result
#   ⚠ All files empty for 2022-02
#   ⚡ Processing 31 files in parallel (max_workers=6)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220301_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220301_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220302_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220302_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220303_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220303_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220304_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220304_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220305_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220305_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220306_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220306_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220307_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220307_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220309_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220309_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220310_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220310_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220308_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220308_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220311_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220311_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220312_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220312_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220313_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220313_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220314_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220314_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220315_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220315_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220317_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220317_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220319_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220319_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220320_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220320_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220318_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220318_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220322_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220322_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220323_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220323_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220325_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220325_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220326_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220326_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220327_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220327_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220328_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220328_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220329_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220329_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220330_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220330_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220331_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220331_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220321_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220321_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220316_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220316_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/03/20220324_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220324_prof.nc: empty result
#   ⚠ All files empty for 2022-03
#   ⚡ Processing 30 files in parallel (max_workers=6)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220403_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220403_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220401_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220401_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220406_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220402_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220406_prof.nc: empty result
#     ⚠ Skipped 20220402_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220405_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220405_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220404_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220404_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220407_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220407_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220410_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220410_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220409_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220409_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220412_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220412_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220411_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220411_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220413_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220413_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220414_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220414_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220415_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220415_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220418_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220418_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220417_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220416_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220417_prof.nc: empty result
#     ⚠ Skipped 20220416_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220419_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220419_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220420_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220420_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220421_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220421_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220422_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220422_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220423_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220423_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220424_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220424_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220425_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220425_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220426_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220426_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220428_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220428_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220429_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220429_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220430_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220430_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220427_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220427_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/04/20220408_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220408_prof.nc: empty result
#   ⚠ All files empty for 2022-04
#   ⚡ Processing 31 files in parallel (max_workers=6)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220502_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220502_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220501_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220501_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220503_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220503_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220508_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220508_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220509_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220509_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220507_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220507_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220510_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220510_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220511_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220511_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220513_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220513_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220514_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220514_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220515_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220515_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220517_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220517_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220505_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220505_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220504_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220504_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220518_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220518_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220506_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220519_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220506_prof.nc: empty result
#     ⚠ Skipped 20220519_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220520_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220520_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220521_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220521_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220512_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220512_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220522_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220523_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220522_prof.nc: empty result
#     ⚠ Skipped 20220523_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220524_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220524_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220525_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220525_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220526_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220526_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220529_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220529_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220528_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220528_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220527_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220527_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220516_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220516_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220530_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220530_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/05/20220531_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220531_prof.nc: empty result
#   ⚠ All files empty for 2022-05
#   ⚡ Processing 30 files in parallel (max_workers=6)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220601_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220601_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220605_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220602_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220605_prof.nc: empty result
#     ⚠ Skipped 20220602_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220603_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220603_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220606_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220606_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220607_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220607_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220608_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220608_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220610_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220610_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220609_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220609_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220611_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220611_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220612_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220612_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220614_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220614_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220615_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220615_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220616_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220616_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220617_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220617_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220618_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220618_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220619_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220619_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220620_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220620_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220621_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220621_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220622_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220622_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220623_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220623_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220624_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220624_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220625_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220625_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220604_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220604_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220626_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220626_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220627_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220627_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220628_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220629_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220629_prof.nc: empty result
#     ⚠ Skipped 20220628_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220630_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220630_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/06/20220613_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220613_prof.nc: empty result
#   ⚠ All files empty for 2022-06
#   ⚡ Processing 31 files in parallel (max_workers=6)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220701_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220703_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220703_prof.nc: empty result
#     ⚠ Skipped 20220701_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220705_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220705_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220704_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220704_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220702_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220702_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220706_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220706_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220707_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220707_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220710_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220710_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220709_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220709_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220711_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220712_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220711_prof.nc: empty result
#     ⚠ Skipped 20220712_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220713_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220713_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220714_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220714_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220715_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220715_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220717_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220717_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220718_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220718_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220719_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220719_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220720_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220720_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220721_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220722_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220721_prof.nc: empty result
#     ⚠ Skipped 20220722_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220723_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220723_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220724_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220724_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220726_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220726_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220728_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220728_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220727_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220727_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220729_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220729_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220708_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220708_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220730_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220731_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220730_prof.nc: empty result
#     ⚠ Skipped 20220731_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220716_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220716_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/07/20220725_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220725_prof.nc: empty result
#   ⚠ All files empty for 2022-07
#   ⚡ Processing 31 files in parallel (max_workers=6)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220802_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220802_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220803_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220803_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220804_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220804_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220801_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220801_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220806_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220806_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220805_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220805_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220809_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220809_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220810_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220810_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220808_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220811_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220812_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220808_prof.nc: empty result
#     ⚠ Skipped 20220812_prof.nc: empty result
#     ⚠ Skipped 20220811_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220813_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220813_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220814_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220814_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220817_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220817_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220816_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220816_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220815_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220818_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220815_prof.nc: empty result
#     ⚠ Skipped 20220818_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220819_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220819_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220820_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220820_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220823_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220823_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/08/20220822_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20220822_prof.nc: empty result
# ...
#     ⚠ Skipped 20221123_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/11/20221124_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221124_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/11/20221125_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221125_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/11/20221127_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221127_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/11/20221128_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/11/20221129_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221128_prof.nc: empty result
#     ⚠ Skipped 20221129_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/11/20221130_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221130_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/11/20221116_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221116_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/11/20221126_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221126_prof.nc: empty result
#   ⚠ All files empty for 2022-11
#   ⚡ Processing 31 files in parallel (max_workers=6)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221206_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221206_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221202_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221203_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221202_prof.nc: empty result
#     ⚠ Skipped 20221203_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221204_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221204_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221201_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221205_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221201_prof.nc: empty result
#     ⚠ Skipped 20221205_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221207_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221209_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221207_prof.nc: empty result
#     ⚠ Skipped 20221209_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221210_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221210_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221208_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221212_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221212_prof.nc: empty result
#     ⚠ Skipped 20221208_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221211_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221211_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221214_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221214_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221213_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221213_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221215_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221215_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221217_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221217_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221216_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221216_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221220_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221219_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221220_prof.nc: empty result
#     ⚠ Skipped 20221219_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221218_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221218_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221221_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221221_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221222_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221222_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221223_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221223_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221226_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221226_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221224_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221224_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221225_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221225_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221227_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221227_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221229_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221229_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221230_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221230_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221228_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221228_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2022/12/20221231_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20221231_prof.nc: empty result
#   ⚠ All files empty for 2022-12
#
# 📂 Processing year: 2023
#   ⚡ Processing 31 files in parallel (max_workers=6)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230105_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20230105_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230102_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20230102_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230101_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230103_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20230101_prof.nc: empty result
#     ⚠ Skipped 20230103_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230106_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230104_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20230106_prof.nc: empty result
#     ⚠ Skipped 20230104_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230108_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20230108_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230107_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20230107_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230109_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20230109_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230110_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20230110_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230111_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20230111_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230115_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20230115_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230113_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20230113_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230112_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20230112_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230114_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20230114_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230116_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20230116_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230119_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20230119_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230117_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20230117_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230120_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20230120_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230121_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20230121_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230122_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20230122_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230123_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20230123_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230125_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
#     ⚠ Skipped 20230125_prof.nc: empty result
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230124_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230126_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ⚠ Skipped https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/2023/01/20230128_prof.nc due to error: cannot reshape array of size 0 into shape (0,newaxis)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3864126442.py in <cell line: 0>()
#     165                 future_to_file = {executor.submit(process_argo_file, dir_url + file): file for file in files}
# --> 166                 for future in as_completed(future_to_file):
#     167                     file = future_to_file[future]
#
# /usr/lib/python3.12/concurrent/futures/_base.py in as_completed(fs, timeout)
#     242
# --> 243             waiter.event.wait(wait_timeout)
#     244
#
# /usr/lib/python3.12/threading.py in wait(self, timeout)
#     654             if not signaled:
# --> 655                 signaled = self._cond.wait(timeout)
#     656             return signaled
#
# /usr/lib/python3.12/threading.py in wait(self, timeout)
#     354             if timeout is None:
# --> 355                 waiter.acquire()
#     356                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3864126442.py in <cell line: 0>()
#     162         if USE_PARALLEL:
#     163             print(f"  ⚡ Processing {len(files)} files in parallel (max_workers={MAX_WORKERS})")
# --> 164             with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
#     165                 future_to_file = {executor.submit(process_argo_file, dir_url + file): file for file in files}
#     166                 for future in as_completed(future_to_file):
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     645
#     646     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 647         self.shutdown(wait=True)
#     648         return False
#     649
#
# /usr/lib/python3.12/concurrent/futures/thread.py in shutdown(self, wait, cancel_futures)
#     237         if wait:
#     238             for t in self._threads:
# --> 239                 t.join()
#     240     shutdown.__doc__ = _base.Executor.shutdown.__doc__
#
# /usr/lib/python3.12/threading.py in join(self, timeout)
#    1147
#    1148         if timeout is None:
# -> 1149             self._wait_for_tstate_lock()
#    1150         else:
#    1151             # the behavior of a negative timeout isn't documented, but
#
# /usr/lib/python3.12/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1167
#    1168         try:
# -> 1169             if lock.acquire(block, timeout):
#    1170                 lock.release()
#    1171                 self._stop()
#
# KeyboardInterrupt:

# %%
import requests
from bs4 import BeautifulSoup
import xarray as xr
import pandas as pd
import numpy as np
import os
import tempfile
import traceback
from concurrent.futures import ThreadPoolExecutor, as_completed

# -----------------------
# Config
# -----------------------
BASE_URL = "https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/"
YEARS = range(2022, 2025)
MONTHS = [f"{m:02d}" for m in range(1, 13)]
OUT_DIR = "argo_2022_2025_parquet"
os.makedirs(OUT_DIR, exist_ok=True)

# Speed / concurrency
USE_PARALLEL = True        # set False to process sequentially
MAX_WORKERS = 6            # threads for downloading/processing

# -----------------------
# Helper: safe flattening of a dataset into a DataFrame
# -----------------------
def open_dataset_with_fallback(path_or_file) -> xr.Dataset:
    """
    Try netCDF4 first (best for modern files), then fallback to scipy.
    Accepts a local filename or a file-like object (but we pass filenames).
    """
    try:
        # prefer netCDF4, disable decode_cf to avoid some automatic conversions that may fail
        ds = xr.open_dataset(path_or_file, engine="netcdf4", decode_cf=False)
        return ds
    except Exception:
        # fallback to scipy (older netcdf3)
        ds = xr.open_dataset(path_or_file, engine="scipy", decode_timedelta=False)
        return ds

def flatten_ds_to_df(ds: xr.Dataset, source_file_name: str) -> pd.DataFrame:
    """
    Build a DataFrame WITHOUT using ds.stack, but by flattening variables manually.
    Handles variables with shapes:
      - (n_prof, n_level)
      - (n_prof,)
      - scalar
    Skips variables with incompatible shapes or zero size.
    """
    # coordinates typically present
    lat = None
    lon = None
    juld = None
    if "LATITUDE" in ds.variables:
        lat = np.asarray(ds["LATITUDE"].values)
    if "LONGITUDE" in ds.variables:
        lon = np.asarray(ds["LONGITUDE"].values)
    if "JULD" in ds.variables:
        try:
            juld = pd.to_datetime(ds["JULD"].values)
        except Exception:
            # ensure something usable
            juld = np.asarray(ds["JULD"].values)

    # infer profile/level dims sizes (safe)
    prof_dim = next((d for d in ds.dims if "N_PROF" in d or d.upper().startswith("N_PROF")), None)
    level_dim = next((d for d in ds.dims if "N_LEVEL" in d or "N_LEVELS" in d or d.upper().startswith("N_LEVEL")), None)

    n_prof = int(ds.sizes.get(prof_dim, 0)) if prof_dim else (len(lat) if lat is not None else 0)
    n_level = int(ds.sizes.get(level_dim, 1)) if level_dim else 1

    # If there are no profiles (n_prof == 0) consider dataset empty
    if n_prof == 0:
        raise ValueError("Dataset has zero profiles (n_prof == 0)")

    # total flattened length
    total_len = n_prof * n_level

    # base arrays: repeat coords per level
    # if lat/lon/juld are missing, attempt to find alternative variables or set NaNs
    if lat is None:
        lat_arr = np.full(total_len, np.nan)
    else:
        if lat.size != n_prof:
            # attempt to coerce - if a scalar, repeat
            if lat.size == 1:
                lat = np.repeat(lat, n_prof)
            else:
                raise ValueError(f"LATITUDE size ({lat.size}) doesn't match n_prof ({n_prof})")
        lat_arr = np.repeat(lat, n_level)

    if lon is None:
        lon_arr = np.full(total_len, np.nan)
    else:
        if lon.size != n_prof:
            if lon.size == 1:
                lon = np.repeat(lon, n_prof)
            else:
                raise ValueError(f"LONGITUDE size ({lon.size}) doesn't match n_prof ({n_prof})")
        lon_arr = np.repeat(lon, n_level)

    if juld is None:
        juld_arr = np.full(total_len, pd.NaT, dtype=object)
    else:
        if len(juld) != n_prof:
            if np.size(juld) == 1:
                juld = np.repeat(juld, n_prof)
            else:
                # coerce to string or leave as-is
                juld = np.array(juld, dtype=object)
        juld_arr = np.repeat(juld, n_level)

    base_df = pd.DataFrame({
        "LATITUDE": lat_arr,
        "LONGITUDE": lon_arr,
        "JULD": juld_arr
    })

    # Try PRES_ADJUSTED then PRES to produce DEPTH_M
    depth_col_vals = None
    if "PRES_ADJUSTED" in ds.variables:
        try:
            arr = np.asarray(ds["PRES_ADJUSTED"].values)
            if arr.size == 0:
                depth_col_vals = None
            elif arr.ndim == 2 and arr.shape == (n_prof, n_level):
                depth_col_vals = arr.flatten()
            elif arr.ndim == 1 and arr.shape[0] == n_prof:
                depth_col_vals = np.repeat(arr, n_level)
            elif arr.ndim == 0:
                depth_col_vals = np.repeat(arr.item(), total_len)
        except Exception:
            depth_col_vals = None

    if depth_col_vals is None and "PRES" in ds.variables:
        try:
            arr = np.asarray(ds["PRES"].values)
            if arr.size == 0:
                depth_col_vals = None
            elif arr.ndim == 2 and arr.shape == (n_prof, n_level):
                depth_col_vals = arr.flatten()
            elif arr.ndim == 1 and arr.shape[0] == n_prof:
                depth_col_vals = np.repeat(arr, n_level)
            elif arr.ndim == 0:
                depth_col_vals = np.repeat(arr.item(), total_len)
        except Exception:
            depth_col_vals = None

    base_df["DEPTH_M"] = depth_col_vals if depth_col_vals is not None else np.nan

    # Now iterate all variables and safely flatten relevant ones
    for var in ds.variables:
        if var in ["LATITUDE", "LONGITUDE", "JULD"]:
            continue  # already handled
        # Skip coordinate dims
        data = ds[var].values
        try:
            arr = np.asarray(data)
        except Exception:
            # skip unreadable var
            continue

        if arr.size == 0:
            # skip empty variables
            # print debug once per var
            # print(f"  (skip var {var} because it's empty)")
            continue

        # 2D var shaped (n_prof, n_level)
        if arr.ndim == 2 and arr.shape[0] == n_prof and arr.shape[1] == n_level:
            flat = arr.flatten()
            base_df[var] = flat
            continue

        # 1D var shaped (n_prof,)
        if arr.ndim == 1 and arr.shape[0] == n_prof:
            base_df[var] = np.repeat(arr, n_level)
            continue

        # scalar
        if arr.ndim == 0:
            base_df[var] = np.repeat(arr.item(), total_len)
            continue

        # other shapes: try to broadcast if possible
        # e.g., (n_level,) -> tile across n_prof
        if arr.ndim == 1 and arr.shape[0] == n_level:
            base_df[var] = np.tile(arr, n_prof)
            continue

        # if we get here shapes don't match the expected pattern; skip variable
        # print debug
        # print(f"  (skip var {var}: unexpected shape {arr.shape})")
        continue

    # Cleaning similar to your pipeline
    base_df.dropna(axis=1, how="all", inplace=True)
    thresh = int(0.1 * len(base_df))
    if thresh > 0:
        base_df.dropna(axis=1, thresh=thresh, inplace=True)

    # fill numeric NaNs with mean as before
    for col in base_df.select_dtypes(include=[np.number]).columns:
        if base_df[col].isna().any():
            m = base_df[col].mean()
            if not np.isnan(m):
                base_df[col].fillna(m, inplace=True)

    base_df["source_file"] = source_file_name
    return base_df

# -----------------------
# Worker: process 1 file (download + open + flatten)
# -----------------------
def process_argo_file(file_url: str) -> pd.DataFrame:
    """
    Download file to temp, open with netcdf4 (fallback to scipy),
    then flatten safely to DataFrame.
    """
    try:
        # Download to temp file
        with tempfile.NamedTemporaryFile(suffix=".nc") as tmp:
            with requests.get(file_url, stream=True, timeout=60) as r:
                r.raise_for_status()
                for chunk in r.iter_content(chunk_size=1024*1024):
                    tmp.write(chunk)
            tmp.flush()

            # Open dataset with fallback
            try:
                ds = xr.open_dataset(tmp.name, engine="netcdf4", decode_cf=False)
            except Exception:
                ds = xr.open_dataset(tmp.name, engine="scipy", decode_timedelta=False)

            # convert dataset into DataFrame safely
            source_name = os.path.basename(file_url)
            df = flatten_ds_to_df(ds, source_name)
            # close dataset to free resources
            ds.close()
            return df

    except Exception as e:
        # show a short, informative message
        print(f"⚠ Skipped {file_url} due to error: {e}")
        return None

# -----------------------
# Helper: summarization (unchanged logic)
# -----------------------
def summarize_month(df: pd.DataFrame) -> pd.DataFrame:
    s = df.copy()

    depth_col = None
    if "PRES_ADJUSTED" in s.columns:
        depth_col = "PRES_ADJUSTED"
    elif "PRES" in s.columns:
        depth_col = "PRES"
    elif "DEPTH_M" in s.columns:
        depth_col = "DEPTH_M"

    if depth_col is not None:
        s[depth_col] = pd.to_numeric(s[depth_col], errors="coerce")

    metrics = []
    overall = {"metric": "overall", "n_obs": len(s)}
    if "TEMP" in s.columns:
        overall["temp_mean"] = float(s["TEMP"].mean()) if s["TEMP"].notna().any() else np.nan
        overall["temp_std"] = float(s["TEMP"].std()) if s["TEMP"].notna().any() else np.nan
    if "PSAL" in s.columns:
        overall["psal_mean"] = float(s["PSAL"].mean()) if s["PSAL"].notna().any() else np.nan
        overall["psal_std"] = float(s["PSAL"].std()) if s["PSAL"].notna().any() else np.nan
    metrics.append(overall)

    if depth_col is not None:
        bins = [-1e9, 10, 200, 1e9]
        labels = ["surface_0_10m", "mid_10_200m", "deep_200m_plus"]
        s["depth_bin"] = pd.cut(s[depth_col], bins=bins, labels=labels)
        for lbl in labels:
            sub = s[s["depth_bin"] == lbl]
            rec = {"metric": f"depth_bin::{lbl}", "n_obs": int(len(sub))}
            if "TEMP" in sub.columns and len(sub) > 0 and sub["TEMP"].notna().any():
                rec["temp_mean"] = float(sub["TEMP"].mean())
                rec["temp_std"] = float(sub["TEMP"].std())
            else:
                rec["temp_mean"], rec["temp_std"] = np.nan, np.nan
            if "PSAL" in sub.columns and len(sub) > 0 and sub["PSAL"].notna().any():
                rec["psal_mean"] = float(sub["PSAL"].mean())
                rec["psal_std"] = float(sub["PSAL"].std())
            else:
                rec["psal_mean"], rec["psal_std"] = np.nan, np.nan
            metrics.append(rec)

    top_sources = (
        s["source_file"].value_counts().reset_index().rename(columns={"index": "source_file", "source_file": "n_obs"})
    )
    for _, row in top_sources.head(10).iterrows():
        metrics.append({"metric": f"top_source::{row['source_file']}", "n_obs": int(row["n_obs"])})

    summary_df = pd.DataFrame(metrics)
    if "LATITUDE" in s.columns:
        try:
            summary_df["lat_mean"] = float(s["LATITUDE"].mean())
        except Exception:
            summary_df["lat_mean"] = np.nan
    if "LONGITUDE" in s.columns:
        try:
            summary_df["lon_mean"] = float(s["LONGITUDE"].mean())
        except Exception:
            summary_df["lon_mean"] = np.nan

    return summary_df

# -----------------------
# Main loop
# -----------------------
for year in YEARS:
    print(f"\n📂 Processing year: {year}")
    for month in MONTHS:
        dir_url = f"{BASE_URL}{year}/{month}/"
        try:
            resp = requests.get(dir_url, timeout=10)
            if resp.status_code != 200:
                print(f"  (no listing or status {resp.status_code}): {dir_url}")
                continue
        except Exception as e:
            print(f"  (request error for {dir_url}): {e}")
            continue

        soup = BeautifulSoup(resp.text, "html.parser")
        files = [a.get('href') for a in soup.find_all('a') if a.get('href', "").endswith(".nc")]
        if not files:
            continue

        month_data = []

        if USE_PARALLEL:
            print(f"  ⚡ Processing {len(files)} files in parallel (max_workers={MAX_WORKERS})")
            with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
                future_to_file = {executor.submit(process_argo_file, dir_url + file): file for file in files}
                for future in as_completed(future_to_file):
                    file = future_to_file[future]
                    try:
                        df = future.result()
                        if df is not None and not df.empty:
                            month_data.append(df)
                            print(f"    ✅ Done: {file} | rows: {len(df)}")
                        else:
                            print(f"    ⚠ Skipped {file}: empty result")
                    except Exception:
                        print(f"    ⚠ Skipped {file} due to error:")
                        traceback.print_exc()
        else:
            for file in files:
                file_url = dir_url + file
                print(f"  🔹 Reading: {file_url}")
                try:
                    df = process_argo_file(file_url)
                    if df is not None and not df.empty:
                        month_data.append(df)
                        print(f"    ✅ Done: {file} | rows: {len(df)}")
                    else:
                        print(f"    ⚠ Skipped {file}: empty result")
                except Exception:
                    print(f"    ⚠ Skipped {file} due to error:")
                    traceback.print_exc()

        # ✅ safe saving block
        if month_data:
            final_df = pd.concat([df for df in month_data if df is not None], ignore_index=True)
            if not final_df.empty:
                out_file = f"{OUT_DIR}/{year}_{month}_ALL_PARAMS.parquet"
                final_df.to_parquet(out_file, index=False)
                print(f"  ✅ Saved Parquet: {out_file} | Shape: {final_df.shape}")

                try:
                    summary_df = summarize_month(final_df)
                    out_summary = f"{OUT_DIR}/{year}_{month}_SUMMARY.parquet"
                    summary_df.to_parquet(out_summary, index=False)
                    print(f"  🔎 Saved SUMMARY: {out_summary} | rows: {len(summary_df)})")
                except Exception:
                    print("  ⚠ Failed to create/save summary:")
                    traceback.print_exc()
            else:
                print(f"  ⚠ No usable data for {year}-{month}")
        else:
            print(f"  ⚠ All files empty for {year}-{month}")

print("\n🎉 Processing complete! One Parquet (ALL_PARAMS) + one SUMMARY per month saved when data exists.")
# Out:
# 📂 Processing year: 2022
#   ⚡ Processing 31 files in parallel (max_workers=6)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20220103_prof.nc | rows: 72864
#     ✅ Done: 20220102_prof.nc | rows: 80780
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20220106_prof.nc | rows: 88566
#     ✅ Done: 20220104_prof.nc | rows: 93472
#     ✅ Done: 20220105_prof.nc | rows: 102439
#     ✅ Done: 20220101_prof.nc | rows: 77770
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20220108_prof.nc | rows: 91922
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20220110_prof.nc | rows: 75332
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20220112_prof.nc | rows: 87780
#     ✅ Done: 20220111_prof.nc | rows: 67804
#     ✅ Done: 20220109_prof.nc | rows: 87040
#     ✅ Done: 20220107_prof.nc | rows: 69936
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20220113_prof.nc | rows: 69759
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20220114_prof.nc | rows: 95786
#     ✅ Done: 20220118_prof.nc | rows: 86946
#     ✅ Done: 20220116_prof.nc | rows: 92004
#     ✅ Done: 20220115_prof.nc | rows: 101288
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20220117_prof.nc | rows: 72128
#     ✅ Done: 20220119_prof.nc | rows: 91260
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20220120_prof.nc | rows: 74022
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20220122_prof.nc | rows: 81863
#     ✅ Done: 20220123_prof.nc | rows: 67871
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20220124_prof.nc | rows: 96710
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20220125_prof.nc | rows: 107043
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20220121_prof.nc | rows: 79948
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20220126_prof.nc | rows: 83472
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20220128_prof.nc | rows: 79794
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20220127_prof.nc | rows: 68748
#     ✅ Done: 20220129_prof.nc | rows: 86360
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20220130_prof.nc | rows: 66792
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20220131_prof.nc | rows: 79794
#   ✅ Saved Parquet: argo_2022_2025_parquet/2022_01_ALL_PARAMS.parquet | Shape: (2577293, 51)
#   ⚠ Failed to create/save summary:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
# ...
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20221221_prof.nc | rows: 111161
#     ✅ Done: 20221224_prof.nc | rows: 92513
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20221226_prof.nc | rows: 79326
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20221225_prof.nc | rows: 134458
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20221227_prof.nc | rows: 87838
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20221231_prof.nc | rows: 172020
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20221229_prof.nc | rows: 84910
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20221230_prof.nc | rows: 94875
# /tmp/ipython-input-2938751951.py:207: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   base_df[col].fillna(m, inplace=True)
#     ✅ Done: 20221228_prof.nc | rows: 123272

# %%
import pandas as pd
import os

# ----------------------
# Config
# ----------------------
OUT_DIR = "argo_2022_2025_parquet"   # change to "argo_2022_2025_csvs" if you saved CSVs
YEAR = 2022
MONTH = "11"   # only used if parquet monthly files exist
USE_PARQUET = True  # set False if you want to read CSV yearly files

# ----------------------
# File path
# ----------------------
if USE_PARQUET:
    file_path = os.path.join(OUT_DIR, f"{YEAR}_{MONTH}_ALL_PARAMS.parquet")
else:
    file_path = os.path.join("argo_2022_2025_csvs", f"{YEAR}_ALL_PARAMS.csv")

# ----------------------
# Read & show first rows
# ----------------------
if not os.path.exists(file_path):
    print(f"⚠ File not found: {file_path}")
else:
    print(f"📂 Reading file: {file_path}")
    if USE_PARQUET:
        df = pd.read_parquet(file_path)
    else:
        df = pd.read_csv(file_path)

    print("\n🔹 First 10 rows of the dataset:\n")
    print(df.head(10))   # change to head(5) for first 5 rows
    print(f"\n✅ Loaded DataFrame with shape: {df.shape}")
# Out:
# 📂 Reading file: argo_2022_2025_parquet/2022_11_ALL_PARAMS.parquet
#
# 🔹 First 10 rows of the dataset:
#
#    LATITUDE  LONGITUDE                    JULD  DEPTH_M            DATA_TYPE  \
# 0 -38.37789   26.93396 2022-11-06 17:24:56.160     1.08  b'Argo profile    '
# 1 -38.37789   26.93396 2022-11-06 17:24:56.160     2.00  b'Argo profile    '
# 2 -38.37789   26.93396 2022-11-06 17:24:56.160     3.00  b'Argo profile    '
# 3 -38.37789   26.93396 2022-11-06 17:24:56.160     4.00  b'Argo profile    '
# 4 -38.37789   26.93396 2022-11-06 17:24:56.160     4.96  b'Argo profile    '
# 5 -38.37789   26.93396 2022-11-06 17:24:56.160     6.00  b'Argo profile    '
# 6 -38.37789   26.93396 2022-11-06 17:24:56.160     6.92  b'Argo profile    '
# 7 -38.37789   26.93396 2022-11-06 17:24:56.160     8.00  b'Argo profile    '
# 8 -38.37789   26.93396 2022-11-06 17:24:56.160     9.08  b'Argo profile    '
# 9 -38.37789   26.93396 2022-11-06 17:24:56.160    10.32  b'Argo profile    '
#
#   FORMAT_VERSION HANDBOOK_VERSION REFERENCE_DATE_TIME      DATE_CREATION  \
# 0        b'3.1 '          b'1.2 '   b'19500101000000'  b'20250910051358'
# 1        b'3.1 '          b'1.2 '   b'19500101000000'  b'20250910051358'
# 2        b'3.1 '          b'1.2 '   b'19500101000000'  b'20250910051358'
# 3        b'3.1 '          b'1.2 '   b'19500101000000'  b'20250910051358'
# 4        b'3.1 '          b'1.2 '   b'19500101000000'  b'20250910051358'
# 5        b'3.1 '          b'1.2 '   b'19500101000000'  b'20250910051358'
# 6        b'3.1 '          b'1.2 '   b'19500101000000'  b'20250910051358'
# 7        b'3.1 '          b'1.2 '   b'19500101000000'  b'20250910051358'
# 8        b'3.1 '          b'1.2 '   b'19500101000000'  b'20250910051358'
# 9        b'3.1 '          b'1.2 '   b'19500101000000'  b'20250910051358'
#
#          DATE_UPDATE  ... PSAL_ADJUSTED PSAL_ADJUSTED_QC PSAL_ADJUSTED_ERROR  \
# 0  b'20250910051358'  ...     35.409500             b'1'                0.01
# 1  b'20250910051358'  ...     35.409599             b'1'                0.01
# 2  b'20250910051358'  ...     35.409302             b'1'                0.01
# 3  b'20250910051358'  ...     35.409100             b'1'                0.01
# 4  b'20250910051358'  ...     35.409500             b'1'                0.01
# 5  b'20250910051358'  ...     35.410000             b'1'                0.01
# 6  b'20250910051358'  ...     35.408798             b'1'                0.01
# 7  b'20250910051358'  ...     35.408798             b'1'                0.01
# 8  b'20250910051358'  ...     35.409302             b'1'                0.01
# 9  b'20250910051358'  ...     35.408798             b'1'                0.01
#
#         TEMP TEMP_QC TEMP_ADJUSTED TEMP_ADJUSTED_QC TEMP_ADJUSTED_ERROR  \
# 0  16.888000    b'1'     16.888000             b'1'            0.002236
# 1  16.886999    b'1'     16.886999             b'1'            0.002236
# 2  16.889000    b'1'     16.889000             b'1'            0.002236
# 3  16.893000    b'1'     16.893000             b'1'            0.002236
# 4  16.893999    b'1'     16.893999             b'1'            0.002236
# 5  16.889999    b'1'     16.889999             b'1'            0.002236
# 6  16.879000    b'1'     16.879000             b'1'            0.002236
# 7  16.879999    b'1'     16.879999             b'1'            0.002236
# 8  16.878000    b'1'     16.878000             b'1'            0.002236
# 9  16.872000    b'1'     16.872000             b'1'            0.002236
#
#         source_file MTIME_QC
# 0  20221106_prof.nc     None
# 1  20221106_prof.nc     None
# 2  20221106_prof.nc     None
# 3  20221106_prof.nc     None
# 4  20221106_prof.nc     None
# 5  20221106_prof.nc     None
# 6  20221106_prof.nc     None
# 7  20221106_prof.nc     None
# 8  20221106_prof.nc     None
# 9  20221106_prof.nc     None
#
# [10 rows x 50 columns]
#
# ✅ Loaded DataFrame with shape: (2942155, 50)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import requests
from bs4 import BeautifulSoup
import xarray as xr
import pandas as pd
import numpy as np
import os
import tempfile
from concurrent.futures import ThreadPoolExecutor, as_completed

# -----------------------
# Config
# -----------------------
BASE_URL = "https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/"
YEARS = range(2022, 2025)
MONTHS = [f"{m:02d}" for m in range(1, 13)]
OUT_DIR = "/content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet"
os.makedirs(OUT_DIR, exist_ok=True)

USE_PARALLEL = True
MAX_WORKERS = 6

# Bounding box filter (optional, e.g., Indian Ocean subset)
BBOX = {
    "lat_min": -40, "lat_max": 30,
    "lon_min": 30, "lon_max": 110
}

# -----------------------
# Helper: safe dataset opening
# -----------------------
def open_dataset_safe(path_or_file):
    try:
        return xr.open_dataset(path_or_file, engine="netcdf4", decode_cf=False)
    except Exception:
        return xr.open_dataset(path_or_file, engine="scipy", decode_timedelta=False)

# -----------------------
# Flatten dataset safely (minimal columns)
# -----------------------
def flatten_ds_minimal(ds: xr.Dataset, source_file: str):
    # Coordinates
    lat = np.asarray(ds["LATITUDE"].values) if "LATITUDE" in ds else None
    lon = np.asarray(ds["LONGITUDE"].values) if "LONGITUDE" in ds else None
    juld = pd.to_datetime(ds["JULD"].values, errors='coerce') if "JULD" in ds else None

    # Dimensions
    prof_dim = next((d for d in ds.dims if "N_PROF" in d.upper()), None)
    level_dim = next((d for d in ds.dims if "N_LEVEL" in d.upper() or "N_LEVELS" in d.upper()), None)
    n_prof = int(ds.sizes.get(prof_dim, 0)) if prof_dim else (len(lat) if lat is not None else 0)
    n_level = int(ds.sizes.get(level_dim, 1)) if level_dim else 1
    if n_prof == 0:  # empty dataset
        raise ValueError("Dataset has zero profiles")

    total_len = n_prof * n_level

    # Coordinates arrays
    lat_arr = np.repeat(lat, n_level) if lat is not None else np.full(total_len, np.nan)
    lon_arr = np.repeat(lon, n_level) if lon is not None else np.full(total_len, np.nan)
    juld_arr = np.repeat(juld, n_level) if juld is not None else np.full(total_len, pd.NaT, dtype=object)

    df = pd.DataFrame({
        "LATITUDE": lat_arr,
        "LONGITUDE": lon_arr,
        "JULD": juld_arr,
    })

    # Depth column
    depth_col_vals = None
    for dcol in ["PRES_ADJUSTED", "PRES"]:
        if dcol in ds:
            arr = np.asarray(ds[dcol].values)
            if arr.ndim == 2:
                depth_col_vals = arr.flatten()
            elif arr.ndim == 1:
                if arr.size == n_prof:
                    depth_col_vals = np.repeat(arr, n_level)
                elif arr.size == n_level:
                    depth_col_vals = np.tile(arr, n_prof)
            elif arr.ndim == 0:
                depth_col_vals = np.repeat(arr.item(), total_len)
            if depth_col_vals is not None:
                break
    df["DEPTH_M"] = depth_col_vals if depth_col_vals is not None else np.nan

    # Minimal variables
    for var in ["TEMP", "PSAL"]:
        if var in ds:
            arr = np.asarray(ds[var].values)
            if arr.ndim == 2 and arr.shape == (n_prof, n_level):
                df[var] = arr.flatten()
            elif arr.ndim == 1:
                if arr.size == n_prof:
                    df[var] = np.repeat(arr, n_level)
                elif arr.size == n_level:
                    df[var] = np.tile(arr, n_prof)
            elif arr.ndim == 0:
                df[var] = np.repeat(arr.item(), total_len)
            else:
                df[var] = np.nan
        else:
            df[var] = np.nan

    # Add source file
    df["source_file"] = source_file

    # Apply bbox filter
    df = df[(df["LATITUDE"].between(BBOX["lat_min"], BBOX["lat_max"])) &
            (df["LONGITUDE"].between(BBOX["lon_min"], BBOX["lon_max"]))]

    return df

# -----------------------
# Worker: download + flatten
# -----------------------
def process_file(file_url):
    try:
        with tempfile.NamedTemporaryFile(suffix=".nc") as tmp:
            with requests.get(file_url, stream=True, timeout=60) as r:
                r.raise_for_status()
                for chunk in r.iter_content(1024*1024):
                    tmp.write(chunk)
            tmp.flush()
            ds = open_dataset_safe(tmp.name)
            df = flatten_ds_minimal(ds, os.path.basename(file_url))
            ds.close()
            if df.empty:
                return None
            return df
    except Exception as e:
        print(f"⚠ Skipped {file_url}: {e}")
        return None

# -----------------------
# Main loop
# -----------------------
for year in YEARS:
    print(f"\n📂 Processing year: {year}")
    for month in MONTHS:
        url = f"{BASE_URL}{year}/{month}/"
        try:
            resp = requests.get(url, timeout=10)
            if resp.status_code != 200:
                print(f"  (No listing: {url})")
                continue
        except Exception as e:
            print(f"  (Request error: {url}): {e}")
            continue

        soup = BeautifulSoup(resp.text, "html.parser")
        files = [a.get('href') for a in soup.find_all('a') if a.get('href', '').endswith('.nc')]
        if not files:
            continue

        month_data = []

        if USE_PARALLEL:
            with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
                futures = {executor.submit(process_file, url + f): f for f in files}
                for future in as_completed(futures):
                    f = futures[future]
                    df = future.result()
                    if df is not None:
                        month_data.append(df)
                        print(f"    ✅ {f} | rows: {len(df)}")
                    else:
                        print(f"    ⚠ Skipped {f}: empty result")
        else:
            for f in files:
                df = process_file(url + f)
                if df is not None:
                    month_data.append(df)
                    print(f"    ✅ {f} | rows: {len(df)}")
                else:
                    print(f"    ⚠ Skipped {f}: empty result")

        # Save minimal data
        if month_data:
            final_df = pd.concat(month_data, ignore_index=True)
            if not final_df.empty:
                out_file = f"{OUT_DIR}/{year}_{month}_MINIMAL.parquet"
                final_df.to_parquet(out_file, index=False)
                print(f"  ✅ Saved: {out_file} | Shape: {final_df.shape}")
            else:
                print(f"  ⚠ No usable data for {year}-{month}")
        else:
            print(f"  ⚠ All files empty for {year}-{month}")

print("\n🎉 Prototype processing complete!")
# Out:
# 📂 Processing year: 2022
#     ✅ 20220102_prof.nc | rows: 45006
#     ✅ 20220104_prof.nc | rows: 50800
#     ✅ 20220101_prof.nc | rows: 37370
#     ✅ 20220103_prof.nc | rows: 39468
#     ✅ 20220110_prof.nc | rows: 42756
#     ✅ 20220107_prof.nc | rows: 39480
#     ✅ 20220108_prof.nc | rows: 49324
#     ✅ 20220109_prof.nc | rows: 49152
#     ✅ 20220113_prof.nc | rows: 36396
#     ✅ 20220114_prof.nc | rows: 50950
#     ✅ 20220112_prof.nc | rows: 50820
#     ✅ 20220111_prof.nc | rows: 31372
#     ✅ 20220118_prof.nc | rows: 45495
#     ✅ 20220115_prof.nc | rows: 55248
#     ✅ 20220117_prof.nc | rows: 38318
#     ✅ 20220120_prof.nc | rows: 48672
#     ✅ 20220119_prof.nc | rows: 48672
#     ✅ 20220121_prof.nc | rows: 36432
#     ✅ 20220123_prof.nc | rows: 38494
#     ✅ 20220122_prof.nc | rows: 47273
#     ✅ 20220124_prof.nc | rows: 51918
#     ✅ 20220106_prof.nc | rows: 54972
#     ✅ 20220105_prof.nc | rows: 54097
#     ✅ 20220125_prof.nc | rows: 55248
#     ✅ 20220126_prof.nc | rows: 56400
#     ✅ 20220128_prof.nc | rows: 42966
#     ✅ 20220127_prof.nc | rows: 37407
#     ✅ 20220129_prof.nc | rows: 46736
#     ✅ 20220130_prof.nc | rows: 41492
#     ✅ 20220131_prof.nc | rows: 41943
#     ✅ 20220116_prof.nc | rows: 59466
#   ✅ Saved: argo_prototype_parquet/2022_01_MINIMAL.parquet | Shape: (1424143, 7)
#     ✅ 20220201_prof.nc | rows: 46120
#     ✅ 20220205_prof.nc | rows: 49980
#     ✅ 20220203_prof.nc | rows: 55248
#     ✅ 20220204_prof.nc | rows: 57426
#     ✅ 20220206_prof.nc | rows: 36360
#     ✅ 20220209_prof.nc | rows: 42966
#     ✅ 20220210_prof.nc | rows: 38418
#     ✅ 20220207_prof.nc | rows: 43559
#     ✅ 20220208_prof.nc | rows: 41574
#     ✅ 20220211_prof.nc | rows: 53084
#     ✅ 20220212_prof.nc | rows: 34374
#     ✅ 20220213_prof.nc | rows: 59852
#     ✅ 20220215_prof.nc | rows: 46598
#     ✅ 20220214_prof.nc | rows: 52875
#     ✅ 20220216_prof.nc | rows: 40480
#     ✅ 20220217_prof.nc | rows: 44748
#     ✅ 20220219_prof.nc | rows: 41615
#     ✅ 20220218_prof.nc | rows: 41820
#     ✅ 20220222_prof.nc | rows: 47166
#     ✅ 20220223_prof.nc | rows: 61003
#     ✅ 20220224_prof.nc | rows: 46920
#     ✅ 20220225_prof.nc | rows: 43774
#     ✅ 20220227_prof.nc | rows: 40640
#     ✅ 20220226_prof.nc | rows: 35490
#     ✅ 20220202_prof.nc | rows: 39546
#     ✅ 20220228_prof.nc | rows: 41697
#     ✅ 20220220_prof.nc | rows: 42672
#     ✅ 20220221_prof.nc | rows: 53038
#   ✅ Saved: argo_prototype_parquet/2022_02_MINIMAL.parquet | Shape: (1279043, 7)
#     ✅ 20220301_prof.nc | rows: 37814
#     ✅ 20220302_prof.nc | rows: 44528
#     ✅ 20220303_prof.nc | rows: 50732
#     ✅ 20220304_prof.nc | rows: 47208
#     ✅ 20220306_prof.nc | rows: 45540
#     ✅ 20220307_prof.nc | rows: 49931
#     ✅ 20220309_prof.nc | rows: 38570
#     ✅ 20220310_prof.nc | rows: 45012
#     ✅ 20220311_prof.nc | rows: 35385
#     ✅ 20220314_prof.nc | rows: 35420
#     ✅ 20220312_prof.nc | rows: 45080
#     ✅ 20220315_prof.nc | rows: 57550
#     ✅ 20220317_prof.nc | rows: 47150
#     ✅ 20220316_prof.nc | rows: 43860
#     ✅ 20220319_prof.nc | rows: 42462
#     ✅ 20220318_prof.nc | rows: 41574
#     ✅ 20220321_prof.nc | rows: 42788
#     ✅ 20220322_prof.nc | rows: 49588
#     ✅ 20220323_prof.nc | rows: 52875
#     ✅ 20220305_prof.nc | rows: 56399
#     ✅ 20220326_prof.nc | rows: 46598
#     ✅ 20220313_prof.nc | rows: 53760
#     ✅ 20220308_prof.nc | rows: 37851
#     ✅ 20220328_prof.nc | rows: 37407
#     ✅ 20220329_prof.nc | rows: 45494
#     ✅ 20220320_prof.nc | rows: 44572
#     ✅ 20220331_prof.nc | rows: 40464
#     ✅ 20220330_prof.nc | rows: 54296
#     ✅ 20220324_prof.nc | rows: 34476
#     ✅ 20220325_prof.nc | rows: 49104
#     ✅ 20220327_prof.nc | rows: 42630
#   ✅ Saved: argo_prototype_parquet/2022_03_MINIMAL.parquet | Shape: (1396118, 7)
#     ✅ 20220403_prof.nc | rows: 43384
#     ✅ 20220401_prof.nc | rows: 68220
#     ✅ 20220406_prof.nc | rows: 52762
#     ✅ 20220404_prof.nc | rows: 67248
#     ✅ 20220402_prof.nc | rows: 92290
#     ✅ 20220407_prof.nc | rows: 43602
#     ✅ 20220409_prof.nc | rows: 46084
#     ✅ 20220410_prof.nc | rows: 38726
#     ✅ 20220411_prof.nc | rows: 45585
#     ✅ 20220412_prof.nc | rows: 44704
#     ✅ 20220413_prof.nc | rows: 31434
#     ✅ 20220414_prof.nc | rows: 45810
#     ✅ 20220415_prof.nc | rows: 46552
#     ✅ 20220418_prof.nc | rows: 53952
#     ✅ 20220416_prof.nc | rows: 46035
#     ✅ 20220417_prof.nc | rows: 39507
#     ✅ 20220419_prof.nc | rows: 47838
#     ✅ 20220422_prof.nc | rows: 48676
#     ✅ 20220423_prof.nc | rows: 37455
#     ✅ 20220421_prof.nc | rows: 45200
#     ✅ 20220424_prof.nc | rows: 49456
#     ✅ 20220425_prof.nc | rows: 53063
#     ✅ 20220426_prof.nc | rows: 49368
#     ✅ 20220429_prof.nc | rows: 36504
#     ✅ 20220428_prof.nc | rows: 48590
#     ✅ 20220427_prof.nc | rows: 46166
#     ✅ 20220405_prof.nc | rows: 59760
#     ✅ 20220408_prof.nc | rows: 45540
#     ✅ 20220420_prof.nc | rows: 45560
#     ✅ 20220430_prof.nc | rows: 46699
#   ✅ Saved: argo_prototype_parquet/2022_04_MINIMAL.parquet | Shape: (1465770, 7)
#     ✅ 20220502_prof.nc | rows: 39819
#     ✅ 20220501_prof.nc | rows: 41492
#     ✅ 20220504_prof.nc | rows: 46782
#     ✅ 20220506_prof.nc | rows: 51750
#     ✅ 20220510_prof.nc | rows: 44572
#     ✅ 20220508_prof.nc | rows: 42143
#     ✅ 20220509_prof.nc | rows: 40480
#     ✅ 20220507_prof.nc | rows: 37814
#     ✅ 20220514_prof.nc | rows: 42924
#     ✅ 20220513_prof.nc | rows: 37481
#     ✅ 20220511_prof.nc | rows: 45560
#     ✅ 20220515_prof.nc | rows: 50580
#     ✅ 20220517_prof.nc | rows: 42636
#     ✅ 20220518_prof.nc | rows: 47386
#     ✅ 20220520_prof.nc | rows: 42840
#     ✅ 20220521_prof.nc | rows: 55811
#     ✅ 20220505_prof.nc | rows: 47564
#     ✅ 20220503_prof.nc | rows: 34782
#     ✅ 20220522_prof.nc | rows: 36576
#     ✅ 20220523_prof.nc | rows: 40560
#     ✅ 20220524_prof.nc | rows: 47940
#     ✅ 20220512_prof.nc | rows: 37592
#     ✅ 20220526_prof.nc | rows: 48289
#     ✅ 20220527_prof.nc | rows: 35805
#     ✅ 20220528_prof.nc | rows: 39865
#     ✅ 20220530_prof.nc | rows: 46699
#     ✅ 20220516_prof.nc | rows: 51704
#     ✅ 20220531_prof.nc | rows: 50116
#     ✅ 20220519_prof.nc | rows: 46699
#     ✅ 20220525_prof.nc | rows: 51750
#     ✅ 20220529_prof.nc | rows: 41656
#   ✅ Saved: argo_prototype_parquet/2022_05_MINIMAL.parquet | Shape: (1367667, 7)
#     ✅ 20220601_prof.nc | rows: 36720
#     ✅ 20220602_prof.nc | rows: 39858
#     ✅ 20220605_prof.nc | rows: 44800
#     ✅ 20220604_prof.nc | rows: 45495
#     ✅ 20220603_prof.nc | rows: 54000
#     ✅ 20220606_prof.nc | rows: 33363
#     ✅ 20220607_prof.nc | rows: 43282
#     ✅ 20220608_prof.nc | rows: 40680
#     ✅ 20220611_prof.nc | rows: 37851
#     ✅ 20220609_prof.nc | rows: 51255
#     ✅ 20220612_prof.nc | rows: 48375
#     ✅ 20220610_prof.nc | rows: 45560
#     ✅ 20220613_prof.nc | rows: 45056
#     ✅ 20220615_prof.nc | rows: 37407
#     ✅ 20220614_prof.nc | rows: 49412
#     ✅ 20220617_prof.nc | rows: 53120
#     ✅ 20220616_prof.nc | rows: 32448
#     ✅ 20220621_prof.nc | rows: 42143
#     ✅ 20220619_prof.nc | rows: 58740
#     ✅ 20220620_prof.nc | rows: 53703
#     ✅ 20220623_prof.nc | rows: 51566
#     ✅ 20220622_prof.nc | rows: 60852
#     ✅ 20220624_prof.nc | rows: 51568
#     ✅ 20220625_prof.nc | rows: 49140
#     ✅ 20220628_prof.nc | rows: 54780
#     ✅ 20220626_prof.nc | rows: 31620
#     ✅ 20220629_prof.nc | rows: 55309
#     ✅ 20220630_prof.nc | rows: 54800
#     ✅ 20220618_prof.nc | rows: 56655
#     ✅ 20220627_prof.nc | rows: 50578
#   ✅ Saved: argo_prototype_parquet/2022_06_MINIMAL.parquet | Shape: (1410136, 7)
#     ✅ 20220703_prof.nc | rows: 51658
#     ✅ 20220704_prof.nc | rows: 51030
#     ✅ 20220705_prof.nc | rows: 48867
#     ✅ 20220702_prof.nc | rows: 65712
#     ✅ 20220706_prof.nc | rows: 32416
#     ✅ 20220708_prof.nc | rows: 46472
#     ✅ 20220707_prof.nc | rows: 52160
#     ✅ 20220710_prof.nc | rows: 53469
#     ✅ 20220711_prof.nc | rows: 43282
#     ✅ 20220713_prof.nc | rows: 42672
#     ✅ 20220712_prof.nc | rows: 60808
#     ✅ 20220714_prof.nc | rows: 54225
#     ✅ 20220718_prof.nc | rows: 47034
#     ✅ 20220717_prof.nc | rows: 61248
#     ✅ 20220716_prof.nc | rows: 29406
#     ✅ 20220719_prof.nc | rows: 44920
#     ✅ 20220721_prof.nc | rows: 44421
#     ✅ 20220720_prof.nc | rows: 58996
#     ✅ 20220723_prof.nc | rows: 47846
#     ✅ 20220722_prof.nc | rows: 58824
#     ✅ 20220724_prof.nc | rows: 55982
#     ✅ 20220725_prof.nc | rows: 46287
#     ✅ 20220726_prof.nc | rows: 30390
#     ✅ 20220727_prof.nc | rows: 55814
#     ✅ 20220701_prof.nc | rows: 41004
#     ✅ 20220728_prof.nc | rows: 52603
#     ✅ 20220730_prof.nc | rows: 56334
#     ✅ 20220731_prof.nc | rows: 44421
#     ✅ 20220709_prof.nc | rows: 56616
#     ✅ 20220715_prof.nc | rows: 45144
#     ✅ 20220729_prof.nc | rows: 39468
#   ✅ Saved: argo_prototype_parquet/2022_07_MINIMAL.parquet | Shape: (1519529, 7)
#     ✅ 20220803_prof.nc | rows: 48280
#     ✅ 20220802_prof.nc | rows: 45585
#     ✅ 20220804_prof.nc | rows: 50184
#     ✅ 20220806_prof.nc | rows: 52521
#     ✅ 20220801_prof.nc | rows: 54320
#     ✅ 20220805_prof.nc | rows: 30360
#     ✅ 20220808_prof.nc | rows: 37481
#     ✅ 20220807_prof.nc | rows: 51480
#     ✅ 20220810_prof.nc | rows: 55200
#     ✅ 20220812_prof.nc | rows: 63112
#     ✅ 20220809_prof.nc | rows: 51675
#     ✅ 20220813_prof.nc | rows: 45103
#     ✅ 20220814_prof.nc | rows: 50000
#     ✅ 20220817_prof.nc | rows: 51742
#     ✅ 20220816_prof.nc | rows: 57640
#     ✅ 20220815_prof.nc | rows: 35595
#     ✅ 20220818_prof.nc | rows: 41440
#     ✅ 20220820_prof.nc | rows: 46818
#     ✅ 20220822_prof.nc | rows: 64907
#     ✅ 20220821_prof.nc | rows: 47838
#     ✅ 20220819_prof.nc | rows: 53880
#     ✅ 20220823_prof.nc | rows: 39429
#     ✅ 20220824_prof.nc | rows: 47462
#     ✅ 20220826_prof.nc | rows: 51560
#     ✅ 20220825_prof.nc | rows: 43758
#     ✅ 20220828_prof.nc | rows: 31496
#     ✅ 20220829_prof.nc | rows: 52689
#     ✅ 20220830_prof.nc | rows: 46886
#     ✅ 20220831_prof.nc | rows: 44421
#     ✅ 20220811_prof.nc | rows: 48977
#     ✅ 20220827_prof.nc | rows: 53550
#   ✅ Saved: argo_prototype_parquet/2022_08_MINIMAL.parquet | Shape: (1495389, 7)
#     ✅ 20220902_prof.nc | rows: 35700
#     ✅ 20220906_prof.nc | rows: 40392
#     ✅ 20220901_prof.nc | rows: 63434
#     ✅ 20220904_prof.nc | rows: 33330
#     ✅ 20220907_prof.nc | rows: 34476
#     ✅ 20220909_prof.nc | rows: 44096
#     ✅ 20220908_prof.nc | rows: 45832
#     ✅ 20220910_prof.nc | rows: 42143
#     ✅ 20220912_prof.nc | rows: 41551
#     ✅ 20220914_prof.nc | rows: 44850
#     ✅ 20220915_prof.nc | rows: 57596
#     ✅ 20220916_prof.nc | rows: 36448
#     ✅ 20220917_prof.nc | rows: 37444
#     ✅ 20220918_prof.nc | rows: 47110
#     ✅ 20220919_prof.nc | rows: 39865
#     ✅ 20220920_prof.nc | rows: 54240
#     ✅ 20220921_prof.nc | rows: 55320
#     ✅ 20220922_prof.nc | rows: 44920
#     ✅ 20220923_prof.nc | rows: 40293
#     ✅ 20220903_prof.nc | rows: 46371
#     ✅ 20220905_prof.nc | rows: 51800
#     ✅ 20220925_prof.nc | rows: 49210
#     ✅ 20220926_prof.nc | rows: 38726
#     ✅ 20220927_prof.nc | rows: 34680
#     ✅ 20220929_prof.nc | rows: 41004
#     ✅ 20220913_prof.nc | rows: 46254
#     ✅ 20220911_prof.nc | rows: 61028
#     ✅ 20220928_prof.nc | rows: 37408
#     ✅ 20220924_prof.nc | rows: 42770
#     ✅ 20220930_prof.nc | rows: 56293
#   ✅ Saved: argo_prototype_parquet/2022_09_MINIMAL.parquet | Shape: (1344584, 7)
#     ✅ 20221002_prof.nc | rows: 37407
#     ✅ 20221003_prof.nc | rows: 43920
#     ✅ 20221005_prof.nc | rows: 51920
#     ✅ 20221006_prof.nc | rows: 38726
#     ✅ 20221001_prof.nc | rows: 54015
#     ✅ 20221004_prof.nc | rows: 38182
#     ✅ 20221007_prof.nc | rows: 32416
#     ✅ 20221008_prof.nc | rows: 44649
#     ✅ 20221009_prof.nc | rows: 38726
#     ✅ 20221012_prof.nc | rows: 46246
#     ✅ 20221011_prof.nc | rows: 52630
#     ✅ 20221010_prof.nc | rows: 64202
#     ✅ 20221013_prof.nc | rows: 37026
#     ✅ 20221014_prof.nc | rows: 55019
#     ✅ 20221016_prof.nc | rows: 62156
#     ✅ 20221017_prof.nc | rows: 47838
#     ✅ 20221018_prof.nc | rows: 68456
#     ✅ 20221015_prof.nc | rows: 65274
#     ✅ 20221019_prof.nc | rows: 81122
#     ✅ 20221020_prof.nc | rows: 61740
#     ✅ 20221021_prof.nc | rows: 54120
#     ✅ 20221024_prof.nc | rows: 49282
#     ✅ 20221022_prof.nc | rows: 68061
#     ✅ 20221025_prof.nc | rows: 52680
#     ✅ 20221027_prof.nc | rows: 36648
#     ✅ 20221026_prof.nc | rows: 63180
#     ✅ 20221029_prof.nc | rows: 87880
#     ✅ 20221030_prof.nc | rows: 60660
#     ✅ 20221031_prof.nc | rows: 50881
#     ✅ 20221023_prof.nc | rows: 39372
#     ✅ 20221028_prof.nc | rows: 77602
#   ✅ Saved: argo_prototype_parquet/2022_10_MINIMAL.parquet | Shape: (1662036, 7)
#     ✅ 20221106_prof.nc | rows: 30360
#     ✅ 20221102_prof.nc | rows: 42264
#     ✅ 20221103_prof.nc | rows: 46822
#     ✅ 20221104_prof.nc | rows: 57552
#     ✅ 20221105_prof.nc | rows: 65833
#     ✅ 20221109_prof.nc | rows: 57582
#     ✅ 20221108_prof.nc | rows: 71252
#     ✅ 20221111_prof.nc | rows: 60676
#     ✅ 20221112_prof.nc | rows: 28539
#     ✅ 20221113_prof.nc | rows: 46605
#     ✅ 20221114_prof.nc | rows: 50973
#     ✅ 20221115_prof.nc | rows: 60840
#     ✅ 20221116_prof.nc | rows: 43848
#     ✅ 20221117_prof.nc | rows: 48913
#     ✅ 20221118_prof.nc | rows: 61758
#     ✅ 20221119_prof.nc | rows: 56718
#     ✅ 20221120_prof.nc | rows: 57204
#     ✅ 20221121_prof.nc | rows: 69350
#     ✅ 20221122_prof.nc | rows: 40936
#     ✅ 20221123_prof.nc | rows: 45030
#     ✅ 20221124_prof.nc | rows: 39240
#     ✅ 20221125_prof.nc | rows: 76995
#     ✅ 20221126_prof.nc | rows: 48332
#     ✅ 20221128_prof.nc | rows: 85913
#     ✅ 20221129_prof.nc | rows: 50512
#     ✅ 20221110_prof.nc | rows: 43020
#     ✅ 20221107_prof.nc | rows: 47541
#     ✅ 20221101_prof.nc | rows: 69100
#     ✅ 20221130_prof.nc | rows: 60500
#     ✅ 20221127_prof.nc | rows: 54050
#   ✅ Saved: argo_prototype_parquet/2022_11_MINIMAL.parquet | Shape: (1618258, 7)
#     ✅ 20221202_prof.nc | rows: 37764
#     ✅ 20221203_prof.nc | rows: 47766
#     ✅ 20221204_prof.nc | rows: 40548
#     ✅ 20221205_prof.nc | rows: 70965
#     ✅ 20221201_prof.nc | rows: 66640
#     ✅ 20221210_prof.nc | rows: 64860
#     ✅ 20221207_prof.nc | rows: 52290
#     ✅ 20221208_prof.nc | rows: 82674
#     ✅ 20221211_prof.nc | rows: 76120
#     ✅ 20221212_prof.nc | rows: 38480
#     ✅ 20221213_prof.nc | rows: 51455
#     ✅ 20221214_prof.nc | rows: 39390
#     ✅ 20221216_prof.nc | rows: 42180
#     ✅ 20221217_prof.nc | rows: 49493
#     ✅ 20221218_prof.nc | rows: 83800
#     ✅ 20221219_prof.nc | rows: 44067
#     ✅ 20221220_prof.nc | rows: 60456
#     ✅ 20221221_prof.nc | rows: 57454
#     ✅ 20221222_prof.nc | rows: 50986
#     ✅ 20221223_prof.nc | rows: 43524
#     ✅ 20221224_prof.nc | rows: 39090
#     ✅ 20221206_prof.nc | rows: 37629
#     ✅ 20221226_prof.nc | rows: 37629
#     ✅ 20221225_prof.nc | rows: 72680
#     ✅ 20221229_prof.nc | rows: 44881
#     ✅ 20221230_prof.nc | rows: 56375
#     ✅ 20221228_prof.nc | rows: 79478
#     ✅ 20221209_prof.nc | rows: 44696
#     ✅ 20221215_prof.nc | rows: 75938
#     ✅ 20221227_prof.nc | rows: 49854
#     ✅ 20221231_prof.nc | rows: 93330
#   ✅ Saved: argo_prototype_parquet/2022_12_MINIMAL.parquet | Shape: (1732492, 7)
#
# 📂 Processing year: 2023
#     ✅ 20230105_prof.nc | rows: 40052
#     ✅ 20230102_prof.nc | rows: 45375
#     ✅ 20230101_prof.nc | rows: 54920
#     ✅ 20230106_prof.nc | rows: 61302
#     ✅ 20230103_prof.nc | rows: 36400
#     ✅ 20230104_prof.nc | rows: 65120
#     ✅ 20230109_prof.nc | rows: 43080
#     ✅ 20230108_prof.nc | rows: 46474
#     ✅ 20230107_prof.nc | rows: 86710
#     ✅ 20230112_prof.nc | rows: 38612
#     ✅ 20230110_prof.nc | rows: 65572
#     ✅ 20230117_prof.nc | rows: 78480
#     ✅ 20230118_prof.nc | rows: 40996
#     ✅ 20230119_prof.nc | rows: 41943
#     ✅ 20230120_prof.nc | rows: 65832
#     ✅ 20230121_prof.nc | rows: 49284
#     ✅ 20230122_prof.nc | rows: 44032
#     ✅ 20230123_prof.nc | rows: 42570
#     ✅ 20230115_prof.nc | rows: 41312
#     ✅ 20230111_prof.nc | rows: 54800
#     ✅ 20230125_prof.nc | rows: 48184
#     ✅ 20230124_prof.nc | rows: 55209
#     ✅ 20230113_prof.nc | rows: 38370
#     ✅ 20230126_prof.nc | rows: 55836
#     ✅ 20230127_prof.nc | rows: 79464
#     ✅ 20230116_prof.nc | rows: 64428
#     ✅ 20230129_prof.nc | rows: 40760
#     ✅ 20230114_prof.nc | rows: 68524
#     ✅ 20230130_prof.nc | rows: 65884
#     ✅ 20230131_prof.nc | rows: 50875
#     ✅ 20230128_prof.nc | rows: 36540
#   ✅ Saved: argo_prototype_parquet/2023_01_MINIMAL.parquet | Shape: (1646940, 7)
#     ✅ 20230204_prof.nc | rows: 43296
#     ✅ 20230205_prof.nc | rows: 57648
#     ✅ 20230203_prof.nc | rows: 56761
#     ✅ 20230209_prof.nc | rows: 77300
#     ✅ 20230210_prof.nc | rows: 58266
#     ✅ 20230211_prof.nc | rows: 41582
#     ✅ 20230212_prof.nc | rows: 45008
#     ✅ 20230213_prof.nc | rows: 62240
#     ✅ 20230214_prof.nc | rows: 41856
#     ✅ 20230201_prof.nc | rows: 45507
#     ✅ 20230215_prof.nc | rows: 81692
#     ✅ 20230202_prof.nc | rows: 38338
#     ✅ 20230216_prof.nc | rows: 72360
#     ✅ 20230208_prof.nc | rows: 47249
#     ✅ 20230206_prof.nc | rows: 76956
#     ✅ 20230207_prof.nc | rows: 54775
#     ✅ 20230218_prof.nc | rows: 42630
#     ✅ 20230220_prof.nc | rows: 57246
#     ✅ 20230221_prof.nc | rows: 36482
#     ✅ 20230223_prof.nc | rows: 65208
#     ✅ 20230224_prof.nc | rows: 39680
#     ✅ 20230225_prof.nc | rows: 63070
#     ✅ 20230227_prof.nc | rows: 47320
#     ✅ 20230226_prof.nc | rows: 89505
#     ✅ 20230228_prof.nc | rows: 43731
#     ✅ 20230219_prof.nc | rows: 52844
#     ✅ 20230217_prof.nc | rows: 49839
#     ✅ 20230222_prof.nc | rows: 37071
#   ✅ Saved: argo_prototype_parquet/2023_02_MINIMAL.parquet | Shape: (1525460, 7)
#     ✅ 20230301_prof.nc | rows: 44460
#     ✅ 20230306_prof.nc | rows: 40610
#     ✅ 20230304_prof.nc | rows: 44128
#     ✅ 20230302_prof.nc | rows: 52500
#     ✅ 20230305_prof.nc | rows: 56595
#     ✅ 20230310_prof.nc | rows: 44032
#     ✅ 20230307_prof.nc | rows: 62222
#     ✅ 20230311_prof.nc | rows: 44878
#     ✅ 20230312_prof.nc | rows: 46139
#     ✅ 20230313_prof.nc | rows: 42346
#     ✅ 20230314_prof.nc | rows: 46886
#     ✅ 20230317_prof.nc | rows: 55272
#     ✅ 20230316_prof.nc | rows: 48544
#     ✅ 20230318_prof.nc | rows: 77700
#     ✅ 20230320_prof.nc | rows: 50106
#     ✅ 20230303_prof.nc | rows: 39962
#     ✅ 20230321_prof.nc | rows: 48260
#     ✅ 20230309_prof.nc | rows: 55522
#     ✅ 20230322_prof.nc | rows: 45066
#     ✅ 20230323_prof.nc | rows: 39527
#     ✅ 20230324_prof.nc | rows: 45356
#     ✅ 20230325_prof.nc | rows: 58443
#     ✅ 20230326_prof.nc | rows: 47160
#     ✅ 20230327_prof.nc | rows: 59517
#     ✅ 20230308_prof.nc | rows: 75250
#     ✅ 20230328_prof.nc | rows: 66115
#     ✅ 20230319_prof.nc | rows: 55685
#     ✅ 20230329_prof.nc | rows: 50966
#     ✅ 20230331_prof.nc | rows: 39168
#     ✅ 20230315_prof.nc | rows: 50112
#     ✅ 20230330_prof.nc | rows: 51772
#   ✅ Saved: argo_prototype_parquet/2023_03_MINIMAL.parquet | Shape: (1584299, 7)
#     ✅ 20230406_prof.nc | rows: 59517
#     ✅ 20230402_prof.nc | rows: 32520
#     ✅ 20230401_prof.nc | rows: 44520
#     ✅ 20230403_prof.nc | rows: 52288
#     ✅ 20230409_prof.nc | rows: 43602
#     ✅ 20230408_prof.nc | rows: 54575
#     ✅ 20230407_prof.nc | rows: 58752
#     ✅ 20230412_prof.nc | rows: 37152
#     ✅ 20230411_prof.nc | rows: 50728
#     ✅ 20230413_prof.nc | rows: 43554
#     ✅ 20230416_prof.nc | rows: 65136
#     ✅ 20230415_prof.nc | rows: 56004
#     ✅ 20230414_prof.nc | rows: 51677
#     ✅ 20230419_prof.nc | rows: 42107
#     ✅ 20230418_prof.nc | rows: 59592
#     ✅ 20230417_prof.nc | rows: 78273
#     ✅ 20230420_prof.nc | rows: 41436
#     ✅ 20230422_prof.nc | rows: 41370
#     ✅ 20230421_prof.nc | rows: 60480
#     ✅ 20230423_prof.nc | rows: 51480
#     ✅ 20230425_prof.nc | rows: 57288
#     ✅ 20230424_prof.nc | rows: 52992
#     ✅ 20230410_prof.nc | rows: 39134
#     ✅ 20230426_prof.nc | rows: 59125
#     ✅ 20230428_prof.nc | rows: 55227
#     ✅ 20230405_prof.nc | rows: 50427
#     ✅ 20230427_prof.nc | rows: 82216
#     ✅ 20230430_prof.nc | rows: 44472
#     ✅ 20230404_prof.nc | rows: 59310
#     ✅ 20230429_prof.nc | rows: 43700
#   ✅ Saved: argo_prototype_parquet/2023_04_MINIMAL.parquet | Shape: (1568654, 7)
#     ✅ 20230502_prof.nc | rows: 35594
#     ✅ 20230506_prof.nc | rows: 53781
#     ✅ 20230505_prof.nc | rows: 48544
#     ✅ 20230501_prof.nc | rows: 47880
#     ✅ 20230503_prof.nc | rows: 57332
#     ✅ 20230504_prof.nc | rows: 67944
#     ✅ 20230508_prof.nc | rows: 58050
#     ✅ 20230510_prof.nc | rows: 46768
#     ✅ 20230509_prof.nc | rows: 59220
#     ✅ 20230511_prof.nc | rows: 45243
#     ✅ 20230512_prof.nc | rows: 41616
#     ✅ 20230507_prof.nc | rows: 82720
#     ✅ 20230513_prof.nc | rows: 53680
#     ✅ 20230518_prof.nc | rows: 47232
#     ✅ 20230516_prof.nc | rows: 53625
#     ✅ 20230514_prof.nc | rows: 80346
#     ✅ 20230517_prof.nc | rows: 90640
#     ✅ 20230520_prof.nc | rows: 37518
#     ✅ 20230521_prof.nc | rows: 65305
#     ✅ 20230523_prof.nc | rows: 56539
#     ✅ 20230526_prof.nc | rows: 48636
#     ✅ 20230525_prof.nc | rows: 52592
#     ✅ 20230528_prof.nc | rows: 52440
#     ✅ 20230527_prof.nc | rows: 96880
#     ✅ 20230529_prof.nc | rows: 59312
#     ✅ 20230530_prof.nc | rows: 38570
#     ✅ 20230531_prof.nc | rows: 73164
#     ✅ 20230515_prof.nc | rows: 47088
#     ✅ 20230519_prof.nc | rows: 57964
#     ✅ 20230522_prof.nc | rows: 30625
#     ✅ 20230524_prof.nc | rows: 93248
#   ✅ Saved: argo_prototype_parquet/2023_05_MINIMAL.parquet | Shape: (1780096, 7)
#     ✅ 20230602_prof.nc | rows: 53820
#     ✅ 20230604_prof.nc | rows: 45675
#     ✅ 20230605_prof.nc | rows: 75852
#     ✅ 20230603_prof.nc | rows: 110520
#     ✅ 20230607_prof.nc | rows: 60122
#     ✅ 20230609_prof.nc | rows: 42315
#     ✅ 20230608_prof.nc | rows: 60750
#     ✅ 20230610_prof.nc | rows: 50502
#     ✅ 20230611_prof.nc | rows: 42870
#     ✅ 20230612_prof.nc | rows: 54390
#     ✅ 20230614_prof.nc | rows: 48433
#     ✅ 20230613_prof.nc | rows: 90695
#     ✅ 20230615_prof.nc | rows: 40760
#     ✅ 20230617_prof.nc | rows: 54432
#     ✅ 20230616_prof.nc | rows: 96725
#     ✅ 20230619_prof.nc | rows: 44802
#     ✅ 20230620_prof.nc | rows: 55831
#     ✅ 20230623_prof.nc | rows: 95032
#     ✅ 20230624_prof.nc | rows: 44870
#     ✅ 20230601_prof.nc | rows: 34776
#     ✅ 20230625_prof.nc | rows: 37666
#     ✅ 20230627_prof.nc | rows: 56373
#     ✅ 20230606_prof.nc | rows: 97794
#     ✅ 20230628_prof.nc | rows: 49876
#     ✅ 20230629_prof.nc | rows: 48321
#     ✅ 20230618_prof.nc | rows: 64896
#     ✅ 20230621_prof.nc | rows: 42625
#     ✅ 20230622_prof.nc | rows: 50690
#     ✅ 20230626_prof.nc | rows: 85632
#     ✅ 20230630_prof.nc | rows: 48280
#   ✅ Saved: argo_prototype_parquet/2023_06_MINIMAL.parquet | Shape: (1785325, 7)
#     ✅ 20230705_prof.nc | rows: 37851
#     ✅ 20230702_prof.nc | rows: 49536
#     ✅ 20230703_prof.nc | rows: 97632
#     ✅ 20230704_prof.nc | rows: 49742
#     ✅ 20230701_prof.nc | rows: 42150
#     ✅ 20230710_prof.nc | rows: 43470
#     ✅ 20230711_prof.nc | rows: 37874
#     ✅ 20230712_prof.nc | rows: 54036
#     ✅ 20230706_prof.nc | rows: 94536
#     ✅ 20230708_prof.nc | rows: 60615
#     ✅ 20230707_prof.nc | rows: 57508
#     ✅ 20230715_prof.nc | rows: 32416
#     ✅ 20230714_prof.nc | rows: 56244
#     ✅ 20230713_prof.nc | rows: 77873
#     ✅ 20230717_prof.nc | rows: 56029
#     ✅ 20230716_prof.nc | rows: 87669
#     ✅ 20230719_prof.nc | rows: 47120
#     ✅ 20230718_prof.nc | rows: 64896
#     ✅ 20230720_prof.nc | rows: 50076
#     ✅ 20230721_prof.nc | rows: 40672
#     ✅ 20230722_prof.nc | rows: 44955
#     ✅ 20230725_prof.nc | rows: 36320
#     ✅ 20230724_prof.nc | rows: 64239
#     ✅ 20230723_prof.nc | rows: 72908
#     ✅ 20230709_prof.nc | rows: 56144
#     ✅ 20230726_prof.nc | rows: 68640
#     ✅ 20230727_prof.nc | rows: 55986
#     ✅ 20230728_prof.nc | rows: 63020
#     ✅ 20230730_prof.nc | rows: 44380
#     ✅ 20230731_prof.nc | rows: 43098
#     ✅ 20230729_prof.nc | rows: 48375
#   ✅ Saved: argo_prototype_parquet/2023_07_MINIMAL.parquet | Shape: (1736010, 7)
#     ✅ 20230804_prof.nc | rows: 35872
#     ✅ 20230806_prof.nc | rows: 38570
#     ✅ 20230803_prof.nc | rows: 61088
#     ✅ 20230802_prof.nc | rows: 77264
#     ✅ 20230808_prof.nc | rows: 43559
#     ✅ 20230807_prof.nc | rows: 62928
#     ✅ 20230810_prof.nc | rows: 50680
#     ✅ 20230811_prof.nc | rows: 67284
#     ✅ 20230812_prof.nc | rows: 65919
#     ✅ 20230813_prof.nc | rows: 67983
#     ✅ 20230815_prof.nc | rows: 57464
#     ✅ 20230817_prof.nc | rows: 53815
#     ✅ 20230801_prof.nc | rows: 45430
#     ✅ 20230805_prof.nc | rows: 94503
#     ✅ 20230809_prof.nc | rows: 51012
#     ✅ 20230820_prof.nc | rows: 49284
#     ✅ 20230821_prof.nc | rows: 42455
#     ✅ 20230814_prof.nc | rows: 45258
#     ✅ 20230816_prof.nc | rows: 52288
#     ✅ 20230823_prof.nc | rows: 63744
#     ✅ 20230824_prof.nc | rows: 44200
#     ✅ 20230818_prof.nc | rows: 51946
#     ✅ 20230825_prof.nc | rows: 56158
#     ✅ 20230826_prof.nc | rows: 49644
#     ✅ 20230828_prof.nc | rows: 49320
#     ✅ 20230830_prof.nc | rows: 43715
#     ✅ 20230831_prof.nc | rows: 40970
#     ✅ 20230819_prof.nc | rows: 52416
#     ✅ 20230822_prof.nc | rows: 64395
#     ✅ 20230827_prof.nc | rows: 59731
#     ✅ 20230829_prof.nc | rows: 55734
#   ✅ Saved: argo_prototype_parquet/2023_08_MINIMAL.parquet | Shape: (1694629, 7)
#     ✅ 20230902_prof.nc | rows: 55776
#     ✅ 20230903_prof.nc | rows: 40557
#     ✅ 20230904_prof.nc | rows: 59928
#     ✅ 20230901_prof.nc | rows: 62865
#     ✅ 20230907_prof.nc | rows: 57204
#     ✅ 20230908_prof.nc | rows: 65121
#     ✅ 20230910_prof.nc | rows: 54480
#     ✅ 20230913_prof.nc | rows: 41072
#     ✅ 20230906_prof.nc | rows: 55488
#     ✅ 20230905_prof.nc | rows: 61965
#     ✅ 20230915_prof.nc | rows: 52440
#     ✅ 20230912_prof.nc | rows: 51948
#     ✅ 20230909_prof.nc | rows: 43044
#     ✅ 20230916_prof.nc | rows: 46080
#     ✅ 20230917_prof.nc | rows: 49032
#     ✅ 20230919_prof.nc | rows: 60288
#     ✅ 20230920_prof.nc | rows: 42210
#     ✅ 20230911_prof.nc | rows: 60312
#     ✅ 20230921_prof.nc | rows: 70312
#     ✅ 20230923_prof.nc | rows: 41551
#     ✅ 20230924_prof.nc | rows: 57420
#     ✅ 20230925_prof.nc | rows: 46920
#     ✅ 20230927_prof.nc | rows: 44814
#     ✅ 20230928_prof.nc | rows: 75582
#     ✅ 20230929_prof.nc | rows: 46930
#     ✅ 20230914_prof.nc | rows: 56631
#     ✅ 20230930_prof.nc | rows: 48720
#     ✅ 20230926_prof.nc | rows: 46690
#     ✅ 20230918_prof.nc | rows: 66542
#     ✅ 20230922_prof.nc | rows: 53480
#   ✅ Saved: argo_prototype_parquet/2023_09_MINIMAL.parquet | Shape: (1615402, 7)
#     ✅ 20231003_prof.nc | rows: 37888
#     ✅ 20231006_prof.nc | rows: 53268
#     ✅ 20231007_prof.nc | rows: 47600
#     ✅ 20231008_prof.nc | rows: 67000
#     ✅ 20231009_prof.nc | rows: 47386
#     ✅ 20231010_prof.nc | rows: 58368
#     ✅ 20231011_prof.nc | rows: 52041
#     ✅ 20231012_prof.nc | rows: 61785
#     ✅ 20231013_prof.nc | rows: 37587
#     ✅ 20231015_prof.nc | rows: 40722
#     ✅ 20231016_prof.nc | rows: 60500
#     ✅ 20231001_prof.nc | rows: 48342
#     ✅ 20231005_prof.nc | rows: 49464
#     ✅ 20231004_prof.nc | rows: 59984
#     ✅ 20231002_prof.nc | rows: 56211
#     ✅ 20231019_prof.nc | rows: 54045
#     ✅ 20231020_prof.nc | rows: 56718
#     ✅ 20231021_prof.nc | rows: 57240
#     ✅ 20231022_prof.nc | rows: 46444
#     ✅ 20231024_prof.nc | rows: 52931
#     ✅ 20231026_prof.nc | rows: 86619
#     ✅ 20231014_prof.nc | rows: 63553
#     ✅ 20231027_prof.nc | rows: 78584
#     ✅ 20231028_prof.nc | rows: 73226
#     ✅ 20231029_prof.nc | rows: 101800
#     ✅ 20231017_prof.nc | rows: 52728
#     ✅ 20231030_prof.nc | rows: 100896
#     ✅ 20231031_prof.nc | rows: 101426
#     ✅ 20231018_prof.nc | rows: 53440
#     ✅ 20231023_prof.nc | rows: 47229
#     ✅ 20231025_prof.nc | rows: 52920
#   ✅ Saved: argo_prototype_parquet/2023_10_MINIMAL.parquet | Shape: (1857945, 7)
#     ✅ 20231104_prof.nc | rows: 40520
#     ✅ 20231105_prof.nc | rows: 55240
#     ✅ 20231106_prof.nc | rows: 53840
#     ✅ 20231101_prof.nc | rows: 66432
#     ✅ 20231102_prof.nc | rows: 92664
#     ✅ 20231107_prof.nc | rows: 55614
#     ✅ 20231108_prof.nc | rows: 56917
#     ✅ 20231111_prof.nc | rows: 50653
#     ✅ 20231109_prof.nc | rows: 51373
#     ✅ 20231110_prof.nc | rows: 45832
#     ✅ 20231112_prof.nc | rows: 45864
#     ✅ 20231115_prof.nc | rows: 59125
#     ✅ 20231116_prof.nc | rows: 47145
#     ✅ 20231113_prof.nc | rows: 106080
#     ✅ 20231117_prof.nc | rows: 56975
#     ✅ 20231118_prof.nc | rows: 48320
#     ✅ 20231119_prof.nc | rows: 60466
#     ✅ 20231120_prof.nc | rows: 55907
#     ✅ 20231121_prof.nc | rows: 52212
#     ✅ 20231122_prof.nc | rows: 50154
#     ✅ 20231124_prof.nc | rows: 45436
#     ✅ 20231123_prof.nc | rows: 98700
#     ✅ 20231125_prof.nc | rows: 66240
#     ✅ 20231126_prof.nc | rows: 47320
#     ✅ 20231128_prof.nc | rows: 44928
#     ✅ 20231127_prof.nc | rows: 54894
#     ✅ 20231129_prof.nc | rows: 60583
#     ✅ 20231103_prof.nc | rows: 103494
#     ✅ 20231114_prof.nc | rows: 47680
#     ✅ 20231130_prof.nc | rows: 52250
#   ✅ Saved: argo_prototype_parquet/2023_11_MINIMAL.parquet | Shape: (1772858, 7)
#     ✅ 20231206_prof.nc | rows: 45540
#     ✅ 20231205_prof.nc | rows: 47191
#     ✅ 20231201_prof.nc | rows: 52098
#     ✅ 20231202_prof.nc | rows: 56452
#     ✅ 20231204_prof.nc | rows: 50388
#     ✅ 20231203_prof.nc | rows: 82164
#     ✅ 20231207_prof.nc | rows: 51441
#     ✅ 20231208_prof.nc | rows: 57624
#     ✅ 20231210_prof.nc | rows: 61380
#     ✅ 20231209_prof.nc | rows: 57500
#     ✅ 20231211_prof.nc | rows: 44870
#     ✅ 20231212_prof.nc | rows: 66000
#     ✅ 20231213_prof.nc | rows: 89872
#     ✅ 20231215_prof.nc | rows: 50484
#     ✅ 20231214_prof.nc | rows: 75140
#     ✅ 20231216_prof.nc | rows: 51023
#     ✅ 20231218_prof.nc | rows: 64024
#     ✅ 20231217_prof.nc | rows: 51300
#     ✅ 20231219_prof.nc | rows: 48000
#     ✅ 20231221_prof.nc | rows: 40320
#     ✅ 20231220_prof.nc | rows: 70356
#     ✅ 20231222_prof.nc | rows: 61920
#     ✅ 20231223_prof.nc | rows: 87032
#     ✅ 20231224_prof.nc | rows: 63856
#     ✅ 20231226_prof.nc | rows: 46784
#     ✅ 20231225_prof.nc | rows: 55186
#     ✅ 20231227_prof.nc | rows: 45955
#     ✅ 20231229_prof.nc | rows: 43995
#     ✅ 20231230_prof.nc | rows: 66332
#     ✅ 20231231_prof.nc | rows: 43680
#     ✅ 20231228_prof.nc | rows: 62169
#   ✅ Saved: argo_prototype_parquet/2023_12_MINIMAL.parquet | Shape: (1790076, 7)
#
# 📂 Processing year: 2024
#     ✅ 20240105_prof.nc | rows: 38584
#     ✅ 20240104_prof.nc | rows: 62556
#     ✅ 20240103_prof.nc | rows: 48626
#     ✅ 20240101_prof.nc | rows: 52402
#     ✅ 20240106_prof.nc | rows: 46546
#     ✅ 20240102_prof.nc | rows: 97008
#     ✅ 20240107_prof.nc | rows: 60945
#     ✅ 20240111_prof.nc | rows: 49572
#     ✅ 20240108_prof.nc | rows: 60818
#     ✅ 20240109_prof.nc | rows: 55440
#     ✅ 20240110_prof.nc | rows: 52640
#     ✅ 20240112_prof.nc | rows: 115398
#     ✅ 20240114_prof.nc | rows: 64130
#     ✅ 20240115_prof.nc | rows: 44000
#     ✅ 20240113_prof.nc | rows: 79960
#     ✅ 20240116_prof.nc | rows: 51792
#     ✅ 20240118_prof.nc | rows: 57669
#     ✅ 20240119_prof.nc | rows: 59432
#     ✅ 20240121_prof.nc | rows: 45375
#     ✅ 20240120_prof.nc | rows: 48087
#     ✅ 20240122_prof.nc | rows: 106164
#     ✅ 20240123_prof.nc | rows: 63973
#     ✅ 20240126_prof.nc | rows: 39904
#     ✅ 20240127_prof.nc | rows: 59700
#     ✅ 20240129_prof.nc | rows: 78416
#     ✅ 20240131_prof.nc | rows: 58953
#     ✅ 20240117_prof.nc | rows: 54648
#     ✅ 20240124_prof.nc | rows: 56212
#     ✅ 20240125_prof.nc | rows: 45747
#     ✅ 20240128_prof.nc | rows: 51040
#     ✅ 20240130_prof.nc | rows: 40590
#   ✅ Saved: argo_prototype_parquet/2024_01_MINIMAL.parquet | Shape: (1846327, 7)
#     ✅ 20240204_prof.nc | rows: 41220
#     ✅ 20240205_prof.nc | rows: 39875
#     ✅ 20240206_prof.nc | rows: 55037
#     ✅ 20240201_prof.nc | rows: 104040
#     ✅ 20240207_prof.nc | rows: 54012
#     ✅ 20240209_prof.nc | rows: 49720
#     ✅ 20240208_prof.nc | rows: 65377
#     ✅ 20240210_prof.nc | rows: 57666
#     ✅ 20240214_prof.nc | rows: 52760
#     ✅ 20240211_prof.nc | rows: 82775
#     ✅ 20240212_prof.nc | rows: 85422
#     ✅ 20240213_prof.nc | rows: 91260
#     ✅ 20240215_prof.nc | rows: 41250
#     ✅ 20240216_prof.nc | rows: 54708
#     ✅ 20240218_prof.nc | rows: 63495
#     ✅ 20240219_prof.nc | rows: 62475
#     ✅ 20240220_prof.nc | rows: 48846
#     ✅ 20240221_prof.nc | rows: 62479
#     ✅ 20240223_prof.nc | rows: 57015
#     ✅ 20240222_prof.nc | rows: 58876
#     ✅ 20240224_prof.nc | rows: 44676
#     ✅ 20240225_prof.nc | rows: 41447
#     ✅ 20240226_prof.nc | rows: 39780
#     ✅ 20240227_prof.nc | rows: 63504
#     ✅ 20240229_prof.nc | rows: 52480
#     ✅ 20240228_prof.nc | rows: 57792
#     ✅ 20240203_prof.nc | rows: 60270
#     ✅ 20240202_prof.nc | rows: 81958
#     ✅ 20240217_prof.nc | rows: 62750
#   ✅ Saved: argo_prototype_parquet/2024_02_MINIMAL.parquet | Shape: (1732965, 7)
#     ✅ 20240304_prof.nc | rows: 50445
#     ✅ 20240305_prof.nc | rows: 40765
#     ✅ 20240301_prof.nc | rows: 54090
#     ✅ 20240302_prof.nc | rows: 52288
#     ✅ 20240303_prof.nc | rows: 61785
#     ✅ 20240307_prof.nc | rows: 36684
#     ✅ 20240310_prof.nc | rows: 53466
#     ✅ 20240308_prof.nc | rows: 61950
#     ✅ 20240311_prof.nc | rows: 54340
#     ✅ 20240309_prof.nc | rows: 75121
#     ✅ 20240312_prof.nc | rows: 50838
#     ✅ 20240313_prof.nc | rows: 53256
#     ✅ 20240315_prof.nc | rows: 47088
#     ✅ 20240314_prof.nc | rows: 49456
#     ✅ 20240316_prof.nc | rows: 45375
#     ✅ 20240317_prof.nc | rows: 45144
#     ✅ 20240320_prof.nc | rows: 57690
#     ✅ 20240319_prof.nc | rows: 59444
#     ✅ 20240318_prof.nc | rows: 67522
#     ✅ 20240321_prof.nc | rows: 52650
#     ✅ 20240322_prof.nc | rows: 45408
#     ✅ 20240323_prof.nc | rows: 53340
#     ✅ 20240325_prof.nc | rows: 50046
#     ✅ 20240324_prof.nc | rows: 42756
#     ✅ 20240326_prof.nc | rows: 45045
#     ✅ 20240327_prof.nc | rows: 50838
#     ✅ 20240328_prof.nc | rows: 60768
#     ✅ 20240330_prof.nc | rows: 60348
#     ✅ 20240329_prof.nc | rows: 63990
#     ✅ 20240331_prof.nc | rows: 49751
#     ✅ 20240306_prof.nc | rows: 48125
#   ✅ Saved: argo_prototype_parquet/2024_03_MINIMAL.parquet | Shape: (1639812, 7)
#     ✅ 20240405_prof.nc | rows: 41520
#     ✅ 20240402_prof.nc | rows: 50840
#     ✅ 20240401_prof.nc | rows: 52174
#     ✅ 20240404_prof.nc | rows: 54642
#     ✅ 20240403_prof.nc | rows: 43989
#     ✅ 20240406_prof.nc | rows: 55040
#     ✅ 20240412_prof.nc | rows: 38874
#     ✅ 20240408_prof.nc | rows: 55809
#     ✅ 20240409_prof.nc | rows: 68370
#     ✅ 20240411_prof.nc | rows: 61920
#     ✅ 20240407_prof.nc | rows: 59643
#     ✅ 20240410_prof.nc | rows: 43882
#     ✅ 20240415_prof.nc | rows: 49913
#     ✅ 20240414_prof.nc | rows: 50661
#     ✅ 20240416_prof.nc | rows: 53625
#     ✅ 20240413_prof.nc | rows: 49931
#     ✅ 20240418_prof.nc | rows: 65120
#     ✅ 20240417_prof.nc | rows: 93912
#     ✅ 20240423_prof.nc | rows: 49588
#     ✅ 20240420_prof.nc | rows: 44004
#     ✅ 20240422_prof.nc | rows: 38812
#     ✅ 20240424_prof.nc | rows: 48982
#     ✅ 20240425_prof.nc | rows: 51186
#     ✅ 20240426_prof.nc | rows: 54280
#     ✅ 20240428_prof.nc | rows: 64032
#     ✅ 20240429_prof.nc | rows: 59340
#     ✅ 20240430_prof.nc | rows: 52059
#     ✅ 20240421_prof.nc | rows: 65904
#     ✅ 20240419_prof.nc | rows: 63308
#     ✅ 20240427_prof.nc | rows: 61152
#   ✅ Saved: argo_prototype_parquet/2024_04_MINIMAL.parquet | Shape: (1642512, 7)
#     ✅ 20240504_prof.nc | rows: 56540
#     ✅ 20240502_prof.nc | rows: 42594
#     ✅ 20240505_prof.nc | rows: 46908
#     ✅ 20240503_prof.nc | rows: 73963
#     ✅ 20240507_prof.nc | rows: 54038
#     ✅ 20240510_prof.nc | rows: 50310
#     ✅ 20240511_prof.nc | rows: 50120
#     ✅ 20240512_prof.nc | rows: 48230
#     ✅ 20240514_prof.nc | rows: 54390
#     ✅ 20240513_prof.nc | rows: 75962
#     ✅ 20240516_prof.nc | rows: 55883
#     ✅ 20240515_prof.nc | rows: 55298
#     ✅ 20240517_prof.nc | rows: 59478
#     ✅ 20240501_prof.nc | rows: 55665
#     ✅ 20240519_prof.nc | rows: 48456
#     ✅ 20240506_prof.nc | rows: 70217
#     ✅ 20240509_prof.nc | rows: 46722
#     ✅ 20240520_prof.nc | rows: 48678
#     ✅ 20240521_prof.nc | rows: 59092
#     ✅ 20240522_prof.nc | rows: 78000
#     ✅ 20240523_prof.nc | rows: 42245
#     ✅ 20240524_prof.nc | rows: 54936
#     ✅ 20240525_prof.nc | rows: 55728
#     ✅ 20240508_prof.nc | rows: 70584
#     ✅ 20240526_prof.nc | rows: 54400
#     ✅ 20240528_prof.nc | rows: 69888
#     ✅ 20240529_prof.nc | rows: 45786
#     ✅ 20240530_prof.nc | rows: 45318
#     ✅ 20240518_prof.nc | rows: 69137
#     ✅ 20240527_prof.nc | rows: 58351
#     ✅ 20240531_prof.nc | rows: 57645
#   ✅ Saved: argo_prototype_parquet/2024_05_MINIMAL.parquet | Shape: (1754562, 7)
#     ✅ 20240602_prof.nc | rows: 41820
#     ✅ 20240603_prof.nc | rows: 48951
#     ✅ 20240601_prof.nc | rows: 68000
#     ✅ 20240605_prof.nc | rows: 46274
#     ✅ 20240606_prof.nc | rows: 65136
#     ✅ 20240604_prof.nc | rows: 63792
#     ✅ 20240612_prof.nc | rows: 42882
#     ✅ 20240608_prof.nc | rows: 40426
#     ✅ 20240609_prof.nc | rows: 41738
#     ✅ 20240611_prof.nc | rows: 46682
#     ✅ 20240607_prof.nc | rows: 73500
#     ✅ 20240610_prof.nc | rows: 86000
#     ✅ 20240613_prof.nc | rows: 54161
#     ✅ 20240614_prof.nc | rows: 61523
#     ✅ 20240615_prof.nc | rows: 52767
#     ✅ 20240618_prof.nc | rows: 41580
#     ✅ 20240616_prof.nc | rows: 65136
#     ✅ 20240619_prof.nc | rows: 41984
#     ✅ 20240622_prof.nc | rows: 38494
#     ✅ 20240621_prof.nc | rows: 49536
#     ✅ 20240620_prof.nc | rows: 90000
#     ✅ 20240623_prof.nc | rows: 55356
#     ✅ 20240617_prof.nc | rows: 70560
#     ✅ 20240626_prof.nc | rows: 59039
#     ✅ 20240628_prof.nc | rows: 42253
#     ✅ 20240627_prof.nc | rows: 71757
#     ✅ 20240625_prof.nc | rows: 66060
#     ✅ 20240629_prof.nc | rows: 42714
#     ✅ 20240630_prof.nc | rows: 86000
#     ✅ 20240624_prof.nc | rows: 54516
#   ✅ Saved: argo_prototype_parquet/2024_06_MINIMAL.parquet | Shape: (1708637, 7)
#     ✅ 20240702_prof.nc | rows: 35455
#     ✅ 20240704_prof.nc | rows: 44676
#     ✅ 20240701_prof.nc | rows: 53095
#     ✅ 20240703_prof.nc | rows: 68588
#     ✅ 20240706_prof.nc | rows: 56070
#     ✅ 20240708_prof.nc | rows: 44781
#     ✅ 20240710_prof.nc | rows: 39678
#     ✅ 20240711_prof.nc | rows: 44421
#     ✅ 20240713_prof.nc | rows: 65500
#     ✅ 20240709_prof.nc | rows: 86043
#     ✅ 20240712_prof.nc | rows: 48265
#     ✅ 20240716_prof.nc | rows: 56244
#     ✅ 20240715_prof.nc | rows: 72792
#     ✅ 20240717_prof.nc | rows: 64755
#     ✅ 20240718_prof.nc | rows: 36900
#     ✅ 20240720_prof.nc | rows: 48995
#     ✅ 20240719_prof.nc | rows: 65967
#     ✅ 20240721_prof.nc | rows: 43282
#     ✅ 20240723_prof.nc | rows: 53640
#     ✅ 20240722_prof.nc | rows: 59254
#     ✅ 20240724_prof.nc | rows: 53118
#     ✅ 20240705_prof.nc | rows: 67400
#     ✅ 20240725_prof.nc | rows: 56490
#     ✅ 20240726_prof.nc | rows: 66657
#     ✅ 20240727_prof.nc | rows: 59286
#     ✅ 20240707_prof.nc | rows: 76551
#     ✅ 20240728_prof.nc | rows: 40920
#     ✅ 20240731_prof.nc | rows: 38726
#     ✅ 20240729_prof.nc | rows: 64000
#     ✅ 20240730_prof.nc | rows: 51004
#     ✅ 20240714_prof.nc | rows: 46886
#   ✅ Saved: argo_prototype_parquet/2024_07_MINIMAL.parquet | Shape: (1709439, 7)
#     ✅ 20240801_prof.nc | rows: 60412
#     ✅ 20240803_prof.nc | rows: 42602
#     ✅ 20240802_prof.nc | rows: 73700
#     ✅ 20240804_prof.nc | rows: 59356
#     ✅ 20240806_prof.nc | rows: 65898
#     ✅ 20240805_prof.nc | rows: 74841
#     ✅ 20240807_prof.nc | rows: 82041
#     ✅ 20240808_prof.nc | rows: 39382
#     ✅ 20240809_prof.nc | rows: 51213
#     ✅ 20240812_prof.nc | rows: 71500
#     ✅ 20240810_prof.nc | rows: 40324
#     ✅ 20240811_prof.nc | rows: 60412
#     ✅ 20240813_prof.nc | rows: 32103
#     ✅ 20240814_prof.nc | rows: 62698
#     ✅ 20240818_prof.nc | rows: 46172
#     ✅ 20240817_prof.nc | rows: 70035
#     ✅ 20240815_prof.nc | rows: 69748
#     ✅ 20240820_prof.nc | rows: 51828
#     ✅ 20240821_prof.nc | rows: 63296
#     ✅ 20240822_prof.nc | rows: 63312
#     ✅ 20240823_prof.nc | rows: 39534
#     ✅ 20240824_prof.nc | rows: 58652
#     ✅ 20240825_prof.nc | rows: 72520
#     ✅ 20240827_prof.nc | rows: 37026
#     ✅ 20240828_prof.nc | rows: 40740
#     ✅ 20240830_prof.nc | rows: 47838
#     ✅ 20240829_prof.nc | rows: 44319
#     ✅ 20240831_prof.nc | rows: 64766
#     ✅ 20240819_prof.nc | rows: 39780
#     ✅ 20240816_prof.nc | rows: 66836
#     ✅ 20240826_prof.nc | rows: 92000
#   ✅ Saved: argo_prototype_parquet/2024_08_MINIMAL.parquet | Shape: (1784884, 7)
#     ✅ 20240902_prof.nc | rows: 43610
#     ✅ 20240901_prof.nc | rows: 57640
#     ✅ 20240903_prof.nc | rows: 65170
#     ✅ 20240906_prof.nc | rows: 40512
#     ✅ 20240905_prof.nc | rows: 94047
#     ✅ 20240908_prof.nc | rows: 39882
#     ✅ 20240907_prof.nc | rows: 44748
#     ✅ 20240910_prof.nc | rows: 62134
#     ✅ 20240909_prof.nc | rows: 48120
#     ✅ 20240911_prof.nc | rows: 58002
#     ✅ 20240912_prof.nc | rows: 52630
#     ✅ 20240913_prof.nc | rows: 51408
#     ✅ 20240914_prof.nc | rows: 70384
#     ✅ 20240916_prof.nc | rows: 50076
#     ✅ 20240917_prof.nc | rows: 32670
#     ✅ 20240919_prof.nc | rows: 46080
#     ✅ 20240918_prof.nc | rows: 46308
#     ✅ 20240920_prof.nc | rows: 63168
#     ✅ 20240921_prof.nc | rows: 49500
#     ✅ 20240923_prof.nc | rows: 54768
#     ✅ 20240922_prof.nc | rows: 59355
#     ✅ 20240926_prof.nc | rows: 38040
#     ✅ 20240927_prof.nc | rows: 30390
#     ✅ 20240929_prof.nc | rows: 47191
#     ✅ 20240928_prof.nc | rows: 46274
#     ✅ 20240930_prof.nc | rows: 54243
#     ✅ 20240904_prof.nc | rows: 65936
#     ✅ 20240915_prof.nc | rows: 95952
#     ✅ 20240925_prof.nc | rows: 72435
#     ✅ 20240924_prof.nc | rows: 94000
#   ✅ Saved: argo_prototype_parquet/2024_09_MINIMAL.parquet | Shape: (1674673, 7)
#     ✅ 20241006_prof.nc | rows: 31025
#     ✅ 20241002_prof.nc | rows: 57319
#     ✅ 20241003_prof.nc | rows: 61350
#     ✅ 20241005_prof.nc | rows: 77112
#     ✅ 20241004_prof.nc | rows: 96048
#     ✅ 20241009_prof.nc | rows: 48384
#     ✅ 20241007_prof.nc | rows: 32608
#     ✅ 20241010_prof.nc | rows: 55524
#     ✅ 20241011_prof.nc | rows: 56621
#     ✅ 20241012_prof.nc | rows: 57104
#     ✅ 20241014_prof.nc | rows: 54894
#     ✅ 20241013_prof.nc | rows: 113943
#     ✅ 20241015_prof.nc | rows: 77976
#     ✅ 20241017_prof.nc | rows: 29493
#     ✅ 20241018_prof.nc | rows: 50209
#     ✅ 20241019_prof.nc | rows: 47838
#     ✅ 20241020_prof.nc | rows: 54489
#     ✅ 20241022_prof.nc | rows: 66453
#     ✅ 20241021_prof.nc | rows: 60720
#     ✅ 20241001_prof.nc | rows: 53703
#     ✅ 20241023_prof.nc | rows: 116058
#     ✅ 20241024_prof.nc | rows: 54160
#     ✅ 20241025_prof.nc | rows: 67666
#     ✅ 20241026_prof.nc | rows: 43092
#     ✅ 20241027_prof.nc | rows: 27297
#     ✅ 20241028_prof.nc | rows: 50061
#     ✅ 20241029_prof.nc | rows: 50568
#     ✅ 20241008_prof.nc | rows: 44814
#     ✅ 20241030_prof.nc | rows: 57018
#     ✅ 20241016_prof.nc | rows: 33399
#     ✅ 20241031_prof.nc | rows: 52440
#   ✅ Saved: argo_prototype_parquet/2024_10_MINIMAL.parquet | Shape: (1779386, 7)
#     ✅ 20241105_prof.nc | rows: 42756
#     ✅ 20241106_prof.nc | rows: 32200
#     ✅ 20241102_prof.nc | rows: 98000
#     ✅ 20241101_prof.nc | rows: 68952
#     ✅ 20241109_prof.nc | rows: 59805
#     ✅ 20241107_prof.nc | rows: 52923
#     ✅ 20241110_prof.nc | rows: 56334
#     ✅ 20241112_prof.nc | rows: 65023
#     ✅ 20241113_prof.nc | rows: 57663
#     ✅ 20241111_prof.nc | rows: 98049
#     ✅ 20241114_prof.nc | rows: 57687
#     ✅ 20241116_prof.nc | rows: 27297
#     ✅ 20241117_prof.nc | rows: 38940
#     ✅ 20241118_prof.nc | rows: 59488
#     ✅ 20241120_prof.nc | rows: 67850
#     ✅ 20241103_prof.nc | rows: 59092
#     ✅ 20241121_prof.nc | rows: 80000
#     ✅ 20241104_prof.nc | rows: 66440
#     ✅ 20241108_prof.nc | rows: 49720
#     ✅ 20241122_prof.nc | rows: 67496
#     ✅ 20241123_prof.nc | rows: 51480
#     ✅ 20241125_prof.nc | rows: 49686
#     ✅ 20241124_prof.nc | rows: 60880
#     ✅ 20241126_prof.nc | rows: 54911
#     ✅ 20241127_prof.nc | rows: 48298
#     ✅ 20241128_prof.nc | rows: 57132
#     ✅ 20241129_prof.nc | rows: 56545
#     ✅ 20241115_prof.nc | rows: 51795
#     ✅ 20241119_prof.nc | rows: 54120
#     ✅ 20241130_prof.nc | rows: 100050
#   ✅ Saved: argo_prototype_parquet/2024_11_MINIMAL.parquet | Shape: (1790612, 7)
#     ✅ 20241201_prof.nc | rows: 52884
#     ✅ 20241202_prof.nc | rows: 64600
#     ✅ 20241203_prof.nc | rows: 54040
#     ✅ 20241206_prof.nc | rows: 60700
#     ✅ 20241205_prof.nc | rows: 55062
#     ✅ 20241204_prof.nc | rows: 64328
#     ✅ 20241207_prof.nc | rows: 44421
#     ✅ 20241212_prof.nc | rows: 66716
#     ✅ 20241208_prof.nc | rows: 56580
#     ✅ 20241209_prof.nc | rows: 56674
#     ✅ 20241211_prof.nc | rows: 57708
#     ✅ 20241210_prof.nc | rows: 99950
#     ✅ 20241213_prof.nc | rows: 58080
#     ✅ 20241216_prof.nc | rows: 40760
#     ✅ 20241215_prof.nc | rows: 58515
#     ✅ 20241217_prof.nc | rows: 61593
#     ✅ 20241218_prof.nc | rows: 49938
#     ✅ 20241214_prof.nc | rows: 59800
#     ✅ 20241219_prof.nc | rows: 96048
#     ✅ 20241221_prof.nc | rows: 56457
#     ✅ 20241224_prof.nc | rows: 62748
#     ✅ 20241222_prof.nc | rows: 65500
#     ✅ 20241223_prof.nc | rows: 60243
#     ✅ 20241220_prof.nc | rows: 55678
#     ✅ 20241225_prof.nc | rows: 44748
#     ✅ 20241226_prof.nc | rows: 50355
#     ✅ 20241228_prof.nc | rows: 52000
#     ✅ 20241227_prof.nc | rows: 59290
#     ✅ 20241230_prof.nc | rows: 53001
#     ✅ 20241229_prof.nc | rows: 96000
#     ✅ 20241231_prof.nc | rows: 55692
#   ✅ Saved: argo_prototype_parquet/2024_12_MINIMAL.parquet | Shape: (1870109, 7)
#
# 🎉 Prototype processing complete!

# %%
import pandas as pd

# Pick two files to inspect
files_to_check = [
    "argo_prototype_parquet/2024_12_MINIMAL.parquet",
    "argo_prototype_parquet/2024_02_MINIMAL.parquet"
]

for f in files_to_check:
    print(f"\n📂 Preview of {f}")
    try:
        df = pd.read_parquet(f)
        print(df.head(10))   # show first 10 rows
        print(f"✅ Shape: {df.shape}")
    except Exception as e:
        print(f"⚠ Error reading {f}: {e}")
# Out:
# 📂 Preview of argo_prototype_parquet/2024_12_MINIMAL.parquet
#    LATITUDE  LONGITUDE                          JULD  DEPTH_M       TEMP  \
# 0    4.9747    49.3841 2024-12-01 18:09:34.001944064     4.15  27.884001
# 1    4.9747    49.3841 2024-12-01 18:09:34.001944064     5.85  27.881001
# 2    4.9747    49.3841 2024-12-01 18:09:34.001944064     7.85  27.886999
# 3    4.9747    49.3841 2024-12-01 18:09:34.001944064     9.85  27.888000
# 4    4.9747    49.3841 2024-12-01 18:09:34.001944064    11.85  27.892000
# 5    4.9747    49.3841 2024-12-01 18:09:34.001944064    13.85  27.886000
# 6    4.9747    49.3841 2024-12-01 18:09:34.001944064    15.85  27.878000
# 7    4.9747    49.3841 2024-12-01 18:09:34.001944064    17.85  27.847000
# 8    4.9747    49.3841 2024-12-01 18:09:34.001944064    19.85  27.840000
# 9    4.9747    49.3841 2024-12-01 18:09:34.001944064    21.85  27.799999
#
#         PSAL       source_file
# 0  35.851002  20241201_prof.nc
# 1  35.849998  20241201_prof.nc
# 2  35.852001  20241201_prof.nc
# 3  35.849998  20241201_prof.nc
# 4  35.849998  20241201_prof.nc
# 5  35.848999  20241201_prof.nc
# 6  35.848000  20241201_prof.nc
# 7  35.839001  20241201_prof.nc
# 8  35.838001  20241201_prof.nc
# 9  35.827000  20241201_prof.nc
# ✅ Shape: (1870109, 7)
#
# 📂 Preview of argo_prototype_parquet/2024_02_MINIMAL.parquet
#    LATITUDE  LONGITUDE                    JULD  DEPTH_M       TEMP       PSAL  \
# 0 -33.56785   48.01184 2024-02-04 17:30:28.800     1.08  21.889000  35.861000
# 1 -33.56785   48.01184 2024-02-04 17:30:28.800     2.00  21.884001  35.863998
# 2 -33.56785   48.01184 2024-02-04 17:30:28.800     3.00  21.889000  35.862202
# 3 -33.56785   48.01184 2024-02-04 17:30:28.800     4.04  21.892000  35.862598
# 4 -33.56785   48.01184 2024-02-04 17:30:28.800     5.04  21.889999  35.862598
# 5 -33.56785   48.01184 2024-02-04 17:30:28.800     6.04  21.892000  35.862000
# 6 -33.56785   48.01184 2024-02-04 17:30:28.800     6.96  21.893000  35.862202
# 7 -33.56785   48.01184 2024-02-04 17:30:28.800     7.96  21.889999  35.861801
# 8 -33.56785   48.01184 2024-02-04 17:30:28.800     9.00  21.877001  35.863201
# 9 -33.56785   48.01184 2024-02-04 17:30:28.800    10.04  21.878000  35.863400
#
#         source_file
# 0  20240204_prof.nc
# 1  20240204_prof.nc
# 2  20240204_prof.nc
# 3  20240204_prof.nc
# 4  20240204_prof.nc
# 5  20240204_prof.nc
# 6  20240204_prof.nc
# 7  20240204_prof.nc
# 8  20240204_prof.nc
# 9  20240204_prof.nc
# ✅ Shape: (1732965, 7)

# %%
import os
import polars as pl
import pandas as pd

# 📂 Folder where your parquet files are saved
DATA_DIR = "argo_prototype_parquet"
metadata = []

# Loop through all parquet files
for fname in sorted(os.listdir(DATA_DIR)):
    if not fname.endswith(".parquet"):
        continue

    fpath = os.path.join(DATA_DIR, fname)
    print(f"Processing {fpath} ...")

    # Read small sample (for fast metadata extraction)
    df = pl.read_parquet(fpath)

    # Extract year and month from filename
    year, month = fname.split("_")[:2]

    # Collect metadata
    entry = {
        "year": int(year),
        "month": int(month),
        "file_path": fpath,
        "min_date": df["JULD"].min(),
        "max_date": df["JULD"].max(),
        "min_lat": df["LATITUDE"].min(),
        "max_lat": df["LATITUDE"].max(),
        "min_lon": df["LONGITUDE"].min(),
        "max_lon": df["LONGITUDE"].max(),
        "min_depth": df["DEPTH_M"].min(),
        "max_depth": df["DEPTH_M"].max(),
    }
    metadata.append(entry)

# Convert to Pandas DataFrame for saving
meta_df = pd.DataFrame(metadata)

# Save catalog
meta_df.to_csv("argo_metadata.csv", index=False)

print("✅ Metadata catalog saved as argo_metadata.csv")
print(meta_df.head(10))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4175075467.py in <cell line: 0>()
#       8
#       9 # Loop through all parquet files
# ---> 10 for fname in sorted(os.listdir(DATA_DIR)):
#      11     if not fname.endswith(".parquet"):
#      12         continue
#
# FileNotFoundError: [Errno 2] No such file or directory: 'argo_prototype_parquet'

# %%
import requests
from bs4 import BeautifulSoup
import xarray as xr
import pandas as pd
import numpy as np
import os
import tempfile
from concurrent.futures import ThreadPoolExecutor, as_completed

# -----------------------
# Config
# -----------------------
BASE_URL = "https://usgodae.org/pub/outgoing/argo/geo/indian_ocean/"
YEARS = range(2022, 2025)
MONTHS = [f"{m:02d}" for m in range(1, 13)]
OUT_DIR = "/content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet"
os.makedirs(OUT_DIR, exist_ok=True)

USE_PARALLEL = True
MAX_WORKERS = 6

# Bounding box filter (optional, e.g., Indian Ocean subset)
BBOX = {
    "lat_min": -40, "lat_max": 30,
    "lon_min": 30, "lon_max": 110
}

# -----------------------
# Helper: safe dataset opening
# -----------------------
def open_dataset_safe(path_or_file):
    try:
        return xr.open_dataset(path_or_file, engine="netcdf4", decode_cf=False)
    except Exception:
        return xr.open_dataset(path_or_file, engine="scipy", decode_timedelta=False)

# -----------------------
# Flatten dataset safely (minimal columns)
# -----------------------
def flatten_ds_minimal(ds: xr.Dataset, source_file: str):
    # Coordinates
    lat = np.asarray(ds["LATITUDE"].values) if "LATITUDE" in ds else None
    lon = np.asarray(ds["LONGITUDE"].values) if "LONGITUDE" in ds else None
    juld = pd.to_datetime(ds["JULD"].values, errors='coerce') if "JULD" in ds else None

    # Dimensions
    prof_dim = next((d for d in ds.dims if "N_PROF" in d.upper()), None)
    level_dim = next((d for d in ds.dims if "N_LEVEL" in d.upper() or "N_LEVELS" in d.upper()), None)
    n_prof = int(ds.sizes.get(prof_dim, 0)) if prof_dim else (len(lat) if lat is not None else 0)
    n_level = int(ds.sizes.get(level_dim, 1)) if level_dim else 1
    if n_prof == 0:  # empty dataset
        raise ValueError("Dataset has zero profiles")

    total_len = n_prof * n_level

    # Coordinates arrays
    lat_arr = np.repeat(lat, n_level) if lat is not None else np.full(total_len, np.nan)
    lon_arr = np.repeat(lon, n_level) if lon is not None else np.full(total_len, np.nan)
    juld_arr = np.repeat(juld, n_level) if juld is not None else np.full(total_len, pd.NaT, dtype=object)

    df = pd.DataFrame({
        "LATITUDE": lat_arr,
        "LONGITUDE": lon_arr,
        "JULD": juld_arr,
    })

    # Depth column
    depth_col_vals = None
    for dcol in ["PRES_ADJUSTED", "PRES"]:
        if dcol in ds:
            arr = np.asarray(ds[dcol].values)
            if arr.ndim == 2:
                depth_col_vals = arr.flatten()
            elif arr.ndim == 1:
                if arr.size == n_prof:
                    depth_col_vals = np.repeat(arr, n_level)
                elif arr.size == n_level:
                    depth_col_vals = np.tile(arr, n_prof)
            elif arr.ndim == 0:
                depth_col_vals = np.repeat(arr.item(), total_len)
            if depth_col_vals is not None:
                break
    df["DEPTH_M"] = depth_col_vals if depth_col_vals is not None else np.nan

    # Minimal variables
    for var in ["TEMP", "PSAL"]:
        if var in ds:
            arr = np.asarray(ds[var].values)
            if arr.ndim == 2 and arr.shape == (n_prof, n_level):
                df[var] = arr.flatten()
            elif arr.ndim == 1:
                if arr.size == n_prof:
                    df[var] = np.repeat(arr, n_level)
                elif arr.size == n_level:
                    df[var] = np.tile(arr, n_prof)
            elif arr.ndim == 0:
                df[var] = np.repeat(arr.item(), total_len)
            else:
                df[var] = np.nan
        else:
            df[var] = np.nan

    # Add source file
    df["source_file"] = source_file

    # Apply bbox filter
    df = df[(df["LATITUDE"].between(BBOX["lat_min"], BBOX["lat_max"])) &
            (df["LONGITUDE"].between(BBOX["lon_min"], BBOX["lon_max"]))]

    return df

# -----------------------
# Worker: download + flatten
# -----------------------
def process_file(file_url):
    try:
        with tempfile.NamedTemporaryFile(suffix=".nc") as tmp:
            with requests.get(file_url, stream=True, timeout=60) as r:
                r.raise_for_status()
                for chunk in r.iter_content(1024*1024):
                    tmp.write(chunk)
            tmp.flush()
            ds = open_dataset_safe(tmp.name)
            df = flatten_ds_minimal(ds, os.path.basename(file_url))
            ds.close()
            if df.empty:
                return None
            return df
    except Exception as e:
        print(f"⚠ Skipped {file_url}: {e}")
        return None

# -----------------------
# Main loop
# -----------------------
for year in YEARS:
    print(f"\n📂 Processing year: {year}")
    for month in MONTHS:
        url = f"{BASE_URL}{year}/{month}/"
        try:
            resp = requests.get(url, timeout=10)
            if resp.status_code != 200:
                print(f"  (No listing: {url})")
                continue
        except Exception as e:
            print(f"  (Request error: {url}): {e}")
            continue

        soup = BeautifulSoup(resp.text, "html.parser")
        files = [a.get('href') for a in soup.find_all('a') if a.get('href', '').endswith('.nc')]
        if not files:
            continue

        month_data = []

        if USE_PARALLEL:
            with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
                futures = {executor.submit(process_file, url + f): f for f in files}
                for future in as_completed(futures):
                    f = futures[future]
                    df = future.result()
                    if df is not None:
                        month_data.append(df)
                        print(f"    ✅ {f} | rows: {len(df)}")
                    else:
                        print(f"    ⚠ Skipped {f}: empty result")
        else:
            for f in files:
                df = process_file(url + f)
                if df is not None:
                    month_data.append(df)
                    print(f"    ✅ {f} | rows: {len(df)}")
                else:
                    print(f"    ⚠ Skipped {f}: empty result")

        # Save minimal data
        if month_data:
            final_df = pd.concat(month_data, ignore_index=True)
            if not final_df.empty:
                out_file = f"{OUT_DIR}/{year}_{month}_MINIMAL.parquet"
                final_df.to_parquet(out_file, index=False)
                print(f"  ✅ Saved: {out_file} | Shape: {final_df.shape}")
            else:
                print(f"  ⚠ No usable data for {year}-{month}")
        else:
            print(f"  ⚠ All files empty for {year}-{month}")

print("\n🎉 Prototype processing complete!")
# Out:
# 📂 Processing year: 2022
#     ✅ 20220103_prof.nc | rows: 39468
#     ✅ 20220101_prof.nc | rows: 37370
#     ✅ 20220106_prof.nc | rows: 54972
#     ✅ 20220105_prof.nc | rows: 54097
#     ✅ 20220102_prof.nc | rows: 45006
#     ✅ 20220110_prof.nc | rows: 42756
#     ✅ 20220108_prof.nc | rows: 49324
#     ✅ 20220107_prof.nc | rows: 39480
#     ✅ 20220113_prof.nc | rows: 36396
#     ✅ 20220112_prof.nc | rows: 50820
#     ✅ 20220114_prof.nc | rows: 50950
#     ✅ 20220116_prof.nc | rows: 59466
#     ✅ 20220115_prof.nc | rows: 55248
#     ✅ 20220117_prof.nc | rows: 38318
#     ✅ 20220118_prof.nc | rows: 45495
#     ✅ 20220119_prof.nc | rows: 48672
#     ✅ 20220120_prof.nc | rows: 48672
#     ✅ 20220104_prof.nc | rows: 50800
#     ✅ 20220122_prof.nc | rows: 47273
#     ✅ 20220121_prof.nc | rows: 36432
#     ✅ 20220123_prof.nc | rows: 38494
#     ✅ 20220125_prof.nc | rows: 55248
#     ✅ 20220126_prof.nc | rows: 56400
#     ✅ 20220127_prof.nc | rows: 37407
#     ✅ 20220128_prof.nc | rows: 42966
#     ✅ 20220129_prof.nc | rows: 46736
#     ✅ 20220130_prof.nc | rows: 41492
#     ✅ 20220131_prof.nc | rows: 41943
#     ✅ 20220109_prof.nc | rows: 49152
#     ✅ 20220111_prof.nc | rows: 31372
#     ✅ 20220124_prof.nc | rows: 51918
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2022_01_MINIMAL.parquet | Shape: (1424143, 7)
#     ✅ 20220202_prof.nc | rows: 39546
#     ✅ 20220201_prof.nc | rows: 46120
#     ✅ 20220203_prof.nc | rows: 55248
#     ✅ 20220204_prof.nc | rows: 57426
#     ✅ 20220206_prof.nc | rows: 36360
#     ✅ 20220209_prof.nc | rows: 42966
#     ✅ 20220207_prof.nc | rows: 43559
#     ✅ 20220210_prof.nc | rows: 38418
#     ✅ 20220208_prof.nc | rows: 41574
#     ✅ 20220211_prof.nc | rows: 53084
#     ✅ 20220212_prof.nc | rows: 34374
#     ✅ 20220213_prof.nc | rows: 59852
#     ✅ 20220215_prof.nc | rows: 46598
#     ✅ 20220216_prof.nc | rows: 40480
#     ✅ 20220217_prof.nc | rows: 44748
#     ✅ 20220218_prof.nc | rows: 41820
#     ✅ 20220220_prof.nc | rows: 42672
#     ✅ 20220221_prof.nc | rows: 53038
#     ✅ 20220222_prof.nc | rows: 47166
#     ✅ 20220223_prof.nc | rows: 61003
#     ✅ 20220225_prof.nc | rows: 43774
#     ✅ 20220226_prof.nc | rows: 35490
#     ✅ 20220205_prof.nc | rows: 49980
#     ✅ 20220228_prof.nc | rows: 41697
#     ✅ 20220219_prof.nc | rows: 41615
#     ✅ 20220214_prof.nc | rows: 52875
#     ✅ 20220227_prof.nc | rows: 40640
#     ✅ 20220224_prof.nc | rows: 46920
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2022_02_MINIMAL.parquet | Shape: (1279043, 7)
#     ✅ 20220301_prof.nc | rows: 37814
#     ✅ 20220303_prof.nc | rows: 50732
#     ✅ 20220302_prof.nc | rows: 44528
#     ✅ 20220306_prof.nc | rows: 45540
#     ✅ 20220305_prof.nc | rows: 56399
#     ✅ 20220307_prof.nc | rows: 49931
#     ✅ 20220309_prof.nc | rows: 38570
#     ✅ 20220311_prof.nc | rows: 35385
#     ✅ 20220310_prof.nc | rows: 45012
#     ✅ 20220312_prof.nc | rows: 45080
#     ✅ 20220314_prof.nc | rows: 35420
#     ✅ 20220313_prof.nc | rows: 53760
#     ✅ 20220315_prof.nc | rows: 57550
#     ✅ 20220316_prof.nc | rows: 43860
#     ✅ 20220317_prof.nc | rows: 47150
#     ✅ 20220319_prof.nc | rows: 42462
#     ✅ 20220318_prof.nc | rows: 41574
#     ✅ 20220322_prof.nc | rows: 49588
#     ✅ 20220323_prof.nc | rows: 52875
#     ✅ 20220324_prof.nc | rows: 34476
#     ✅ 20220325_prof.nc | rows: 49104
#     ✅ 20220326_prof.nc | rows: 46598
#     ✅ 20220327_prof.nc | rows: 42630
#     ✅ 20220304_prof.nc | rows: 47208
#     ✅ 20220328_prof.nc | rows: 37407
#     ✅ 20220329_prof.nc | rows: 45494
#     ✅ 20220331_prof.nc | rows: 40464
#     ✅ 20220330_prof.nc | rows: 54296
#     ✅ 20220321_prof.nc | rows: 42788
#     ✅ 20220308_prof.nc | rows: 37851
#     ✅ 20220320_prof.nc | rows: 44572
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2022_03_MINIMAL.parquet | Shape: (1396118, 7)
#     ✅ 20220406_prof.nc | rows: 52762
#     ✅ 20220405_prof.nc | rows: 59760
#     ✅ 20220403_prof.nc | rows: 43384
#     ✅ 20220404_prof.nc | rows: 67248
#     ✅ 20220401_prof.nc | rows: 68220
#     ✅ 20220407_prof.nc | rows: 43602
#     ✅ 20220410_prof.nc | rows: 38726
#     ✅ 20220409_prof.nc | rows: 46084
#     ✅ 20220408_prof.nc | rows: 45540
#     ✅ 20220411_prof.nc | rows: 45585
#     ✅ 20220412_prof.nc | rows: 44704
#     ✅ 20220413_prof.nc | rows: 31434
#     ✅ 20220415_prof.nc | rows: 46552
#     ✅ 20220414_prof.nc | rows: 45810
#     ✅ 20220416_prof.nc | rows: 46035
#     ✅ 20220418_prof.nc | rows: 53952
#     ✅ 20220417_prof.nc | rows: 39507
#     ✅ 20220420_prof.nc | rows: 45560
#     ✅ 20220421_prof.nc | rows: 45200
#     ✅ 20220423_prof.nc | rows: 37455
#     ✅ 20220425_prof.nc | rows: 53063
#     ✅ 20220426_prof.nc | rows: 49368
#     ✅ 20220427_prof.nc | rows: 46166
#     ✅ 20220428_prof.nc | rows: 48590
#     ✅ 20220429_prof.nc | rows: 36504
#     ✅ 20220430_prof.nc | rows: 46699
#     ✅ 20220402_prof.nc | rows: 92290
#     ✅ 20220419_prof.nc | rows: 47838
#     ✅ 20220424_prof.nc | rows: 49456
#     ✅ 20220422_prof.nc | rows: 48676
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2022_04_MINIMAL.parquet | Shape: (1465770, 7)
#     ✅ 20220501_prof.nc | rows: 41492
#     ✅ 20220504_prof.nc | rows: 46782
#     ✅ 20220502_prof.nc | rows: 39819
#     ✅ 20220506_prof.nc | rows: 51750
#     ✅ 20220503_prof.nc | rows: 34782
#     ✅ 20220510_prof.nc | rows: 44572
#     ✅ 20220508_prof.nc | rows: 42143
#     ✅ 20220509_prof.nc | rows: 40480
#     ✅ 20220511_prof.nc | rows: 45560
#     ✅ 20220507_prof.nc | rows: 37814
#     ✅ 20220512_prof.nc | rows: 37592
#     ✅ 20220513_prof.nc | rows: 37481
#     ✅ 20220515_prof.nc | rows: 50580
#     ✅ 20220518_prof.nc | rows: 47386
#     ✅ 20220517_prof.nc | rows: 42636
#     ✅ 20220519_prof.nc | rows: 46699
#     ✅ 20220520_prof.nc | rows: 42840
#     ✅ 20220522_prof.nc | rows: 36576
#     ✅ 20220521_prof.nc | rows: 55811
#     ✅ 20220523_prof.nc | rows: 40560
#     ✅ 20220524_prof.nc | rows: 47940
#     ✅ 20220525_prof.nc | rows: 51750
#     ✅ 20220526_prof.nc | rows: 48289
#     ✅ 20220527_prof.nc | rows: 35805
#     ✅ 20220528_prof.nc | rows: 39865
#     ✅ 20220505_prof.nc | rows: 47564
#     ✅ 20220529_prof.nc | rows: 41656
#     ✅ 20220530_prof.nc | rows: 46699
#     ✅ 20220531_prof.nc | rows: 50116
#     ✅ 20220514_prof.nc | rows: 42924
#     ✅ 20220516_prof.nc | rows: 51704
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2022_05_MINIMAL.parquet | Shape: (1367667, 7)
#     ✅ 20220604_prof.nc | rows: 45495
#     ✅ 20220601_prof.nc | rows: 36720
#     ✅ 20220602_prof.nc | rows: 39858
#     ✅ 20220608_prof.nc | rows: 40680
#     ✅ 20220609_prof.nc | rows: 51255
#     ✅ 20220607_prof.nc | rows: 43282
#     ✅ 20220610_prof.nc | rows: 45560
#     ✅ 20220611_prof.nc | rows: 37851
#     ✅ 20220612_prof.nc | rows: 48375
#     ✅ 20220613_prof.nc | rows: 45056
#     ✅ 20220614_prof.nc | rows: 49412
#     ✅ 20220615_prof.nc | rows: 37407
#     ✅ 20220618_prof.nc | rows: 56655
#     ✅ 20220616_prof.nc | rows: 32448
#     ✅ 20220617_prof.nc | rows: 53120
#     ✅ 20220619_prof.nc | rows: 58740
#     ✅ 20220621_prof.nc | rows: 42143
#     ✅ 20220620_prof.nc | rows: 53703
#     ✅ 20220622_prof.nc | rows: 60852
#     ✅ 20220623_prof.nc | rows: 51566
#     ✅ 20220624_prof.nc | rows: 51568
#     ✅ 20220605_prof.nc | rows: 44800
#     ✅ 20220625_prof.nc | rows: 49140
#     ✅ 20220626_prof.nc | rows: 31620
#     ✅ 20220627_prof.nc | rows: 50578
#     ✅ 20220603_prof.nc | rows: 54000
#     ✅ 20220628_prof.nc | rows: 54780
#     ✅ 20220629_prof.nc | rows: 55309
#     ✅ 20220630_prof.nc | rows: 54800
#     ✅ 20220606_prof.nc | rows: 33363
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2022_06_MINIMAL.parquet | Shape: (1410136, 7)
#     ✅ 20220701_prof.nc | rows: 41004
#     ✅ 20220703_prof.nc | rows: 51658
#     ✅ 20220704_prof.nc | rows: 51030
#     ✅ 20220705_prof.nc | rows: 48867
#     ✅ 20220702_prof.nc | rows: 65712
#     ✅ 20220706_prof.nc | rows: 32416
#     ✅ 20220708_prof.nc | rows: 46472
#     ✅ 20220710_prof.nc | rows: 53469
#     ✅ 20220707_prof.nc | rows: 52160
#     ✅ 20220712_prof.nc | rows: 60808
#     ✅ 20220709_prof.nc | rows: 56616
#     ✅ 20220711_prof.nc | rows: 43282
#     ✅ 20220713_prof.nc | rows: 42672
#     ✅ 20220714_prof.nc | rows: 54225
#     ✅ 20220718_prof.nc | rows: 47034
#     ✅ 20220716_prof.nc | rows: 29406
#     ✅ 20220719_prof.nc | rows: 44920
#     ✅ 20220721_prof.nc | rows: 44421
#     ✅ 20220720_prof.nc | rows: 58996
#     ✅ 20220722_prof.nc | rows: 58824
#     ✅ 20220723_prof.nc | rows: 47846
#     ✅ 20220724_prof.nc | rows: 55982
#     ✅ 20220725_prof.nc | rows: 46287
#     ✅ 20220726_prof.nc | rows: 30390
#     ✅ 20220727_prof.nc | rows: 55814
#     ✅ 20220729_prof.nc | rows: 39468
#     ✅ 20220730_prof.nc | rows: 56334
#     ✅ 20220731_prof.nc | rows: 44421
#     ✅ 20220715_prof.nc | rows: 45144
#     ✅ 20220717_prof.nc | rows: 61248
#     ✅ 20220728_prof.nc | rows: 52603
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2022_07_MINIMAL.parquet | Shape: (1519529, 7)
#     ✅ 20220804_prof.nc | rows: 50184
#     ✅ 20220806_prof.nc | rows: 52521
#     ✅ 20220801_prof.nc | rows: 54320
#     ✅ 20220802_prof.nc | rows: 45585
#     ✅ 20220805_prof.nc | rows: 30360
#     ✅ 20220810_prof.nc | rows: 55200
#     ✅ 20220811_prof.nc | rows: 48977
#     ✅ 20220809_prof.nc | rows: 51675
#     ✅ 20220812_prof.nc | rows: 63112
#     ✅ 20220813_prof.nc | rows: 45103
#     ✅ 20220814_prof.nc | rows: 50000
#     ✅ 20220816_prof.nc | rows: 57640
#     ✅ 20220817_prof.nc | rows: 51742
#     ✅ 20220818_prof.nc | rows: 41440
#     ✅ 20220819_prof.nc | rows: 53880
#     ✅ 20220820_prof.nc | rows: 46818
#     ✅ 20220822_prof.nc | rows: 64907
#     ✅ 20220803_prof.nc | rows: 48280
#     ✅ 20220808_prof.nc | rows: 37481
#     ✅ 20220823_prof.nc | rows: 39429
#     ✅ 20220824_prof.nc | rows: 47462
#     ✅ 20220826_prof.nc | rows: 51560
#     ✅ 20220827_prof.nc | rows: 53550
#     ✅ 20220828_prof.nc | rows: 31496
#     ✅ 20220807_prof.nc | rows: 51480
#     ✅ 20220829_prof.nc | rows: 52689
#     ✅ 20220830_prof.nc | rows: 46886
#     ✅ 20220831_prof.nc | rows: 44421
#     ✅ 20220815_prof.nc | rows: 35595
#     ✅ 20220821_prof.nc | rows: 47838
#     ✅ 20220825_prof.nc | rows: 43758
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2022_08_MINIMAL.parquet | Shape: (1495389, 7)
#     ✅ 20220906_prof.nc | rows: 40392
#     ✅ 20220901_prof.nc | rows: 63434
#     ✅ 20220903_prof.nc | rows: 46371
#     ✅ 20220904_prof.nc | rows: 33330
#     ✅ 20220905_prof.nc | rows: 51800
#     ✅ 20220907_prof.nc | rows: 34476
#     ✅ 20220908_prof.nc | rows: 45832
#     ✅ 20220910_prof.nc | rows: 42143
#     ✅ 20220912_prof.nc | rows: 41551
#     ✅ 20220913_prof.nc | rows: 46254
#     ✅ 20220914_prof.nc | rows: 44850
#     ✅ 20220915_prof.nc | rows: 57596
#     ✅ 20220916_prof.nc | rows: 36448
#     ✅ 20220917_prof.nc | rows: 37444
#     ✅ 20220919_prof.nc | rows: 39865
#     ✅ 20220918_prof.nc | rows: 47110
#     ✅ 20220921_prof.nc | rows: 55320
#     ✅ 20220922_prof.nc | rows: 44920
#     ✅ 20220924_prof.nc | rows: 42770
#     ✅ 20220902_prof.nc | rows: 35700
#     ✅ 20220925_prof.nc | rows: 49210
#     ✅ 20220926_prof.nc | rows: 38726
#     ✅ 20220909_prof.nc | rows: 44096
#     ✅ 20220927_prof.nc | rows: 34680
#     ✅ 20220928_prof.nc | rows: 37408
#     ✅ 20220929_prof.nc | rows: 41004
#     ✅ 20220911_prof.nc | rows: 61028
#     ✅ 20220930_prof.nc | rows: 56293
#     ✅ 20220923_prof.nc | rows: 40293
#     ✅ 20220920_prof.nc | rows: 54240
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2022_09_MINIMAL.parquet | Shape: (1344584, 7)
#     ✅ 20221002_prof.nc | rows: 37407
#     ✅ 20221006_prof.nc | rows: 38726
#     ✅ 20221003_prof.nc | rows: 43920
#     ✅ 20221001_prof.nc | rows: 54015
#     ✅ 20221005_prof.nc | rows: 51920
#     ✅ 20221008_prof.nc | rows: 44649
#     ✅ 20221011_prof.nc | rows: 52630
#     ✅ 20221010_prof.nc | rows: 64202
#     ✅ 20221012_prof.nc | rows: 46246
#     ✅ 20221013_prof.nc | rows: 37026
#     ✅ 20221014_prof.nc | rows: 55019
#     ✅ 20221017_prof.nc | rows: 47838
#     ✅ 20221015_prof.nc | rows: 65274
#     ✅ 20221018_prof.nc | rows: 68456
#     ✅ 20221019_prof.nc | rows: 81122
#     ✅ 20221020_prof.nc | rows: 61740
#     ✅ 20221021_prof.nc | rows: 54120
#     ✅ 20221007_prof.nc | rows: 32416
#     ✅ 20221022_prof.nc | rows: 68061
#     ✅ 20221023_prof.nc | rows: 39372
#     ✅ 20221009_prof.nc | rows: 38726
#     ✅ 20221024_prof.nc | rows: 49282
#     ✅ 20221004_prof.nc | rows: 38182
#     ✅ 20221025_prof.nc | rows: 52680
#     ✅ 20221027_prof.nc | rows: 36648
#     ✅ 20221028_prof.nc | rows: 77602
#     ✅ 20221030_prof.nc | rows: 60660
#     ✅ 20221031_prof.nc | rows: 50881
#     ✅ 20221029_prof.nc | rows: 87880
#     ✅ 20221016_prof.nc | rows: 62156
#     ✅ 20221026_prof.nc | rows: 63180
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2022_10_MINIMAL.parquet | Shape: (1662036, 7)
#     ✅ 20221106_prof.nc | rows: 30360
#     ✅ 20221102_prof.nc | rows: 42264
#     ✅ 20221105_prof.nc | rows: 65833
#     ✅ 20221101_prof.nc | rows: 69100
#     ✅ 20221107_prof.nc | rows: 47541
#     ✅ 20221109_prof.nc | rows: 57582
#     ✅ 20221108_prof.nc | rows: 71252
#     ✅ 20221112_prof.nc | rows: 28539
#     ✅ 20221111_prof.nc | rows: 60676
#     ✅ 20221113_prof.nc | rows: 46605
#     ✅ 20221114_prof.nc | rows: 50973
#     ✅ 20221115_prof.nc | rows: 60840
#     ✅ 20221116_prof.nc | rows: 43848
#     ✅ 20221117_prof.nc | rows: 48913
#     ✅ 20221118_prof.nc | rows: 61758
#     ✅ 20221119_prof.nc | rows: 56718
#     ✅ 20221122_prof.nc | rows: 40936
#     ✅ 20221120_prof.nc | rows: 57204
#     ✅ 20221121_prof.nc | rows: 69350
#     ✅ 20221123_prof.nc | rows: 45030
#     ✅ 20221124_prof.nc | rows: 39240
#     ✅ 20221125_prof.nc | rows: 76995
#     ✅ 20221126_prof.nc | rows: 48332
#     ✅ 20221127_prof.nc | rows: 54050
#     ✅ 20221103_prof.nc | rows: 46822
#     ✅ 20221128_prof.nc | rows: 85913
#     ✅ 20221104_prof.nc | rows: 57552
#     ✅ 20221129_prof.nc | rows: 50512
#     ✅ 20221130_prof.nc | rows: 60500
#     ✅ 20221110_prof.nc | rows: 43020
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2022_11_MINIMAL.parquet | Shape: (1618258, 7)
#     ✅ 20221202_prof.nc | rows: 37764
#     ✅ 20221206_prof.nc | rows: 37629
#     ✅ 20221204_prof.nc | rows: 40548
#     ✅ 20221203_prof.nc | rows: 47766
#     ✅ 20221201_prof.nc | rows: 66640
#     ✅ 20221205_prof.nc | rows: 70965
#     ✅ 20221207_prof.nc | rows: 52290
#     ✅ 20221210_prof.nc | rows: 64860
#     ✅ 20221208_prof.nc | rows: 82674
#     ✅ 20221212_prof.nc | rows: 38480
#     ✅ 20221211_prof.nc | rows: 76120
#     ✅ 20221213_prof.nc | rows: 51455
#     ✅ 20221214_prof.nc | rows: 39390
#     ✅ 20221216_prof.nc | rows: 42180
#     ✅ 20221217_prof.nc | rows: 49493
#     ✅ 20221219_prof.nc | rows: 44067
#     ✅ 20221218_prof.nc | rows: 83800
#     ✅ 20221220_prof.nc | rows: 60456
#     ✅ 20221221_prof.nc | rows: 57454
#     ✅ 20221222_prof.nc | rows: 50986
#     ✅ 20221223_prof.nc | rows: 43524
#     ✅ 20221224_prof.nc | rows: 39090
#     ✅ 20221225_prof.nc | rows: 72680
#     ✅ 20221226_prof.nc | rows: 37629
#     ✅ 20221227_prof.nc | rows: 49854
#     ✅ 20221228_prof.nc | rows: 79478
#     ✅ 20221229_prof.nc | rows: 44881
#     ✅ 20221230_prof.nc | rows: 56375
#     ✅ 20221209_prof.nc | rows: 44696
#     ✅ 20221231_prof.nc | rows: 93330
#     ✅ 20221215_prof.nc | rows: 75938
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2022_12_MINIMAL.parquet | Shape: (1732492, 7)
#
# 📂 Processing year: 2023
#     ✅ 20230105_prof.nc | rows: 40052
#     ✅ 20230103_prof.nc | rows: 36400
#     ✅ 20230101_prof.nc | rows: 54920
#     ✅ 20230106_prof.nc | rows: 61302
#     ✅ 20230104_prof.nc | rows: 65120
#     ✅ 20230109_prof.nc | rows: 43080
#     ✅ 20230108_prof.nc | rows: 46474
#     ✅ 20230107_prof.nc | rows: 86710
#     ✅ 20230111_prof.nc | rows: 54800
#     ✅ 20230113_prof.nc | rows: 38370
#     ✅ 20230115_prof.nc | rows: 41312
#     ✅ 20230112_prof.nc | rows: 38612
#     ✅ 20230114_prof.nc | rows: 68524
#     ✅ 20230118_prof.nc | rows: 40996
#     ✅ 20230119_prof.nc | rows: 41943
#     ✅ 20230116_prof.nc | rows: 64428
#     ✅ 20230117_prof.nc | rows: 78480
#     ✅ 20230120_prof.nc | rows: 65832
#     ✅ 20230122_prof.nc | rows: 44032
#     ✅ 20230123_prof.nc | rows: 42570
#     ✅ 20230124_prof.nc | rows: 55209
#     ✅ 20230102_prof.nc | rows: 45375
#     ✅ 20230127_prof.nc | rows: 79464
#     ✅ 20230128_prof.nc | rows: 36540
#     ✅ 20230129_prof.nc | rows: 40760
#     ✅ 20230110_prof.nc | rows: 65572
#     ✅ 20230130_prof.nc | rows: 65884
#     ✅ 20230131_prof.nc | rows: 50875
#     ✅ 20230125_prof.nc | rows: 48184
#     ✅ 20230121_prof.nc | rows: 49284
#     ✅ 20230126_prof.nc | rows: 55836
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2023_01_MINIMAL.parquet | Shape: (1646940, 7)
#     ✅ 20230201_prof.nc | rows: 45507
#     ✅ 20230204_prof.nc | rows: 43296
#     ✅ 20230203_prof.nc | rows: 56761
#     ✅ 20230202_prof.nc | rows: 38338
#     ✅ 20230208_prof.nc | rows: 47249
#     ✅ 20230211_prof.nc | rows: 41582
#     ✅ 20230212_prof.nc | rows: 45008
#     ✅ 20230213_prof.nc | rows: 62240
#     ✅ 20230214_prof.nc | rows: 41856
#     ✅ 20230215_prof.nc | rows: 81692
#     ✅ 20230205_prof.nc | rows: 57648
#     ✅ 20230206_prof.nc | rows: 76956
#     ✅ 20230207_prof.nc | rows: 54775
#     ✅ 20230217_prof.nc | rows: 49839
#     ✅ 20230216_prof.nc | rows: 72360
#     ✅ 20230210_prof.nc | rows: 58266
#     ✅ 20230218_prof.nc | rows: 42630
#     ✅ 20230209_prof.nc | rows: 77300
#     ✅ 20230219_prof.nc | rows: 52844
#     ✅ 20230221_prof.nc | rows: 36482
#     ✅ 20230220_prof.nc | rows: 57246
#     ✅ 20230224_prof.nc | rows: 39680
#     ✅ 20230222_prof.nc | rows: 37071
#     ✅ 20230223_prof.nc | rows: 65208
#     ✅ 20230225_prof.nc | rows: 63070
#     ✅ 20230227_prof.nc | rows: 47320
#     ✅ 20230228_prof.nc | rows: 43731
#     ✅ 20230226_prof.nc | rows: 89505
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2023_02_MINIMAL.parquet | Shape: (1525460, 7)
#     ✅ 20230306_prof.nc | rows: 40610
#     ✅ 20230305_prof.nc | rows: 56595
#     ✅ 20230302_prof.nc | rows: 52500
#     ✅ 20230304_prof.nc | rows: 44128
#     ✅ 20230307_prof.nc | rows: 62222
#     ✅ 20230310_prof.nc | rows: 44032
#     ✅ 20230308_prof.nc | rows: 75250
#     ✅ 20230309_prof.nc | rows: 55522
#     ✅ 20230312_prof.nc | rows: 46139
#     ✅ 20230313_prof.nc | rows: 42346
#     ✅ 20230314_prof.nc | rows: 46886
#     ✅ 20230316_prof.nc | rows: 48544
#     ✅ 20230317_prof.nc | rows: 55272
#     ✅ 20230315_prof.nc | rows: 50112
#     ✅ 20230319_prof.nc | rows: 55685
#     ✅ 20230320_prof.nc | rows: 50106
#     ✅ 20230318_prof.nc | rows: 77700
#     ✅ 20230321_prof.nc | rows: 48260
#     ✅ 20230323_prof.nc | rows: 39527
#     ✅ 20230324_prof.nc | rows: 45356
#     ✅ 20230325_prof.nc | rows: 58443
#     ✅ 20230303_prof.nc | rows: 39962
#     ✅ 20230301_prof.nc | rows: 44460
#     ✅ 20230326_prof.nc | rows: 47160
#     ✅ 20230327_prof.nc | rows: 59517
#     ✅ 20230329_prof.nc | rows: 50966
#     ✅ 20230328_prof.nc | rows: 66115
#     ✅ 20230330_prof.nc | rows: 51772
#     ✅ 20230331_prof.nc | rows: 39168
#     ✅ 20230311_prof.nc | rows: 44878
#     ✅ 20230322_prof.nc | rows: 45066
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2023_03_MINIMAL.parquet | Shape: (1584299, 7)
#     ✅ 20230405_prof.nc | rows: 50427
#     ✅ 20230406_prof.nc | rows: 59517
#     ✅ 20230402_prof.nc | rows: 32520
#     ✅ 20230401_prof.nc | rows: 44520
#     ✅ 20230403_prof.nc | rows: 52288
#     ✅ 20230404_prof.nc | rows: 59310
#     ✅ 20230410_prof.nc | rows: 39134
#     ✅ 20230408_prof.nc | rows: 54575
#     ✅ 20230407_prof.nc | rows: 58752
#     ✅ 20230412_prof.nc | rows: 37152
#     ✅ 20230411_prof.nc | rows: 50728
#     ✅ 20230415_prof.nc | rows: 56004
#     ✅ 20230413_prof.nc | rows: 43554
#     ✅ 20230414_prof.nc | rows: 51677
#     ✅ 20230417_prof.nc | rows: 78273
#     ✅ 20230419_prof.nc | rows: 42107
#     ✅ 20230420_prof.nc | rows: 41436
#     ✅ 20230418_prof.nc | rows: 59592
#     ✅ 20230421_prof.nc | rows: 60480
#     ✅ 20230422_prof.nc | rows: 41370
#     ✅ 20230423_prof.nc | rows: 51480
#     ✅ 20230424_prof.nc | rows: 52992
#     ✅ 20230426_prof.nc | rows: 59125
#     ✅ 20230425_prof.nc | rows: 57288
#     ✅ 20230428_prof.nc | rows: 55227
#     ✅ 20230427_prof.nc | rows: 82216
#     ✅ 20230430_prof.nc | rows: 44472
#     ✅ 20230429_prof.nc | rows: 43700
#     ✅ 20230409_prof.nc | rows: 43602
#     ✅ 20230416_prof.nc | rows: 65136
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2023_04_MINIMAL.parquet | Shape: (1568654, 7)
#     ✅ 20230501_prof.nc | rows: 47880
#     ✅ 20230504_prof.nc | rows: 67944
#     ✅ 20230505_prof.nc | rows: 48544
#     ✅ 20230507_prof.nc | rows: 82720
#     ✅ 20230508_prof.nc | rows: 58050
#     ✅ 20230510_prof.nc | rows: 46768
#     ✅ 20230511_prof.nc | rows: 45243
#     ✅ 20230512_prof.nc | rows: 41616
#     ✅ 20230514_prof.nc | rows: 80346
#     ✅ 20230515_prof.nc | rows: 47088
#     ✅ 20230506_prof.nc | rows: 53781
#     ✅ 20230516_prof.nc | rows: 53625
#     ✅ 20230502_prof.nc | rows: 35594
#     ✅ 20230517_prof.nc | rows: 90640
#     ✅ 20230518_prof.nc | rows: 47232
#     ✅ 20230509_prof.nc | rows: 59220
#     ✅ 20230519_prof.nc | rows: 57964
#     ✅ 20230520_prof.nc | rows: 37518
#     ✅ 20230522_prof.nc | rows: 30625
#     ✅ 20230521_prof.nc | rows: 65305
#     ✅ 20230503_prof.nc | rows: 57332
#     ✅ 20230523_prof.nc | rows: 56539
#     ✅ 20230525_prof.nc | rows: 52592
#     ✅ 20230526_prof.nc | rows: 48636
#     ✅ 20230524_prof.nc | rows: 93248
#     ✅ 20230527_prof.nc | rows: 96880
#     ✅ 20230528_prof.nc | rows: 52440
#     ✅ 20230529_prof.nc | rows: 59312
#     ✅ 20230530_prof.nc | rows: 38570
#     ✅ 20230513_prof.nc | rows: 53680
#     ✅ 20230531_prof.nc | rows: 73164
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2023_05_MINIMAL.parquet | Shape: (1780096, 7)
#     ✅ 20230601_prof.nc | rows: 34776
#     ✅ 20230604_prof.nc | rows: 45675
#     ✅ 20230602_prof.nc | rows: 53820
#     ✅ 20230605_prof.nc | rows: 75852
#     ✅ 20230603_prof.nc | rows: 110520
#     ✅ 20230606_prof.nc | rows: 97794
#     ✅ 20230607_prof.nc | rows: 60122
#     ✅ 20230609_prof.nc | rows: 42315
#     ✅ 20230608_prof.nc | rows: 60750
#     ✅ 20230610_prof.nc | rows: 50502
#     ✅ 20230611_prof.nc | rows: 42870
#     ✅ 20230612_prof.nc | rows: 54390
#     ✅ 20230613_prof.nc | rows: 90695
#     ✅ 20230617_prof.nc | rows: 54432
#     ✅ 20230616_prof.nc | rows: 96725
#     ✅ 20230618_prof.nc | rows: 64896
#     ✅ 20230619_prof.nc | rows: 44802
#     ✅ 20230621_prof.nc | rows: 42625
#     ✅ 20230622_prof.nc | rows: 50690
#     ✅ 20230620_prof.nc | rows: 55831
#     ✅ 20230624_prof.nc | rows: 44870
#     ✅ 20230625_prof.nc | rows: 37666
#     ✅ 20230623_prof.nc | rows: 95032
#     ✅ 20230626_prof.nc | rows: 85632
#     ✅ 20230627_prof.nc | rows: 56373
#     ✅ 20230628_prof.nc | rows: 49876
#     ✅ 20230629_prof.nc | rows: 48321
#     ✅ 20230630_prof.nc | rows: 48280
#     ✅ 20230614_prof.nc | rows: 48433
#     ✅ 20230615_prof.nc | rows: 40760
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2023_06_MINIMAL.parquet | Shape: (1785325, 7)
#     ✅ 20230705_prof.nc | rows: 37851
#     ✅ 20230704_prof.nc | rows: 49742
#     ✅ 20230702_prof.nc | rows: 49536
#     ✅ 20230701_prof.nc | rows: 42150
#     ✅ 20230703_prof.nc | rows: 97632
#     ✅ 20230707_prof.nc | rows: 57508
#     ✅ 20230708_prof.nc | rows: 60615
#     ✅ 20230710_prof.nc | rows: 43470
#     ✅ 20230711_prof.nc | rows: 37874
#     ✅ 20230712_prof.nc | rows: 54036
#     ✅ 20230715_prof.nc | rows: 32416
#     ✅ 20230714_prof.nc | rows: 56244
#     ✅ 20230713_prof.nc | rows: 77873
#     ✅ 20230716_prof.nc | rows: 87669
#     ✅ 20230718_prof.nc | rows: 64896
#     ✅ 20230719_prof.nc | rows: 47120
#     ✅ 20230720_prof.nc | rows: 50076
#     ✅ 20230721_prof.nc | rows: 40672
#     ✅ 20230722_prof.nc | rows: 44955
#     ✅ 20230724_prof.nc | rows: 64239
#     ✅ 20230725_prof.nc | rows: 36320
#     ✅ 20230723_prof.nc | rows: 72908
#     ✅ 20230726_prof.nc | rows: 68640
#     ✅ 20230727_prof.nc | rows: 55986
#     ✅ 20230728_prof.nc | rows: 63020
#     ✅ 20230729_prof.nc | rows: 48375
#     ✅ 20230731_prof.nc | rows: 43098
#     ✅ 20230717_prof.nc | rows: 56029
#     ✅ 20230709_prof.nc | rows: 56144
#     ✅ 20230706_prof.nc | rows: 94536
#     ✅ 20230730_prof.nc | rows: 44380
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2023_07_MINIMAL.parquet | Shape: (1736010, 7)
#     ✅ 20230806_prof.nc | rows: 38570
#     ✅ 20230803_prof.nc | rows: 61088
#     ✅ 20230801_prof.nc | rows: 45430
#     ✅ 20230802_prof.nc | rows: 77264
#     ✅ 20230805_prof.nc | rows: 94503
#     ✅ 20230808_prof.nc | rows: 43559
#     ✅ 20230807_prof.nc | rows: 62928
#     ✅ 20230810_prof.nc | rows: 50680
#     ✅ 20230809_prof.nc | rows: 51012
#     ✅ 20230812_prof.nc | rows: 65919
#     ✅ 20230813_prof.nc | rows: 67983
#     ✅ 20230814_prof.nc | rows: 45258
#     ✅ 20230815_prof.nc | rows: 57464
#     ✅ 20230816_prof.nc | rows: 52288
#     ✅ 20230818_prof.nc | rows: 51946
#     ✅ 20230819_prof.nc | rows: 52416
#     ✅ 20230820_prof.nc | rows: 49284
#     ✅ 20230822_prof.nc | rows: 64395
#     ✅ 20230804_prof.nc | rows: 35872
#     ✅ 20230823_prof.nc | rows: 63744
#     ✅ 20230824_prof.nc | rows: 44200
#     ✅ 20230825_prof.nc | rows: 56158
#     ✅ 20230826_prof.nc | rows: 49644
#     ✅ 20230828_prof.nc | rows: 49320
#     ✅ 20230829_prof.nc | rows: 55734
#     ✅ 20230830_prof.nc | rows: 43715
#     ✅ 20230831_prof.nc | rows: 40970
#     ✅ 20230811_prof.nc | rows: 67284
#     ✅ 20230817_prof.nc | rows: 53815
#     ✅ 20230821_prof.nc | rows: 42455
#     ✅ 20230827_prof.nc | rows: 59731
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2023_08_MINIMAL.parquet | Shape: (1694629, 7)
#     ✅ 20230902_prof.nc | rows: 55776
#     ✅ 20230903_prof.nc | rows: 40557
#     ✅ 20230906_prof.nc | rows: 55488
#     ✅ 20230901_prof.nc | rows: 62865
#     ✅ 20230905_prof.nc | rows: 61965
#     ✅ 20230904_prof.nc | rows: 59928
#     ✅ 20230907_prof.nc | rows: 57204
#     ✅ 20230908_prof.nc | rows: 65121
#     ✅ 20230909_prof.nc | rows: 43044
#     ✅ 20230912_prof.nc | rows: 51948
#     ✅ 20230910_prof.nc | rows: 54480
#     ✅ 20230911_prof.nc | rows: 60312
#     ✅ 20230913_prof.nc | rows: 41072
#     ✅ 20230916_prof.nc | rows: 46080
#     ✅ 20230915_prof.nc | rows: 52440
#     ✅ 20230914_prof.nc | rows: 56631
#     ✅ 20230917_prof.nc | rows: 49032
#     ✅ 20230918_prof.nc | rows: 66542
#     ✅ 20230919_prof.nc | rows: 60288
#     ✅ 20230922_prof.nc | rows: 53480
#     ✅ 20230921_prof.nc | rows: 70312
#     ✅ 20230924_prof.nc | rows: 57420
#     ✅ 20230925_prof.nc | rows: 46920
#     ✅ 20230926_prof.nc | rows: 46690
#     ✅ 20230927_prof.nc | rows: 44814
#     ✅ 20230928_prof.nc | rows: 75582
#     ✅ 20230929_prof.nc | rows: 46930
#     ✅ 20230930_prof.nc | rows: 48720
#     ✅ 20230923_prof.nc | rows: 41551
#     ✅ 20230920_prof.nc | rows: 42210
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2023_09_MINIMAL.parquet | Shape: (1615402, 7)
#     ✅ 20231003_prof.nc | rows: 37888
#     ✅ 20231006_prof.nc | rows: 53268
#     ✅ 20231004_prof.nc | rows: 59984
#     ✅ 20231005_prof.nc | rows: 49464
#     ✅ 20231007_prof.nc | rows: 47600
#     ✅ 20231009_prof.nc | rows: 47386
#     ✅ 20231008_prof.nc | rows: 67000
#     ✅ 20231010_prof.nc | rows: 58368
#     ✅ 20231013_prof.nc | rows: 37587
#     ✅ 20231011_prof.nc | rows: 52041
#     ✅ 20231012_prof.nc | rows: 61785
#     ✅ 20231014_prof.nc | rows: 63553
#     ✅ 20231015_prof.nc | rows: 40722
#     ✅ 20231017_prof.nc | rows: 52728
#     ✅ 20231018_prof.nc | rows: 53440
#     ✅ 20231019_prof.nc | rows: 54045
#     ✅ 20231020_prof.nc | rows: 56718
#     ✅ 20231021_prof.nc | rows: 57240
#     ✅ 20231022_prof.nc | rows: 46444
#     ✅ 20231023_prof.nc | rows: 47229
#     ✅ 20231024_prof.nc | rows: 52931
#     ✅ 20231026_prof.nc | rows: 86619
#     ✅ 20231027_prof.nc | rows: 78584
#     ✅ 20231028_prof.nc | rows: 73226
#     ✅ 20231001_prof.nc | rows: 48342
#     ✅ 20231029_prof.nc | rows: 101800
#     ✅ 20231002_prof.nc | rows: 56211
#     ✅ 20231031_prof.nc | rows: 101426
#     ✅ 20231030_prof.nc | rows: 100896
#     ✅ 20231016_prof.nc | rows: 60500
#     ✅ 20231025_prof.nc | rows: 52920
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2023_10_MINIMAL.parquet | Shape: (1857945, 7)
#     ✅ 20231104_prof.nc | rows: 40520
#     ✅ 20231106_prof.nc | rows: 53840
#     ✅ 20231102_prof.nc | rows: 92664
#     ✅ 20231101_prof.nc | rows: 66432
#     ✅ 20231103_prof.nc | rows: 103494
#     ✅ 20231107_prof.nc | rows: 55614
#     ✅ 20231111_prof.nc | rows: 50653
#     ✅ 20231108_prof.nc | rows: 56917
#     ✅ 20231109_prof.nc | rows: 51373
#     ✅ 20231110_prof.nc | rows: 45832
#     ✅ 20231112_prof.nc | rows: 45864
#     ✅ 20231114_prof.nc | rows: 47680
#     ✅ 20231115_prof.nc | rows: 59125
#     ✅ 20231116_prof.nc | rows: 47145
#     ✅ 20231113_prof.nc | rows: 106080
#     ✅ 20231117_prof.nc | rows: 56975
#     ✅ 20231118_prof.nc | rows: 48320
#     ✅ 20231119_prof.nc | rows: 60466
#     ✅ 20231120_prof.nc | rows: 55907
#     ✅ 20231122_prof.nc | rows: 50154
#     ✅ 20231121_prof.nc | rows: 52212
#     ✅ 20231124_prof.nc | rows: 45436
#     ✅ 20231125_prof.nc | rows: 66240
#     ✅ 20231123_prof.nc | rows: 98700
#     ✅ 20231126_prof.nc | rows: 47320
#     ✅ 20231127_prof.nc | rows: 54894
#     ✅ 20231128_prof.nc | rows: 44928
#     ✅ 20231130_prof.nc | rows: 52250
#     ✅ 20231129_prof.nc | rows: 60583
#     ✅ 20231105_prof.nc | rows: 55240
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2023_11_MINIMAL.parquet | Shape: (1772858, 7)
#     ✅ 20231206_prof.nc | rows: 45540
#     ✅ 20231204_prof.nc | rows: 50388
#     ✅ 20231205_prof.nc | rows: 47191
#     ✅ 20231201_prof.nc | rows: 52098
#     ✅ 20231202_prof.nc | rows: 56452
#     ✅ 20231203_prof.nc | rows: 82164
#     ✅ 20231208_prof.nc | rows: 57624
#     ✅ 20231207_prof.nc | rows: 51441
#     ✅ 20231211_prof.nc | rows: 44870
#     ✅ 20231210_prof.nc | rows: 61380
#     ✅ 20231209_prof.nc | rows: 57500
#     ✅ 20231215_prof.nc | rows: 50484
#     ✅ 20231214_prof.nc | rows: 75140
#     ✅ 20231212_prof.nc | rows: 66000
#     ✅ 20231213_prof.nc | rows: 89872
#     ✅ 20231216_prof.nc | rows: 51023
#     ✅ 20231217_prof.nc | rows: 51300
#     ✅ 20231218_prof.nc | rows: 64024
#     ✅ 20231221_prof.nc | rows: 40320
#     ✅ 20231219_prof.nc | rows: 48000
#     ✅ 20231220_prof.nc | rows: 70356
#     ✅ 20231222_prof.nc | rows: 61920
#     ✅ 20231223_prof.nc | rows: 87032
#     ✅ 20231224_prof.nc | rows: 63856
#     ✅ 20231226_prof.nc | rows: 46784
#     ✅ 20231228_prof.nc | rows: 62169
#     ✅ 20231229_prof.nc | rows: 43995
#     ✅ 20231231_prof.nc | rows: 43680
#     ✅ 20231230_prof.nc | rows: 66332
#     ✅ 20231225_prof.nc | rows: 55186
#     ✅ 20231227_prof.nc | rows: 45955
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2023_12_MINIMAL.parquet | Shape: (1790076, 7)
#
# 📂 Processing year: 2024
#     ✅ 20240105_prof.nc | rows: 38584
#     ✅ 20240104_prof.nc | rows: 62556
#     ✅ 20240103_prof.nc | rows: 48626
#     ✅ 20240101_prof.nc | rows: 52402
#     ✅ 20240106_prof.nc | rows: 46546
#     ✅ 20240102_prof.nc | rows: 97008
#     ✅ 20240107_prof.nc | rows: 60945
#     ✅ 20240111_prof.nc | rows: 49572
#     ✅ 20240110_prof.nc | rows: 52640
#     ✅ 20240109_prof.nc | rows: 55440
#     ✅ 20240108_prof.nc | rows: 60818
#     ✅ 20240112_prof.nc | rows: 115398
#     ✅ 20240114_prof.nc | rows: 64130
#     ✅ 20240113_prof.nc | rows: 79960
#     ✅ 20240115_prof.nc | rows: 44000
#     ✅ 20240116_prof.nc | rows: 51792
#     ✅ 20240117_prof.nc | rows: 54648
#     ✅ 20240118_prof.nc | rows: 57669
#     ✅ 20240121_prof.nc | rows: 45375
#     ✅ 20240120_prof.nc | rows: 48087
#     ✅ 20240119_prof.nc | rows: 59432
#     ✅ 20240124_prof.nc | rows: 56212
#     ✅ 20240123_prof.nc | rows: 63973
#     ✅ 20240122_prof.nc | rows: 106164
#     ✅ 20240125_prof.nc | rows: 45747
#     ✅ 20240128_prof.nc | rows: 51040
#     ✅ 20240130_prof.nc | rows: 40590
#     ✅ 20240129_prof.nc | rows: 78416
#     ✅ 20240131_prof.nc | rows: 58953
#     ✅ 20240126_prof.nc | rows: 39904
#     ✅ 20240127_prof.nc | rows: 59700
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2024_01_MINIMAL.parquet | Shape: (1846327, 7)
#     ✅ 20240206_prof.nc | rows: 55037
#     ✅ 20240202_prof.nc | rows: 81958
#     ✅ 20240203_prof.nc | rows: 60270
#     ✅ 20240205_prof.nc | rows: 39875
#     ✅ 20240201_prof.nc | rows: 104040
#     ✅ 20240207_prof.nc | rows: 54012
#     ✅ 20240210_prof.nc | rows: 57666
#     ✅ 20240208_prof.nc | rows: 65377
#     ✅ 20240211_prof.nc | rows: 82775
#     ✅ 20240212_prof.nc | rows: 85422
#     ✅ 20240214_prof.nc | rows: 52760
#     ✅ 20240215_prof.nc | rows: 41250
#     ✅ 20240216_prof.nc | rows: 54708
#     ✅ 20240217_prof.nc | rows: 62750
#     ✅ 20240218_prof.nc | rows: 63495
#     ✅ 20240219_prof.nc | rows: 62475
#     ✅ 20240220_prof.nc | rows: 48846
#     ✅ 20240221_prof.nc | rows: 62479
#     ✅ 20240223_prof.nc | rows: 57015
#     ✅ 20240222_prof.nc | rows: 58876
#     ✅ 20240224_prof.nc | rows: 44676
#     ✅ 20240226_prof.nc | rows: 39780
#     ✅ 20240225_prof.nc | rows: 41447
#     ✅ 20240227_prof.nc | rows: 63504
#     ✅ 20240229_prof.nc | rows: 52480
#     ✅ 20240228_prof.nc | rows: 57792
#     ✅ 20240204_prof.nc | rows: 41220
#     ✅ 20240209_prof.nc | rows: 49720
#     ✅ 20240213_prof.nc | rows: 91260
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2024_02_MINIMAL.parquet | Shape: (1732965, 7)
#     ✅ 20240305_prof.nc | rows: 40765
#     ✅ 20240302_prof.nc | rows: 52288
#     ✅ 20240306_prof.nc | rows: 48125
#     ✅ 20240303_prof.nc | rows: 61785
#     ✅ 20240301_prof.nc | rows: 54090
#     ✅ 20240307_prof.nc | rows: 36684
#     ✅ 20240308_prof.nc | rows: 61950
#     ✅ 20240310_prof.nc | rows: 53466
#     ✅ 20240311_prof.nc | rows: 54340
#     ✅ 20240312_prof.nc | rows: 50838
#     ✅ 20240313_prof.nc | rows: 53256
#     ✅ 20240314_prof.nc | rows: 49456
#     ✅ 20240315_prof.nc | rows: 47088
#     ✅ 20240316_prof.nc | rows: 45375
#     ✅ 20240317_prof.nc | rows: 45144
#     ✅ 20240318_prof.nc | rows: 67522
#     ✅ 20240319_prof.nc | rows: 59444
#     ✅ 20240320_prof.nc | rows: 57690
#     ✅ 20240321_prof.nc | rows: 52650
#     ✅ 20240322_prof.nc | rows: 45408
#     ✅ 20240323_prof.nc | rows: 53340
#     ✅ 20240324_prof.nc | rows: 42756
#     ✅ 20240304_prof.nc | rows: 50445
#     ✅ 20240325_prof.nc | rows: 50046
#     ✅ 20240326_prof.nc | rows: 45045
#     ✅ 20240327_prof.nc | rows: 50838
#     ✅ 20240328_prof.nc | rows: 60768
#     ✅ 20240329_prof.nc | rows: 63990
#     ✅ 20240330_prof.nc | rows: 60348
#     ✅ 20240331_prof.nc | rows: 49751
#     ✅ 20240309_prof.nc | rows: 75121
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2024_03_MINIMAL.parquet | Shape: (1639812, 7)
#     ✅ 20240401_prof.nc | rows: 52174
#     ✅ 20240403_prof.nc | rows: 43989
#     ✅ 20240402_prof.nc | rows: 50840
#     ✅ 20240405_prof.nc | rows: 41520
#     ✅ 20240404_prof.nc | rows: 54642
#     ✅ 20240406_prof.nc | rows: 55040
#     ✅ 20240407_prof.nc | rows: 59643
#     ✅ 20240411_prof.nc | rows: 61920
#     ✅ 20240412_prof.nc | rows: 38874
#     ✅ 20240410_prof.nc | rows: 43882
#     ✅ 20240409_prof.nc | rows: 68370
#     ✅ 20240413_prof.nc | rows: 49931
#     ✅ 20240415_prof.nc | rows: 49913
#     ✅ 20240414_prof.nc | rows: 50661
#     ✅ 20240416_prof.nc | rows: 53625
#     ✅ 20240420_prof.nc | rows: 44004
#     ✅ 20240418_prof.nc | rows: 65120
#     ✅ 20240419_prof.nc | rows: 63308
#     ✅ 20240421_prof.nc | rows: 65904
#     ✅ 20240423_prof.nc | rows: 49588
#     ✅ 20240422_prof.nc | rows: 38812
#     ✅ 20240425_prof.nc | rows: 51186
#     ✅ 20240424_prof.nc | rows: 48982
#     ✅ 20240426_prof.nc | rows: 54280
#     ✅ 20240427_prof.nc | rows: 61152
#     ✅ 20240428_prof.nc | rows: 64032
#     ✅ 20240429_prof.nc | rows: 59340
#     ✅ 20240430_prof.nc | rows: 52059
#     ✅ 20240408_prof.nc | rows: 55809
#     ✅ 20240417_prof.nc | rows: 93912
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2024_04_MINIMAL.parquet | Shape: (1642512, 7)
#     ✅ 20240504_prof.nc | rows: 56540
#     ✅ 20240501_prof.nc | rows: 55665
#     ✅ 20240502_prof.nc | rows: 42594
#     ✅ 20240503_prof.nc | rows: 73963
#     ✅ 20240505_prof.nc | rows: 46908
#     ✅ 20240507_prof.nc | rows: 54038
#     ✅ 20240509_prof.nc | rows: 46722
#     ✅ 20240510_prof.nc | rows: 50310
#     ✅ 20240508_prof.nc | rows: 70584
#     ✅ 20240511_prof.nc | rows: 50120
#     ✅ 20240512_prof.nc | rows: 48230
#     ✅ 20240514_prof.nc | rows: 54390
#     ✅ 20240513_prof.nc | rows: 75962
#     ✅ 20240516_prof.nc | rows: 55883
#     ✅ 20240517_prof.nc | rows: 59478
#     ✅ 20240519_prof.nc | rows: 48456
#     ✅ 20240520_prof.nc | rows: 48678
#     ✅ 20240518_prof.nc | rows: 69137
#     ✅ 20240521_prof.nc | rows: 59092
#     ✅ 20240523_prof.nc | rows: 42245
#     ✅ 20240524_prof.nc | rows: 54936
#     ✅ 20240522_prof.nc | rows: 78000
#     ✅ 20240526_prof.nc | rows: 54400
#     ✅ 20240527_prof.nc | rows: 58351
#     ✅ 20240529_prof.nc | rows: 45786
#     ✅ 20240530_prof.nc | rows: 45318
#     ✅ 20240531_prof.nc | rows: 57645
#     ✅ 20240506_prof.nc | rows: 70217
#     ✅ 20240515_prof.nc | rows: 55298
#     ✅ 20240525_prof.nc | rows: 55728
#     ✅ 20240528_prof.nc | rows: 69888
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2024_05_MINIMAL.parquet | Shape: (1754562, 7)
#     ✅ 20240603_prof.nc | rows: 48951
#     ✅ 20240602_prof.nc | rows: 41820
#     ✅ 20240601_prof.nc | rows: 68000
#     ✅ 20240605_prof.nc | rows: 46274
#     ✅ 20240606_prof.nc | rows: 65136
#     ✅ 20240604_prof.nc | rows: 63792
#     ✅ 20240612_prof.nc | rows: 42882
#     ✅ 20240608_prof.nc | rows: 40426
#     ✅ 20240609_prof.nc | rows: 41738
#     ✅ 20240607_prof.nc | rows: 73500
#     ✅ 20240611_prof.nc | rows: 46682
#     ✅ 20240610_prof.nc | rows: 86000
#     ✅ 20240614_prof.nc | rows: 61523
#     ✅ 20240615_prof.nc | rows: 52767
#     ✅ 20240618_prof.nc | rows: 41580
#     ✅ 20240617_prof.nc | rows: 70560
#     ✅ 20240616_prof.nc | rows: 65136
#     ✅ 20240619_prof.nc | rows: 41984
#     ✅ 20240622_prof.nc | rows: 38494
#     ✅ 20240621_prof.nc | rows: 49536
#     ✅ 20240623_prof.nc | rows: 55356
#     ✅ 20240620_prof.nc | rows: 90000
#     ✅ 20240624_prof.nc | rows: 54516
#     ✅ 20240625_prof.nc | rows: 66060
#     ✅ 20240628_prof.nc | rows: 42253
#     ✅ 20240626_prof.nc | rows: 59039
#     ✅ 20240627_prof.nc | rows: 71757
#     ✅ 20240629_prof.nc | rows: 42714
#     ✅ 20240630_prof.nc | rows: 86000
#     ✅ 20240613_prof.nc | rows: 54161
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2024_06_MINIMAL.parquet | Shape: (1708637, 7)
#     ✅ 20240702_prof.nc | rows: 35455
#     ✅ 20240704_prof.nc | rows: 44676
#     ✅ 20240703_prof.nc | rows: 68588
#     ✅ 20240701_prof.nc | rows: 53095
#     ✅ 20240706_prof.nc | rows: 56070
#     ✅ 20240705_prof.nc | rows: 67400
#     ✅ 20240707_prof.nc | rows: 76551
#     ✅ 20240708_prof.nc | rows: 44781
#     ✅ 20240712_prof.nc | rows: 48265
#     ✅ 20240710_prof.nc | rows: 39678
#     ✅ 20240709_prof.nc | rows: 86043
#     ✅ 20240711_prof.nc | rows: 44421
#     ✅ 20240714_prof.nc | rows: 46886
#     ✅ 20240713_prof.nc | rows: 65500
#     ✅ 20240718_prof.nc | rows: 36900
#     ✅ 20240716_prof.nc | rows: 56244
#     ✅ 20240717_prof.nc | rows: 64755
#     ✅ 20240715_prof.nc | rows: 72792
#     ✅ 20240720_prof.nc | rows: 48995
#     ✅ 20240721_prof.nc | rows: 43282
#     ✅ 20240723_prof.nc | rows: 53640
#     ✅ 20240724_prof.nc | rows: 53118
#     ✅ 20240722_prof.nc | rows: 59254
#     ✅ 20240725_prof.nc | rows: 56490
#     ✅ 20240726_prof.nc | rows: 66657
#     ✅ 20240719_prof.nc | rows: 65967
#     ✅ 20240728_prof.nc | rows: 40920
#     ✅ 20240727_prof.nc | rows: 59286
#     ✅ 20240730_prof.nc | rows: 51004
#     ✅ 20240731_prof.nc | rows: 38726
#     ✅ 20240729_prof.nc | rows: 64000
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2024_07_MINIMAL.parquet | Shape: (1709439, 7)
#     ✅ 20240801_prof.nc | rows: 60412
#     ✅ 20240803_prof.nc | rows: 42602
#     ✅ 20240802_prof.nc | rows: 73700
#     ✅ 20240806_prof.nc | rows: 65898
#     ✅ 20240804_prof.nc | rows: 59356
#     ✅ 20240805_prof.nc | rows: 74841
#     ✅ 20240807_prof.nc | rows: 82041
#     ✅ 20240808_prof.nc | rows: 39382
#     ✅ 20240810_prof.nc | rows: 40324
#     ✅ 20240812_prof.nc | rows: 71500
#     ✅ 20240811_prof.nc | rows: 60412
#     ✅ 20240813_prof.nc | rows: 32103
#     ✅ 20240814_prof.nc | rows: 62698
#     ✅ 20240817_prof.nc | rows: 70035
#     ✅ 20240816_prof.nc | rows: 66836
#     ✅ 20240818_prof.nc | rows: 46172
#     ✅ 20240815_prof.nc | rows: 69748
#     ✅ 20240823_prof.nc | rows: 39534
#     ✅ 20240821_prof.nc | rows: 63296
#     ✅ 20240820_prof.nc | rows: 51828
#     ✅ 20240822_prof.nc | rows: 63312
#     ✅ 20240827_prof.nc | rows: 37026
#     ✅ 20240824_prof.nc | rows: 58652
#     ✅ 20240826_prof.nc | rows: 92000
#     ✅ 20240829_prof.nc | rows: 44319
#     ✅ 20240830_prof.nc | rows: 47838
#     ✅ 20240809_prof.nc | rows: 51213
#     ✅ 20240831_prof.nc | rows: 64766
#     ✅ 20240819_prof.nc | rows: 39780
#     ✅ 20240825_prof.nc | rows: 72520
#     ✅ 20240828_prof.nc | rows: 40740
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2024_08_MINIMAL.parquet | Shape: (1784884, 7)
#     ✅ 20240902_prof.nc | rows: 43610
#     ✅ 20240906_prof.nc | rows: 40512
#     ✅ 20240901_prof.nc | rows: 57640
#     ✅ 20240904_prof.nc | rows: 65936
#     ✅ 20240905_prof.nc | rows: 94047
#     ✅ 20240910_prof.nc | rows: 62134
#     ✅ 20240909_prof.nc | rows: 48120
#     ✅ 20240911_prof.nc | rows: 58002
#     ✅ 20240912_prof.nc | rows: 52630
#     ✅ 20240913_prof.nc | rows: 51408
#     ✅ 20240914_prof.nc | rows: 70384
#     ✅ 20240915_prof.nc | rows: 95952
#     ✅ 20240916_prof.nc | rows: 50076
#     ✅ 20240917_prof.nc | rows: 32670
#     ✅ 20240918_prof.nc | rows: 46308
#     ✅ 20240921_prof.nc | rows: 49500
#     ✅ 20240903_prof.nc | rows: 65170
#     ✅ 20240908_prof.nc | rows: 39882
#     ✅ 20240923_prof.nc | rows: 54768
#     ✅ 20240907_prof.nc | rows: 44748
#     ✅ 20240926_prof.nc | rows: 38040
#     ✅ 20240925_prof.nc | rows: 72435
#     ✅ 20240924_prof.nc | rows: 94000
#     ✅ 20240919_prof.nc | rows: 46080
#     ✅ 20240927_prof.nc | rows: 30390
#     ✅ 20240929_prof.nc | rows: 47191
#     ✅ 20240930_prof.nc | rows: 54243
#     ✅ 20240928_prof.nc | rows: 46274
#     ✅ 20240920_prof.nc | rows: 63168
#     ✅ 20240922_prof.nc | rows: 59355
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2024_09_MINIMAL.parquet | Shape: (1674673, 7)
#     ✅ 20241001_prof.nc | rows: 53703
#     ✅ 20241006_prof.nc | rows: 31025
#     ✅ 20241003_prof.nc | rows: 61350
#     ✅ 20241002_prof.nc | rows: 57319
#     ✅ 20241005_prof.nc | rows: 77112
#     ✅ 20241004_prof.nc | rows: 96048
#     ✅ 20241007_prof.nc | rows: 32608
#     ✅ 20241009_prof.nc | rows: 48384
#     ✅ 20241008_prof.nc | rows: 44814
#     ✅ 20241010_prof.nc | rows: 55524
#     ✅ 20241011_prof.nc | rows: 56621
#     ✅ 20241012_prof.nc | rows: 57104
#     ✅ 20241014_prof.nc | rows: 54894
#     ✅ 20241016_prof.nc | rows: 33399
#     ✅ 20241015_prof.nc | rows: 77976
#     ✅ 20241017_prof.nc | rows: 29493
#     ✅ 20241018_prof.nc | rows: 50209
#     ✅ 20241019_prof.nc | rows: 47838
#     ✅ 20241020_prof.nc | rows: 54489
#     ✅ 20241021_prof.nc | rows: 60720
#     ✅ 20241022_prof.nc | rows: 66453
#     ✅ 20241024_prof.nc | rows: 54160
#     ✅ 20241023_prof.nc | rows: 116058
#     ✅ 20241027_prof.nc | rows: 27297
#     ✅ 20241026_prof.nc | rows: 43092
#     ✅ 20241028_prof.nc | rows: 50061
#     ✅ 20241029_prof.nc | rows: 50568
#     ✅ 20241025_prof.nc | rows: 67666
#     ✅ 20241030_prof.nc | rows: 57018
#     ✅ 20241013_prof.nc | rows: 113943
#     ✅ 20241031_prof.nc | rows: 52440
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2024_10_MINIMAL.parquet | Shape: (1779386, 7)
#     ✅ 20241106_prof.nc | rows: 32200
#     ✅ 20241105_prof.nc | rows: 42756
#     ✅ 20241102_prof.nc | rows: 98000
#     ✅ 20241103_prof.nc | rows: 59092
#     ✅ 20241101_prof.nc | rows: 68952
#     ✅ 20241104_prof.nc | rows: 66440
#     ✅ 20241107_prof.nc | rows: 52923
#     ✅ 20241108_prof.nc | rows: 49720
#     ✅ 20241110_prof.nc | rows: 56334
#     ✅ 20241111_prof.nc | rows: 98049
#     ✅ 20241113_prof.nc | rows: 57663
#     ✅ 20241114_prof.nc | rows: 57687
#     ✅ 20241116_prof.nc | rows: 27297
#     ✅ 20241117_prof.nc | rows: 38940
#     ✅ 20241118_prof.nc | rows: 59488
#     ✅ 20241119_prof.nc | rows: 54120
#     ✅ 20241120_prof.nc | rows: 67850
#     ✅ 20241122_prof.nc | rows: 67496
#     ✅ 20241123_prof.nc | rows: 51480
#     ✅ 20241124_prof.nc | rows: 60880
#     ✅ 20241125_prof.nc | rows: 49686
#     ✅ 20241126_prof.nc | rows: 54911
#     ✅ 20241112_prof.nc | rows: 65023
#     ✅ 20241127_prof.nc | rows: 48298
#     ✅ 20241128_prof.nc | rows: 57132
#     ✅ 20241130_prof.nc | rows: 100050
#     ✅ 20241109_prof.nc | rows: 59805
#     ✅ 20241115_prof.nc | rows: 51795
#     ✅ 20241121_prof.nc | rows: 80000
#     ✅ 20241129_prof.nc | rows: 56545
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2024_11_MINIMAL.parquet | Shape: (1790612, 7)
#     ✅ 20241202_prof.nc | rows: 64600
#     ✅ 20241201_prof.nc | rows: 52884
#     ✅ 20241205_prof.nc | rows: 55062
#     ✅ 20241206_prof.nc | rows: 60700
#     ✅ 20241203_prof.nc | rows: 54040
#     ✅ 20241204_prof.nc | rows: 64328
#     ✅ 20241207_prof.nc | rows: 44421
#     ✅ 20241208_prof.nc | rows: 56580
#     ✅ 20241209_prof.nc | rows: 56674
#     ✅ 20241211_prof.nc | rows: 57708
#     ✅ 20241213_prof.nc | rows: 58080
#     ✅ 20241216_prof.nc | rows: 40760
#     ✅ 20241215_prof.nc | rows: 58515
#     ✅ 20241214_prof.nc | rows: 59800
#     ✅ 20241218_prof.nc | rows: 49938
#     ✅ 20241217_prof.nc | rows: 61593
#     ✅ 20241220_prof.nc | rows: 55678
#     ✅ 20241219_prof.nc | rows: 96048
#     ✅ 20241222_prof.nc | rows: 65500
#     ✅ 20241223_prof.nc | rows: 60243
#     ✅ 20241225_prof.nc | rows: 44748
#     ✅ 20241226_prof.nc | rows: 50355
#     ✅ 20241227_prof.nc | rows: 59290
#     ✅ 20241212_prof.nc | rows: 66716
#     ✅ 20241228_prof.nc | rows: 52000
#     ✅ 20241229_prof.nc | rows: 96000
#     ✅ 20241230_prof.nc | rows: 53001
#     ✅ 20241231_prof.nc | rows: 55692
#     ✅ 20241210_prof.nc | rows: 99950
#     ✅ 20241221_prof.nc | rows: 56457
#     ✅ 20241224_prof.nc | rows: 62748
#   ✅ Saved: /content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/2024_12_MINIMAL.parquet | Shape: (1870109, 7)
#
# 🎉 Prototype processing complete!

# %%
import pandas as pd
import os
import pyarrow.parquet as pq

OUT_DIR = "/content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet"
metadata = []

for f in os.listdir(OUT_DIR):
    if f.endswith(".parquet"):
        path = os.path.join(OUT_DIR, f)
        pq_file = pq.ParquetFile(path)
        df_sample = pq_file.read_row_group(0).to_pandas()
        metadata.append({
            "file_path": path,
            "year": int(f[:4]),
            "month": int(f[5:7]),
            "lat_min": df_sample["LATITUDE"].min(),
            "lat_max": df_sample["LATITUDE"].max(),
            "lon_min": df_sample["LONGITUDE"].min(),
            "lon_max": df_sample["LONGITUDE"].max(),
            "depth_min": df_sample["DEPTH_M"].min(),
            "depth_max": df_sample["DEPTH_M"].max(),
            "num_rows": pq_file.metadata.num_rows
        })

meta_df = pd.DataFrame(metadata)
meta_df.to_csv("/content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_metadata_catalog.csv", index=False)
print(meta_df.head())
# Out:
#                                            file_path  year  month    lat_min  \
# 0  /content/drive/MyDrive/ColabNotebooks/SIH2025/...  2022      1 -39.869000
# 1  /content/drive/MyDrive/ColabNotebooks/SIH2025/...  2022      2 -39.906908
# 2  /content/drive/MyDrive/ColabNotebooks/SIH2025/...  2022      3 -39.985000
# 3  /content/drive/MyDrive/ColabNotebooks/SIH2025/...  2022      4 -39.929090
# 4  /content/drive/MyDrive/ColabNotebooks/SIH2025/...  2022      5 -39.912000
#
#      lat_max   lon_min    lon_max  depth_min    depth_max  num_rows
# 0  25.530760  30.86684  109.95030        0.0  4512.899902   1424143
# 1  25.096493  30.17752  109.77480        0.0  4510.209961   1279043
# 2  25.044137  31.17850  109.79900       -0.2  4512.849609   1396118
# 3  26.758967  30.53059  109.89499       -0.1  4502.609863   1465770
# 4  24.786320  31.01284  109.53160        0.0  4529.600098   1367667

# %%
import dask.dataframe as dd

df = dd.read_parquet("/content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/*.parquet")

# List columns
print(df.columns)
# Out:
# Index(['LATITUDE', 'LONGITUDE', 'JULD', 'DEPTH_M', 'TEMP', 'PSAL',
#        'source_file'],
#       dtype='object')

# %%
import dask.dataframe as dd

# Load all parquet files
df = dd.read_parquet("/content/drive/MyDrive/ColabNotebooks/SIH2025/Data/argo_prototype_parquet/*.parquet")

# Example: filter for Bay of Bengal profiles at ~500m in 2023
subset = df[
    (df.LATITUDE.between(5, 20)) &
    (df.LONGITUDE.between(80, 95)) &
    (df.DEPTH_M.between(490, 510)) &
    (df.JULD.dt.year == 2023)
]

# Compute to get a pandas DataFrame
result = subset.compute()
print(result.head())

# %%
import matplotlib.pyplot as plt
import plotly.express as px

# ✅ Depth Profile (Temperature vs Depth)
sample_file = result["source_file"].iloc[0]
profile = result[result["source_file"] == sample_file]

plt.figure(figsize=(6, 8))
plt.plot(profile["TEMP"], profile["DEPTH_M"], marker="o", color="blue")
plt.gca().invert_yaxis()
plt.xlabel("Temperature (°C)")
plt.ylabel("Depth (m)")
plt.title(f"Temperature Profile - {sample_file}")
plt.show()

# ✅ Time Series (Salinity at 500m in Bay of Bengal)
time_series = result[result["DEPTH_M"].between(495, 505)]

plt.figure(figsize=(10, 5))
plt.plot(time_series["JULD"], time_series["PSAL"], marker=".", linestyle="-", color="green")
plt.xlabel("Date")
plt.ylabel("Salinity (PSU)")
plt.title("Salinity at ~500m (Bay of Bengal, 2023)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# ✅ Spatial Map (Lat/Lon colored by Temperature)
map_df = result.copy()

fig = px.scatter_geo(
    map_df,
    lat="LATITUDE",
    lon="LONGITUDE",
    color="TEMP",
    title="Spatial Distribution of Temperature (500m depth, 2023)",
    color_continuous_scale="Viridis",
    projection="natural earth"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a3361e16-4458-4738-bcca-274c1c6a8e6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3361e16-4458-4738-bcca-274c1c6a8e6c")) {                    Plotly.newPlot(                        "a3361e16-4458-4738-bcca-274c1c6a8e6c",                        [{"geo":"geo","hovertemplate":"LATITUDE=%{lat}\u003cbr\u003eLONGITUDE=%{lon}\u003cbr\u003eTEMP=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[6.981966,6.981966,6.981966,6.981966,6.981966,6.981966,6.981966,6.981966,6.981966,11.004,11.004,11.004,10.877,10.877,10.877,19.114,19.114,10.440458333333334,10.440458333333334,18.989,18.989,10.873,10.873,10.873,18.899,18.899,6.792287,6.792287,6.792287,6.792287,6.792287,6.792287,6.792287,6.792287,6.792287,6.792287,18.804,18.804,10.183761666666667,10.183761666666667,10.891,10.891,10.891,11.15123,11.15123,11.15123,11.15123,11.15123,11.15123,11.15123,11.15123,11.15123,11.15123,6.102,10.867,10.867,10.867,18.686,18.686,18.447,18.447,10.0011,10.0011,11.12913,11.12913,11.12913,11.12913,11.12913,11.12913,11.12913,11.12913,11.12913,11.12913,11.12913,6.898314,6.898314,6.898314,6.898314,6.898314,6.898314,6.898314,6.898314,6.898314,6.898314,6.898314,11.40318,11.40318,11.40318,11.40318,11.40318,11.40318,11.40318,11.40318,11.40318,11.40318,10.973,10.973,10.973,6.850772,6.850772,6.850772,6.850772,6.850772,6.850772,6.850772,6.850772,6.850772,10.918,10.918,10.918,6.770216,6.770216,6.770216,6.770216,6.770216,6.770216,6.770216,6.770216,6.770216,6.770216,18.296,18.296,11.049,11.049,11.049,11.648481933284117,11.648481933284117,11.648481933284117,11.648481933284117,11.648481933284117,11.648481933284117,11.648481933284117,11.648481933284117,11.648481933284117,11.648481933284117,9.90383,9.90383,18.217,18.217,10.99,10.99,10.99,5.10155,5.10155,5.10155,5.10155,5.10155,5.10155,5.10155,5.10155,5.10155,7.29338,7.29338,7.29338,7.29338,7.29338,7.29338,7.29338,7.29338,7.29338,7.29338,5.04854,5.04854,5.04854,5.04854,5.04854,5.04854,5.04854,5.04854,5.04854,5.04854,5.04854,18.28,18.28,18.195,18.195,11.3933,11.3933,11.3933,11.3933,11.3933,11.3933,11.3933,11.3933,11.3933,11.3933,10.924,10.924,10.924,9.893385,9.893385,11.035,11.035,11.035,7.13762,7.13762,7.13762,7.13762,7.13762,7.13762,7.13762,7.13762,7.13762,7.13762,7.13762,18.219,18.219,7.437565,7.437565,7.437565,7.437565,7.437565,7.437565,7.437565,7.437565,7.437565,7.437565,7.437565,10.816,10.816,10.816,18.206,18.206,7.467847,7.467847,7.467847,7.467847,7.467847,7.467847,7.467847,7.467847,7.467847,7.467847,11.32649,11.32649,11.32649,11.32649,11.32649,11.32649,11.32649,11.32649,11.32649,11.32649,10.752,10.752,10.752,9.91488,9.91488,10.712,10.712,10.712,18.01,18.01,7.49788,7.49788,7.49788,7.49788,7.49788,7.49788,7.49788,7.49788,7.49788,17.71,17.71,7.538918,7.538918,7.538918,7.538918,7.538918,7.538918,7.538918,7.538918,7.538918,11.26199,11.26199,11.26199,11.26199,11.26199,11.26199,11.26199,11.26199,11.26199,11.26199,10.661,10.661,10.661,10.001126666666666,10.001126666666666,7.559662,7.559662,7.559662,7.559662,7.559662,7.559662,7.559662,7.559662,7.559662,7.559662,10.557,10.557,10.557,7.621573,7.621573,7.621573,7.621573,7.621573,7.621573,7.621573,7.621573,7.621573,7.621573,7.621573,11.09101,11.09101,11.09101,11.09101,11.09101,11.09101,11.09101,11.09101,11.09101,11.09101,10.481,10.481,10.481,9.969291666666667,9.969291666666667,10.41,10.41,10.41,7.696832,7.696832,7.696832,7.696832,7.696832,7.696832,7.696832,7.696832,7.696832,7.696832,10.8403,10.8403,10.8403,10.8403,10.8403,10.8403,10.8403,10.8403,10.8403,10.8403,10.283,10.283,10.283,9.834691666666666,9.834691666666666,10.059,10.059,10.059,10.62403,10.62403,10.62403,10.62403,10.62403,10.62403,10.62403,10.62403,10.62403,10.62403,10.62403,9.823,9.823,9.823,9.564,9.56 ...
